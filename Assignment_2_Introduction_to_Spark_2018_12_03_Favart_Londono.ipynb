# %% [markdown]
# # Big Data Algorithm & Platforms, Assignment 2, Spark
# ## Caroline FAVART - Juan LONDONO

# %% [markdown]
# # Spark (with PySpark)
#
#
# In this tutorial, you will learn how to use Apache Spark, a framework for large-scale data processing, within a notebook.
# Upon completing this lab you will be able to :
#  + Program in Spark with the Python Language
#  + Demonstrate how to read and process data using Spark
#  + Compare and contrast RDD and Dataframes.
#  + Build a simple machine learning application with Spark.
#
#
#
# # Requirements : Installing Spark, PySpark and configuration to run it on jupyter notebooks
#
# According to your OS, you have to follow the following tutorial :
#
# + [Windows](https://changhsinlee.com/install-pyspark-windows-jupyter/)
# + [Mac Os X](https://jmedium.com/pyspark-in-mac/)
#
# At the end of the installation, you should be able to run the following code that is a kind of Hello word in PySpark.

# %%
import findspark
findspark.init()

import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

df = spark.sql('''select 'spark' as hello ''')
df.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-84edcc0ab449> in <module>()
#       1 import findspark
# ----> 2 findspark.init()
#       3
#       4 import pyspark # only run after findspark.init()
#       5 from pyspark.sql import SparkSession
#
# ~\Anaconda3\lib\site-packages\findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     133     # add pyspark to sys.path
#     134     spark_python = os.path.join(spark_home, 'python')
# --> 135     py4j = glob(os.path.join(spark_python, 'lib', 'py4j-*.zip'))[0]
#     136     sys.path[:0] = [spark_python, py4j]
#     137
#
# IndexError: list index out of range

# %%
spark.stop()

# %% [markdown]
# ## Part 1 :  Spark Context
#
# When writing a spark program, the first thing to do is to define a `SparkContext`.
#
# In Spark, communication occurs between a driver and executors. The driver has Spark jobs that it needs to run and these jobs are split into tasks that are submitted to the executors for completion. The results from these tasks are delivered back to the driver.
#
# Here, we will use the `findspark` package that has to be installed using the following command:
#
# ` pip3 install findspark`
#
# Then we can use the `findspark.init()`function to locate the Spark process.

# %%
# Import of findspark and pyspark and definition of the Spark Context

import findspark

findspark.init()

import pyspark

sc=pyspark.SparkContext("local[*]","First program in Spark")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-34dc395aa980> in <module>()
#       3 import findspark
#       4
# ----> 5 findspark.init()
#       6
#       7 import pyspark
#
# ~\Anaconda3\lib\site-packages\findspark.py in init(spark_home, python_path, edit_rc, edit_profile)
#     133     # add pyspark to sys.path
#     134     spark_python = os.path.join(spark_home, 'python')
# --> 135     py4j = glob(os.path.join(spark_python, 'lib', 'py4j-*.zip'))[0]
#     136     sys.path[:0] = [spark_python, py4j]
#     137
#
# IndexError: list index out of range

# %% [markdown]
# Try printing out sc to see its type.

# %%
# Printing the Spark Context

print(sc, 'type : ', type(sc))
# Out:
# (<SparkContext master=local[*] appName=First program in Spark>, 'type : ', <class 'pyspark.context.SparkContext'>)

# %% [markdown]
# sc is a SparkContext class object.

# %% [markdown]
# You can use Python's `dir()` function to get a list of all the attributes (including methods) accessible through the `sc` object.

# %%
# Printing the list of all attributes accessible through sc
dir(sc)
# Out:
# ['PACKAGE_EXTENSIONS',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__enter__',
#  '__exit__',
#  '__format__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accumulatorServer',
#  '_active_spark_context',
#  '_batchSize',
#  '_callsite',
#  '_checkpointFile',
#  '_conf',
#  '_dictToJavaMap',
#  '_do_init',
#  '_encryption_enabled',
#  '_ensure_initialized',
#  '_gateway',
#  '_getJavaStorageLevel',
#  '_initialize_context',
#  '_javaAccumulator',
#  '_jsc',
#  '_jvm',
#  '_lock',
#  '_next_accum_id',
#  '_pickled_broadcast_vars',
#  '_python_includes',
#  '_repr_html_',
#  '_serialize_to_jvm',
#  '_temp_dir',
#  '_unbatched_serializer',
#  'accumulator',
#  'addFile',
#  'addPyFile',
#  'appName',
#  'applicationId',
#  'binaryFiles',
#  'binaryRecords',
#  'broadcast',
#  'cancelAllJobs',
#  'cancelJobGroup',
#  'defaultMinPartitions',
#  'defaultParallelism',
#  'dump_profiles',
#  'emptyRDD',
#  'environment',
#  'getConf',
#  'getLocalProperty',
#  'getOrCreate',
#  'hadoopFile',
#  'hadoopRDD',
#  'master',
#  'newAPIHadoopFile',
#  'newAPIHadoopRDD',
#  'parallelize',
#  'pickleFile',
#  'profiler_collector',
#  'pythonExec',
#  'pythonVer',
#  'range',
#  'runJob',
#  'sequenceFile',
#  'serializer',
#  'setCheckpointDir',
#  'setJobDescription',
#  'setJobGroup',
#  'setLocalProperty',
#  'setLogLevel',
#  'setSystemProperty',
#  'show_profiles',
#  'sparkHome',
#  'sparkUser',
#  'startTime',
#  'statusTracker',
#  'stop',
#  'textFile',
#  'uiWebUrl',
#  'union',
#  'version',
#  'wholeTextFiles']

# %% [markdown]
# ## Part 2 : Understanding Spark RDD’s

# %% [markdown]
# ### WordCount in Spark
# In this part, we will write the wordcount in Spark and apply it on the novel Dracula of Bram Stocker (from the Gutemberg project).
#
# First read the [pg345.txt](./SparkData/pg345.txt) file.

# %%
# Loading the text data
data = sc.textFile('./SparkData/pg345.txt')
type(data)
# Out:
# pyspark.rdd.RDD

# %% [markdown]
# To see the content, of the file, we need to run the action `collect` on the  RDD `data`

# %%
# Displaying the data (as it is a RDD, we use the action collect)
data.collect()
# Out:
# [u'The Project Gutenberg EBook of Dracula, by Bram Stoker',
#  u'',
#  u'This eBook is for the use of anyone anywhere at no cost and with',
#  u'almost no restrictions whatsoever.  You may copy it, give it away or',
#  u're-use it under the terms of the Project Gutenberg License included',
#  u'with this eBook or online at www.gutenberg.org/license',
#  u'',
#  u'',
#  u'Title: Dracula',
#  u'',
#  u'Author: Bram Stoker',
#  u'',
#  u'Release Date: August 16, 2013 [EBook #345]',
#  u'',
#  u'Language: English',
#  u'',
#  u'',
#  u'*** START OF THIS PROJECT GUTENBERG EBOOK DRACULA ***',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'Produced by Chuck Greif and the Online Distributed',
#  u'Proofreading Team at http://www.pgdp.net (This file was',
#  u'produced from images generously made available by The',
#  u'Internet Archive)',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'                                DRACULA',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'                                DRACULA',
#  u'',
#  u'                                  _by_',
#  u'',
#  u'                              Bram Stoker',
#  u'',
#  u'                        [Illustration: colophon]',
#  u'',
#  u'                                NEW YORK',
#  u'',
#  u'                            GROSSET & DUNLAP',
#  u'',
#  u'                              _Publishers_',
#  u'',
#  u'      Copyright, 1897, in the United States of America, according',
#  u'                   to Act of Congress, by Bram Stoker',
#  u'',
#  u'                        [_All rights reserved._]',
#  u'',
#  u'                      PRINTED IN THE UNITED STATES',
#  u'                                   AT',
#  u'               THE COUNTRY LIFE PRESS, GARDEN CITY, N.Y.',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'                                   TO',
#  u'',
#  u'                             MY DEAR FRIEND',
#  u'',
#  u'                               HOMMY-BEG',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'CONTENTS',
#  u'',
#  u'',
#  u'CHAPTER I',
#  u'                                                                    Page',
#  u'',
#  u"Jonathan Harker's Journal                                              1",
#  u'',
#  u'CHAPTER II',
#  u'',
#  u"Jonathan Harker's Journal                                             14",
#  u'',
#  u'CHAPTER III',
#  u'',
#  u"Jonathan Harker's Journal                                             26",
#  u'',
#  u'CHAPTER IV',
#  u'',
#  u"Jonathan Harker's Journal                                             38",
#  u'',
#  u'CHAPTER V',
#  u'',
#  u'Letters--Lucy and Mina                                                51',
#  u'',
#  u'CHAPTER VI',
#  u'',
#  u"Mina Murray's Journal                                                 59",
#  u'',
#  u'CHAPTER VII',
#  u'',
#  u'Cutting from "The Dailygraph," 8 August                               71',
#  u'',
#  u'CHAPTER VIII',
#  u'',
#  u"Mina Murray's Journal                                                 84",
#  u'',
#  u'CHAPTER IX',
#  u'',
#  u"Mina Murray's Journal                                                 98",
#  u'',
#  u'CHAPTER X',
#  u'',
#  u"Mina Murray's Journal                                                111",
#  u'',
#  u'CHAPTER XI',
#  u'',
#  u"Lucy Westenra's Diary                                                124",
#  u'',
#  u'CHAPTER XII',
#  u'',
#  u"Dr. Seward's Diary                                                   136",
#  u'',
#  u'CHAPTER XIII',
#  u'',
#  u"Dr. Seward's Diary                                                   152",
#  u'',
#  u'CHAPTER XIV',
#  u'',
#  u"Mina Harker's Journal                                                167",
#  u'',
#  u'CHAPTER XV',
#  u'',
#  u"Dr. Seward's Diary                                                   181",
#  u'',
#  u'CHAPTER XVI',
#  u'',
#  u"Dr. Seward's Diary                                                   194",
#  u'',
#  u'CHAPTER XVII',
#  u'',
#  u"Dr. Seward's Diary                                                   204",
#  u'',
#  u'CHAPTER XVIII',
#  u'',
#  u"Dr. Seward's Diary                                                   216",
#  u'',
#  u'CHAPTER XIX',
#  u'',
#  u"Jonathan Harker's Journal                                            231",
#  u'',
#  u'CHAPTER XX',
#  u'',
#  u"Jonathan Harker's Journal                                            243",
#  u'',
#  u'CHAPTER XXI',
#  u'',
#  u"Dr. Seward's Diary                                                   256",
#  u'',
#  u'CHAPTER XXII',
#  u'',
#  u"Jonathan Harker's Journal                                            269",
#  u'',
#  u'CHAPTER XXIII',
#  u'',
#  u"Dr. Seward's Diary                                                   281",
#  u'',
#  u'CHAPTER XXIV',
#  u'',
#  u"Dr. Seward's Phonograph Diary, spoken by Van Helsing                 294",
#  u'',
#  u'CHAPTER XXV',
#  u'',
#  u"Dr. Seward's Diary                                                   308",
#  u'',
#  u'CHAPTER XXVI',
#  u'',
#  u"Dr. Seward's Diary                                                   322",
#  u'',
#  u'CHAPTER XXVII',
#  u'',
#  u"Mina Harker's Journal                                                338",
#  u'',
#  u'',
#  u'',
#  u'',
#  u'DRACULA',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'CHAPTER I',
#  u'',
#  u"JONATHAN HARKER'S JOURNAL",
#  u'',
#  u'(_Kept in shorthand._)',
#  u'',
#  u'',
#  u'_3 May. Bistritz._--Left Munich at 8:35 P. M., on 1st May, arriving at',
#  u'Vienna early next morning; should have arrived at 6:46, but train was an',
#  u'hour late. Buda-Pesth seems a wonderful place, from the glimpse which I',
#  u'got of it from the train and the little I could walk through the',
#  u'streets. I feared to go very far from the station, as we had arrived',
#  u'late and would start as near the correct time as possible. The',
#  u'impression I had was that we were leaving the West and entering the',
#  u'East; the most western of splendid bridges over the Danube, which is',
#  u'here of noble width and depth, took us among the traditions of Turkish',
#  u'rule.',
#  u'',
#  u'We left in pretty good time, and came after nightfall to Klausenburgh.',
#  u'Here I stopped for the night at the Hotel Royale. I had for dinner, or',
#  u'rather supper, a chicken done up some way with red pepper, which was',
#  u'very good but thirsty. (_Mem._, get recipe for Mina.) I asked the',
#  u'waiter, and he said it was called "paprika hendl," and that, as it was a',
#  u'national dish, I should be able to get it anywhere along the',
#  u'Carpathians. I found my smattering of German very useful here; indeed, I',
#  u"don't know how I should be able to get on without it.",
#  u'',
#  u'Having had some time at my disposal when in London, I had visited the',
#  u'British Museum, and made search among the books and maps in the library',
#  u'regarding Transylvania; it had struck me that some foreknowledge of the',
#  u'country could hardly fail to have some importance in dealing with a',
#  u'nobleman of that country. I find that the district he named is in the',
#  u'extreme east of the country, just on the borders of three states,',
#  u'Transylvania, Moldavia and Bukovina, in the midst of the Carpathian',
#  u'mountains; one of the wildest and least known portions of Europe. I was',
#  u'not able to light on any map or work giving the exact locality of the',
#  u'Castle Dracula, as there are no maps of this country as yet to compare',
#  u'with our own Ordnance Survey maps; but I found that Bistritz, the post',
#  u'town named by Count Dracula, is a fairly well-known place. I shall enter',
#  u'here some of my notes, as they may refresh my memory when I talk over my',
#  u'travels with Mina.',
#  u'',
#  u'In the population of Transylvania there are four distinct nationalities:',
#  u'Saxons in the South, and mixed with them the Wallachs, who are the',
#  u'descendants of the Dacians; Magyars in the West, and Szekelys in the',
#  u'East and North. I am going among the latter, who claim to be descended',
#  u'from Attila and the Huns. This may be so, for when the Magyars conquered',
#  u'the country in the eleventh century they found the Huns settled in it. I',
#  u'read that every known superstition in the world is gathered into the',
#  u'horseshoe of the Carpathians, as if it were the centre of some sort of',
#  u'imaginative whirlpool; if so my stay may be very interesting. (_Mem._, I',
#  u'must ask the Count all about them.)',
#  u'',
#  u'I did not sleep well, though my bed was comfortable enough, for I had',
#  u'all sorts of queer dreams. There was a dog howling all night under my',
#  u'window, which may have had something to do with it; or it may have been',
#  u'the paprika, for I had to drink up all the water in my carafe, and was',
#  u'still thirsty. Towards morning I slept and was wakened by the continuous',
#  u'knocking at my door, so I guess I must have been sleeping soundly then.',
#  u'I had for breakfast more paprika, and a sort of porridge of maize flour',
#  u'which they said was "mamaliga," and egg-plant stuffed with forcemeat, a',
#  u'very excellent dish, which they call "impletata." (_Mem._, get recipe',
#  u'for this also.) I had to hurry breakfast, for the train started a little',
#  u'before eight, or rather it ought to have done so, for after rushing to',
#  u'the station at 7:30 I had to sit in the carriage for more than an hour',
#  u'before we began to move. It seems to me that the further east you go the',
#  u'more unpunctual are the trains. What ought they to be in China?',
#  u'',
#  u'All day long we seemed to dawdle through a country which was full of',
#  u'beauty of every kind. Sometimes we saw little towns or castles on the',
#  u'top of steep hills such as we see in old missals; sometimes we ran by',
#  u'rivers and streams which seemed from the wide stony margin on each side',
#  u'of them to be subject to great floods. It takes a lot of water, and',
#  u'running strong, to sweep the outside edge of a river clear. At every',
#  u'station there were groups of people, sometimes crowds, and in all sorts',
#  u'of attire. Some of them were just like the peasants at home or those I',
#  u'saw coming through France and Germany, with short jackets and round hats',
#  u'and home-made trousers; but others were very picturesque. The women',
#  u'looked pretty, except when you got near them, but they were very clumsy',
#  u'about the waist. They had all full white sleeves of some kind or other,',
#  u'and most of them had big belts with a lot of strips of something',
#  u'fluttering from them like the dresses in a ballet, but of course there',
#  u'were petticoats under them. The strangest figures we saw were the',
#  u'Slovaks, who were more barbarian than the rest, with their big cow-boy',
#  u'hats, great baggy dirty-white trousers, white linen shirts, and enormous',
#  u'heavy leather belts, nearly a foot wide, all studded over with brass',
#  u'nails. They wore high boots, with their trousers tucked into them, and',
#  u'had long black hair and heavy black moustaches. They are very',
#  u'picturesque, but do not look prepossessing. On the stage they would be',
#  u'set down at once as some old Oriental band of brigands. They are,',
#  u'however, I am told, very harmless and rather wanting in natural',
#  u'self-assertion.',
#  u'',
#  u'It was on the dark side of twilight when we got to Bistritz, which is a',
#  u'very interesting old place. Being practically on the frontier--for the',
#  u'Borgo Pass leads from it into Bukovina--it has had a very stormy',
#  u'existence, and it certainly shows marks of it. Fifty years ago a series',
#  u'of great fires took place, which made terrible havoc on five separate',
#  u'occasions. At the very beginning of the seventeenth century it underwent',
#  u'a siege of three weeks and lost 13,000 people, the casualties of war',
#  u'proper being assisted by famine and disease.',
#  u'',
#  u'Count Dracula had directed me to go to the Golden Krone Hotel, which I',
#  u'found, to my great delight, to be thoroughly old-fashioned, for of',
#  u'course I wanted to see all I could of the ways of the country. I was',
#  u'evidently expected, for when I got near the door I faced a',
#  u'cheery-looking elderly woman in the usual peasant dress--white',
#  u'undergarment with long double apron, front, and back, of coloured stuff',
#  u'fitting almost too tight for modesty. When I came close she bowed and',
#  u'said, "The Herr Englishman?" "Yes," I said, "Jonathan Harker." She',
#  u'smiled, and gave some message to an elderly man in white shirt-sleeves,',
#  u'who had followed her to the door. He went, but immediately returned with',
#  u'a letter:--',
#  u'',
#  u'     "My Friend.--Welcome to the Carpathians. I am anxiously expecting',
#  u'     you. Sleep well to-night. At three to-morrow the diligence will',
#  u'     start for Bukovina; a place on it is kept for you. At the Borgo',
#  u'     Pass my carriage will await you and will bring you to me. I trust',
#  u'     that your journey from London has been a happy one, and that you',
#  u'     will enjoy your stay in my beautiful land.',
#  u'',
#  u'"Your friend,',
#  u'',
#  u'"DRACULA."',
#  u'',
#  u'',
#  u'_4 May._--I found that my landlord had got a letter from the Count,',
#  u'directing him to secure the best place on the coach for me; but on',
#  u'making inquiries as to details he seemed somewhat reticent, and',
#  u'pretended that he could not understand my German. This could not be',
#  u'true, because up to then he had understood it perfectly; at least, he',
#  u'answered my questions exactly as if he did. He and his wife, the old',
#  u'lady who had received me, looked at each other in a frightened sort of',
#  u'way. He mumbled out that the money had been sent in a letter, and that',
#  u'was all he knew. When I asked him if he knew Count Dracula, and could',
#  u'tell me anything of his castle, both he and his wife crossed themselves,',
#  u'and, saying that they knew nothing at all, simply refused to speak',
#  u'further. It was so near the time of starting that I had no time to ask',
#  u'any one else, for it was all very mysterious and not by any means',
#  u'comforting.',
#  u'',
#  u'Just before I was leaving, the old lady came up to my room and said in a',
#  u'very hysterical way:',
#  u'',
#  u'"Must you go? Oh! young Herr, must you go?" She was in such an excited',
#  u'state that she seemed to have lost her grip of what German she knew, and',
#  u'mixed it all up with some other language which I did not know at all. I',
#  u'was just able to follow her by asking many questions. When I told her',
#  u'that I must go at once, and that I was engaged on important business,',
#  u'she asked again:',
#  u'',
#  u'"Do you know what day it is?" I answered that it was the fourth of May.',
#  u'She shook her head as she said again:',
#  u'',
#  u'"Oh, yes! I know that! I know that, but do you know what day it is?" On',
#  u'my saying that I did not understand, she went on:',
#  u'',
#  u'"It is the eve of St. George\'s Day. Do you not know that to-night, when',
#  u'the clock strikes midnight, all the evil things in the world will have',
#  u'full sway? Do you know where you are going, and what you are going to?"',
#  u'She was in such evident distress that I tried to comfort her, but',
#  u'without effect. Finally she went down on her knees and implored me not',
#  u'to go; at least to wait a day or two before starting. It was all very',
#  u'ridiculous but I did not feel comfortable. However, there was business',
#  u'to be done, and I could allow nothing to interfere with it. I therefore',
#  u'tried to raise her up, and said, as gravely as I could, that I thanked',
#  u'her, but my duty was imperative, and that I must go. She then rose and',
#  u'dried her eyes, and taking a crucifix from her neck offered it to me. I',
#  u'did not know what to do, for, as an English Churchman, I have been',
#  u'taught to regard such things as in some measure idolatrous, and yet it',
#  u'seemed so ungracious to refuse an old lady meaning so well and in such a',
#  u'state of mind. She saw, I suppose, the doubt in my face, for she put the',
#  u'rosary round my neck, and said, "For your mother\'s sake," and went out',
#  u'of the room. I am writing up this part of the diary whilst I am waiting',
#  u'for the coach, which is, of course, late; and the crucifix is still',
#  u"round my neck. Whether it is the old lady's fear, or the many ghostly",
#  u'traditions of this place, or the crucifix itself, I do not know, but I',
#  u'am not feeling nearly as easy in my mind as usual. If this book should',
#  u'ever reach Mina before I do, let it bring my good-bye. Here comes the',
#  u'coach!',
#  u'',
#  u'       *       *       *       *       *',
#  u'',
#  u'_5 May. The Castle._--The grey of the morning has passed, and the sun is',
#  u'high over the distant horizon, which seems jagged, whether with trees or',
#  u'hills I know not, for it is so far off that big things and little are',
#  u'mixed. I am not sleepy, and, as I am not to be called till I awake,',
#  u'naturally I write till sleep comes. There are many odd things to put',
#  u'down, and, lest who reads them may fancy that I dined too well before I',
#  u'left Bistritz, let me put down my dinner exactly. I dined on what they',
#  u'called "robber steak"--bits of bacon, onion, and beef, seasoned with red',
#  u'pepper, and strung on sticks and roasted over the fire, in the simple',
#  u"style of the London cat's meat! The wine was Golden Mediasch, which",
#  u'produces a queer sting on the tongue, which is, however, not',
#  u'disagreeable. I had only a couple of glasses of this, and nothing else.',
#  u'',
#  u'When I got on the coach the driver had not taken his seat, and I saw him',
#  u'talking with the landlady. They were evidently talking of me, for every',
#  u'now and then they looked at me, and some of the people who were sitting',
#  u'on the bench outside the door--which they call by a name meaning',
#  u'"word-bearer"--came and listened, and then looked at me, most of them',
#  u'pityingly. I could hear a lot of words often repeated, queer words, for',
#  u'there were many nationalities in the crowd; so I quietly got my polyglot',
#  u'dictionary from my bag and looked them out. I must say they were not',
#  u'cheering to me, for amongst them were "Ordog"--Satan, "pokol"--hell,',
#  u'"stregoica"--witch, "vrolok" and "vlkoslak"--both of which mean the same',
#  u'thing, one being Slovak and the other Servian for something that is',
#  u'either were-wolf or vampire. (_Mem._, I must ask the Count about these',
#  u'superstitions)',
#  u'',
#  u'When we started, the crowd round the inn door, which had by this time',
#  u'swelled to a considerable size, all made the sign of the cross and',
#  u'pointed two fingers towards me. With some difficulty I got a',
#  u'fellow-passenger to tell me what they meant; he would not answer at',
#  u'first, but on learning that I was English, he explained that it was a',
#  u'charm or guard against the evil eye. This was not very pleasant for me,',
#  u'just starting for an unknown place to meet an unknown man; but every one',
#  u'seemed so kind-hearted, and so sorrowful, and so sympathetic that I',
#  u'could not but be touched. I shall never forget the last glimpse which I',
#  u'had of the inn-yard and its crowd of picturesque figures, all crossing',
#  u'themselves, as they stood round the wide archway, with its background of',
#  u'rich foliage of oleander and orange trees in green tubs clustered in the',
#  u'centre of the yard. Then our driver, whose wide linen drawers covered',
#  u'the whole front of the box-seat--"gotza" they call them--cracked his big',
#  u'whip over his four small horses, which ran abreast, and we set off on',
#  u'our journey.',
#  u'',
#  u'I soon lost sight and recollection of ghostly fears in the beauty of the',
#  u'scene as we drove along, although had I known the language, or rather',
#  u'languages, which my fellow-passengers were speaking, I might not have',
#  u'been able to throw them off so easily. Before us lay a green sloping',
#  u'land full of forests and woods, with here and there steep hills, crowned',
#  u'with clumps of trees or with farmhouses, the blank gable end to the',
#  u'road. There was everywhere a bewildering mass of fruit blossom--apple,',
#  u'plum, pear, cherry; and as we drove by I could see the green grass under',
#  u'the trees spangled with the fallen petals. In and out amongst these',
#  u'green hills of what they call here the "Mittel Land" ran the road,',
#  u'losing itself as it swept round the grassy curve, or was shut out by the',
#  u'straggling ends of pine woods, which here and there ran down the',
#  u'hillsides like tongues of flame. The road was rugged, but still we',
#  u'seemed to fly over it with a feverish haste. I could not understand then',
#  u'what the haste meant, but the driver was evidently bent on losing no',
#  u'time in reaching Borgo Prund. I was told that this road is in summertime',
#  u'excellent, but that it had not yet been put in order after the winter',
#  u'snows. In this respect it is different from the general run of roads in',
#  u'the Carpathians, for it is an old tradition that they are not to be kept',
#  u'in too good order. Of old the Hospadars would not repair them, lest the',
#  u'Turk should think that they were preparing to bring in foreign troops,',
#  u'and so hasten the war which was always really at loading point.',
#  u'',
#  u'Beyond the green swelling hills of the Mittel Land rose mighty slopes',
#  u'of forest up to the lofty steeps of the Carpathians themselves. Right',
#  u'and left of us they towered, with the afternoon sun falling full upon',
#  u'them and bringing out all the glorious colours of this beautiful range,',
#  u'deep blue and purple in the shadows of the peaks, green and brown where',
#  u'grass and rock mingled, and an endless perspective of jagged rock and',
#  u'pointed crags, till these were themselves lost in the distance, where',
#  u'the snowy peaks rose grandly. Here and there seemed mighty rifts in the',
#  u'mountains, through which, as the sun began to sink, we saw now and again',
#  u'the white gleam of falling water. One of my companions touched my arm as',
#  u'we swept round the base of a hill and opened up the lofty, snow-covered',
#  u'peak of a mountain, which seemed, as we wound on our serpentine way, to',
#  u'be right before us:--',
#  u'',
#  u'"Look! Isten szek!"--"God\'s seat!"--and he crossed himself reverently.',
#  u'',
#  u'As we wound on our endless way, and the sun sank lower and lower behind',
#  u'us, the shadows of the evening began to creep round us. This was',
#  u'emphasised by the fact that the snowy mountain-top still held the',
#  u'sunset, and seemed to glow out with a delicate cool pink. Here and there',
#  u'we passed Cszeks and Slovaks, all in picturesque attire, but I noticed',
#  u'that goitre was painfully prevalent. By the roadside were many crosses,',
#  u'and as we swept by, my companions all crossed themselves. Here and there',
#  u'was a peasant man or woman kneeling before a shrine, who did not even',
#  u'turn round as we approached, but seemed in the self-surrender of',
#  u'devotion to have neither eyes nor ears for the outer world. There were',
#  u'many things new to me: for instance, hay-ricks in the trees, and here',
#  u'and there very beautiful masses of weeping birch, their white stems',
#  u'shining like silver through the delicate green of the leaves. Now and',
#  u"again we passed a leiter-wagon--the ordinary peasant's cart--with its",
#  u'long, snake-like vertebra, calculated to suit the inequalities of the',
#  u'road. On this were sure to be seated quite a group of home-coming',
#  u'peasants, the Cszeks with their white, and the Slovaks with their',
#  u'coloured, sheepskins, the latter carrying lance-fashion their long',
#  u'staves, with axe at end. As the evening fell it began to get very cold,',
#  u'and the growing twilight seemed to merge into one dark mistiness the',
#  u'gloom of the trees, oak, beech, and pine, though in the valleys which',
#  u'ran deep between the spurs of the hills, as we ascended through the',
#  u'Pass, the dark firs stood out here and there against the background of',
#  u'late-lying snow. Sometimes, as the road was cut through the pine woods',
#  u'that seemed in the darkness to be closing down upon us, great masses of',
#  u'greyness, which here and there bestrewed the trees, produced a',
#  u'peculiarly weird and solemn effect, which carried on the thoughts and',
#  u'grim fancies engendered earlier in the evening, when the falling sunset',
#  u'threw into strange relief the ghost-like clouds which amongst the',
#  u'Carpathians seem to wind ceaselessly through the valleys. Sometimes the',
#  u"hills were so steep that, despite our driver's haste, the horses could",
#  u'only go slowly. I wished to get down and walk up them, as we do at home,',
#  u'but the driver would not hear of it. "No, no," he said; "you must not',
#  u'walk here; the dogs are too fierce"; and then he added, with what he',
#  u'evidently meant for grim pleasantry--for he looked round to catch the',
#  u'approving smile of the rest--"and you may have enough of such matters',
#  u'before you go to sleep." The only stop he would make was a moment\'s',
#  u'pause to light his lamps.',
#  u'',
#  u'When it grew dark there seemed to be some excitement amongst the',
#  u'passengers, and they kept speaking to him, one after the other, as',
#  u'though urging him to further speed. He lashed the horses unmercifully',
#  u'with his long whip, and with wild cries of encouragement urged them on',
#  u'to further exertions. Then through the darkness I could see a sort of',
#  u'patch of grey light ahead of us, as though there were a cleft in the',
#  u'hills. The excitement of the passengers grew greater; the crazy coach',
#  u'rocked on its great leather springs, and swayed like a boat tossed on a',
#  u'stormy sea. I had to hold on. The road grew more level, and we appeared',
#  u'to fly along. Then the mountains seemed to come nearer to us on each',
#  u'side and to frown down upon us; we were entering on the Borgo Pass. One',
#  u'by one several of the passengers offered me gifts, which they pressed',
#  u'upon me with an earnestness which would take no denial; these were',
#  u'certainly of an odd and varied kind, but each was given in simple good',
#  u'faith, with a kindly word, and a blessing, and that strange mixture of',
#  u'fear-meaning movements which I had seen outside the hotel at',
#  u'Bistritz--the sign of the cross and the guard against the evil eye.',
#  u'Then, as we flew along, the driver leaned forward, and on each side the',
#  u'passengers, craning over the edge of the coach, peered eagerly into the',
#  u'darkness. It was evident that something very exciting was either',
#  u'happening or expected, but though I asked each passenger, no one would',
#  u'give me the slightest explanation. This state of excitement kept on for',
#  u'some little time; and at last we saw before us the Pass opening out on',
#  u'the eastern side. There were dark, rolling clouds overhead, and in the',
#  u'air the heavy, oppressive sense of thunder. It seemed as though the',
#  u'mountain range had separated two atmospheres, and that now we had got',
#  u'into the thunderous one. I was now myself looking out for the conveyance',
#  u'which was to take me to the Count. Each moment I expected to see the',
#  u'glare of lamps through the blackness; but all was dark. The only light',
#  u'was the flickering rays of our own lamps, in which the steam from our',
#  u'hard-driven horses rose in a white cloud. We could see now the sandy',
#  u'road lying white before us, but there was on it no sign of a vehicle.',
#  u'The passengers drew back with a sigh of gladness, which seemed to mock',
#  u'my own disappointment. I was already thinking what I had best do, when',
#  u'the driver, looking at his watch, said to the others something which I',
#  u'could hardly hear, it was spoken so quietly and in so low a tone; I',
#  u'thought it was "An hour less than the time." Then turning to me, he said',
#  u'in German worse than my own:--',
#  u'',
#  u'"There is no carriage here. The Herr is not expected after all. He will',
#  u'now come on to Bukovina, and return to-morrow or the next day; better',
#  u'the next day." Whilst he was speaking the horses began to neigh and',
#  u'snort and plunge wildly, so that the driver had to hold them up. Then,',
#  u'amongst a chorus of screams from the peasants and a universal crossing',
#  u'of themselves, a cal\xe8che, with four horses, drove up behind us, overtook',
#  u'us, and drew up beside the coach. I could see from the flash of our',
#  u'lamps, as the rays fell on them, that the horses were coal-black and',
#  u'splendid animals. They were driven by a tall man, with a long brown',
#  u'beard and a great black hat, which seemed to hide his face from us. I',
#  u'could only see the gleam of a pair of very bright eyes, which seemed red',
#  u'in the lamplight, as he turned to us. He said to the driver:--',
#  u'',
#  u'"You are early to-night, my friend." The man stammered in reply:--',
#  u'',
#  u'"The English Herr was in a hurry," to which the stranger replied:--',
#  u'',
#  u'"That is why, I suppose, you wished him to go on to Bukovina. You cannot',
#  u'deceive me, my friend; I know too much, and my horses are swift." As he',
#  u'spoke he smiled, and the lamplight fell on a hard-looking mouth, with',
#  u'very red lips and sharp-looking teeth, as white as ivory. One of my',
#  u'companions whispered to another the line from Burger\'s "Lenore":--',
#  u'',
#  u'    "Denn die Todten reiten schnell"--',
#  u'    ("For the dead travel fast.")',
#  u'',
#  u'The strange driver evidently heard the words, for he looked up with a',
#  u'gleaming smile. The passenger turned his face away, at the same time',
#  u'putting out his two fingers and crossing himself. "Give me the Herr\'s',
#  u'luggage," said the driver; and with exceeding alacrity my bags were',
#  u'handed out and put in the cal\xe8che. Then I descended from the side of the',
#  u'coach, as the cal\xe8che was close alongside, the driver helping me with a',
#  u'hand which caught my arm in a grip of steel; his strength must have been',
#  u'prodigious. Without a word he shook his reins, the horses turned, and we',
#  u'swept into the darkness of the Pass. As I looked back I saw the steam',
#  u'from the horses of the coach by the light of the lamps, and projected',
#  u'against it the figures of my late companions crossing themselves. Then',
#  u'the driver cracked his whip and called to his horses, and off they swept',
#  u'on their way to Bukovina. As they sank into the darkness I felt a',
#  u'strange chill, and a lonely feeling came over me; but a cloak was thrown',
#  u'over my shoulders, and a rug across my knees, and the driver said in',
#  u'excellent German:--',
#  u'',
#  u'"The night is chill, mein Herr, and my master the Count bade me take all',
#  u'care of you. There is a flask of slivovitz (the plum brandy of the',
#  u'country) underneath the seat, if you should require it." I did not take',
#  u'any, but it was a comfort to know it was there all the same. I felt a',
#  u'little strangely, and not a little frightened. I think had there been',
#  u'any alternative I should have taken it, instead of prosecuting that',
#  u'unknown night journey. The carriage went at a hard pace straight along,',
#  u'then we made a complete turn and went along another straight road. It',
#  u'seemed to me that we were simply going over and over the same ground',
#  u'again; and so I took note of some salient point, and found that this was',
#  u'so. I would have liked to have asked the driver what this all meant, but',
#  u'I really feared to do so, for I thought that, placed as I was, any',
#  u'protest would have had no effect in case there had been an intention to',
#  u'delay. By-and-by, however, as I was curious to know how time was',
#  u'passing, I struck a match, and by its flame looked at my watch; it was',
#  u'within a few minutes of midnight. This gave me a sort of shock, for I',
#  u'suppose the general superstition about midnight was increased by my',
#  u'recent experiences. I waited with a sick feeling of suspense.',
#  u'',
#  u'Then a dog began to howl somewhere in a farmhouse far down the road--a',
#  u'long, agonised wailing, as if from fear. The sound was taken up by',
#  u'another dog, and then another and another, till, borne on the wind which',
#  u'now sighed softly through the Pass, a wild howling began, which seemed',
#  u'to come from all over the country, as far as the imagination could grasp',
#  u'it through the gloom of the night. At the first howl the horses began to',
#  u'strain and rear, but the driver spoke to them soothingly, and they',
#  u'quieted down, but shivered and sweated as though after a runaway from',
#  u'sudden fright. Then, far off in the distance, from the mountains on each',
#  u'side of us began a louder and a sharper howling--that of wolves--which',
#  u'affected both the horses and myself in the same way--for I was minded to',
#  u'jump from the cal\xe8che and run, whilst they reared again and plunged',
#  u'madly, so that the driver had to use all his great strength to keep them',
#  u'from bolting. In a few minutes, however, my own ears got accustomed to',
#  u'the sound, and the horses so far became quiet that the driver was able',
#  u'to descend and to stand before them. He petted and soothed them, and',
#  u'whispered something in their ears, as I have heard of horse-tamers',
#  u'doing, and with extraordinary effect, for under his caresses they became',
#  u'quite manageable again, though they still trembled. The driver again',
#  u'took his seat, and shaking his reins, started off at a great pace. This',
#  u'time, after going to the far side of the Pass, he suddenly turned down a',
#  u'narrow roadway which ran sharply to the right.',
#  u'',
#  u'Soon we were hemmed in with trees, which in places arched right over the',
#  u'roadway till we passed as through a tunnel; and again great frowning',
#  u'rocks guarded us boldly on either side. Though we were in shelter, we',
#  u'could hear the rising wind, for it moaned and whistled through the',
#  u'rocks, and the branches of the trees crashed together as we swept along.',
#  u'It grew colder and colder still, and fine, powdery snow began to fall,',
#  u'so that soon we and all around us were covered with a white blanket. The',
#  u'keen wind still carried the howling of the dogs, though this grew',
#  u'fainter as we went on our way. The baying of the wolves sounded nearer',
#  u'and nearer, as though they were closing round on us from every side. I',
#  u'grew dreadfully afraid, and the horses shared my fear. The driver,',
#  u'however, was not in the least disturbed; he kept turning his head to',
#  u'left and right, but I could not see anything through the darkness.',
#  u'',
#  u'Suddenly, away on our left, I saw a faint flickering blue flame. The',
#  u'driver saw it at the same moment; he at once checked the horses, and,',
#  u'jumping to the ground, disappeared into the darkness. I did not know',
#  u'what to do, the less as the howling of the wolves grew closer; but while',
#  u'I wondered the driver suddenly appeared again, and without a word took',
#  u'his seat, and we resumed our journey. I think I must have fallen asleep',
#  u'and kept dreaming of the incident, for it seemed to be repeated',
#  u'endlessly, and now looking back, it is like a sort of awful nightmare.',
#  u'Once the flame appeared so near the road, that even in the darkness',
#  u"around us I could watch the driver's motions. He went rapidly to where",
#  u'the blue flame arose--it must have been very faint, for it did not seem',
#  u'to illumine the place around it at all--and gathering a few stones,',
#  u'formed them into some device. Once there appeared a strange optical',
#  u'effect: when he stood between me and the flame he did not obstruct it,',
#  u'for I could see its ghostly flicker all the same. This startled me, but',
#  u'as the effect was only momentary, I took it that my eyes deceived me',
#  u'straining through the darkness. Then for a time there were no blue',
#  u'flames, and we sped onwards through the gloom, with the howling of the',
#  u'wolves around us, as though they were following in a moving circle.',
#  u'',
#  u'At last there came a time when the driver went further afield than he',
#  u'had yet gone, and during his absence, the horses began to tremble worse',
#  u'than ever and to snort and scream with fright. I could not see any cause',
#  u'for it, for the howling of the wolves had ceased altogether; but just',
#  u'then the moon, sailing through the black clouds, appeared behind the',
#  u'jagged crest of a beetling, pine-clad rock, and by its light I saw',
#  u'around us a ring of wolves, with white teeth and lolling red tongues,',
#  u'with long, sinewy limbs and shaggy hair. They were a hundred times more',
#  u'terrible in the grim silence which held them than even when they howled.',
#  u'For myself, I felt a sort of paralysis of fear. It is only when a man',
#  u'feels himself face to face with such horrors that he can understand',
#  u'their true import.',
#  u'',
#  u'All at once the wolves began to howl as though the moonlight had had',
#  u'some peculiar effect on them. The horses jumped about and reared, and',
#  u'looked helplessly round with eyes that rolled in a way painful to see;',
#  u'but the living ring of terror encompassed them on every side; and they',
#  u'had perforce to remain within it. I called to the coachman to come, for',
#  u'it seemed to me that our only chance was to try to break out through the',
#  u'ring and to aid his approach. I shouted and beat the side of the',
#  u'cal\xe8che, hoping by the noise to scare the wolves from that side, so as',
#  u'to give him a chance of reaching the trap. How he came there, I know',
#  u'not, but I heard his voice raised in a tone of imperious command, and',
#  u'looking towards the sound, saw him stand in the roadway. As he swept his',
#  u'long arms, as though brushing aside some impalpable obstacle, the wolves',
#  u'fell back and back further still. Just then a heavy cloud passed across',
#  u'the face of the moon, so that we were again in darkness.',
#  u'',
#  u'When I could see again the driver was climbing into the cal\xe8che, and the',
#  u'wolves had disappeared. This was all so strange and uncanny that a',
#  u'dreadful fear came upon me, and I was afraid to speak or move. The time',
#  u'seemed interminable as we swept on our way, now in almost complete',
#  u'darkness, for the rolling clouds obscured the moon. We kept on',
#  u'ascending, with occasional periods of quick descent, but in the main',
#  u'always ascending. Suddenly, I became conscious of the fact that the',
#  u'driver was in the act of pulling up the horses in the courtyard of a',
#  u'vast ruined castle, from whose tall black windows came no ray of light,',
#  u'and whose broken battlements showed a jagged line against the moonlit',
#  u'sky.',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'CHAPTER II',
#  u'',
#  u"JONATHAN HARKER'S JOURNAL--_continued_",
#  u'',
#  u'',
#  u'_5 May._--I must have been asleep, for certainly if I had been fully',
#  u'awake I must have noticed the approach of such a remarkable place. In',
#  u'the gloom the courtyard looked of considerable size, and as several dark',
#  u'ways led from it under great round arches, it perhaps seemed bigger than',
#  u'it really is. I have not yet been able to see it by daylight.',
#  u'',
#  u'When the cal\xe8che stopped, the driver jumped down and held out his hand',
#  u'to assist me to alight. Again I could not but notice his prodigious',
#  u'strength. His hand actually seemed like a steel vice that could have',
#  u'crushed mine if he had chosen. Then he took out my traps, and placed',
#  u'them on the ground beside me as I stood close to a great door, old and',
#  u'studded with large iron nails, and set in a projecting doorway of',
#  u'massive stone. I could see even in the dim light that the stone was',
#  u'massively carved, but that the carving had been much worn by time and',
#  u'weather. As I stood, the driver jumped again into his seat and shook the',
#  u'reins; the horses started forward, and trap and all disappeared down one',
#  u'of the dark openings.',
#  u'',
#  u'I stood in silence where I was, for I did not know what to do. Of bell',
#  u'or knocker there was no sign; through these frowning walls and dark',
#  u'window openings it was not likely that my voice could penetrate. The',
#  u'time I waited seemed endless, and I felt doubts and fears crowding upon',
#  u'me. What sort of place had I come to, and among what kind of people?',
#  u'What sort of grim adventure was it on which I had embarked? Was this a',
#  u"customary incident in the life of a solicitor's clerk sent out to",
#  u"explain the purchase of a London estate to a foreigner? Solicitor's",
#  u'clerk! Mina would not like that. Solicitor--for just before leaving',
#  u'London I got word that my examination was successful; and I am now a',
#  u'full-blown solicitor! I began to rub my eyes and pinch myself to see if',
#  u'I were awake. It all seemed like a horrible nightmare to me, and I',
#  u'expected that I should suddenly awake, and find myself at home, with',
#  u'the dawn struggling in through the windows, as I had now and again felt',
#  u'in the morning after a day of overwork. But my flesh answered the',
#  u'pinching test, and my eyes were not to be deceived. I was indeed awake',
#  u'and among the Carpathians. All I could do now was to be patient, and to',
#  u'wait the coming of the morning.',
#  u'',
#  u'Just as I had come to this conclusion I heard a heavy step approaching',
#  u'behind the great door, and saw through the chinks the gleam of a coming',
#  u'light. Then there was the sound of rattling chains and the clanking of',
#  u'massive bolts drawn back. A key was turned with the loud grating noise',
#  u'of long disuse, and the great door swung back.',
#  u'',
#  u'Within, stood a tall old man, clean shaven save for a long white',
#  u'moustache, and clad in black from head to foot, without a single speck',
#  u'of colour about him anywhere. He held in his hand an antique silver',
#  u'lamp, in which the flame burned without chimney or globe of any kind,',
#  u'throwing long quivering shadows as it flickered in the draught of the',
#  u'open door. The old man motioned me in with his right hand with a courtly',
#  u'gesture, saying in excellent English, but with a strange intonation:--',
#  u'',
#  u'"Welcome to my house! Enter freely and of your own will!" He made no',
#  u'motion of stepping to meet me, but stood like a statue, as though his',
#  u'gesture of welcome had fixed him into stone. The instant, however, that',
#  u'I had stepped over the threshold, he moved impulsively forward, and',
#  u'holding out his hand grasped mine with a strength which made me wince,',
#  u'an effect which was not lessened by the fact that it seemed as cold as',
#  u'ice--more like the hand of a dead than a living man. Again he said:--',
#  u'',
#  u'"Welcome to my house. Come freely. Go safely; and leave something of the',
#  u'happiness you bring!" The strength of the handshake was so much akin to',
#  u'that which I had noticed in the driver, whose face I had not seen, that',
#  u'for a moment I doubted if it were not the same person to whom I was',
#  u'speaking; so to make sure, I said interrogatively:--',
#  u'',
#  u'"Count Dracula?" He bowed in a courtly way as he replied:--',
#  u'',
#  u'"I am Dracula; and I bid you welcome, Mr. Harker, to my house. Come in;',
#  u'the night air is chill, and you must need to eat and rest." As he was',
#  u'speaking, he put the lamp on a bracket on the wall, and stepping out,',
#  u'took my luggage; he had carried it in before I could forestall him. I',
#  u'protested but he insisted:--',
#  u'',
#  u'"Nay, sir, you are my guest. It is late, and my people are not',
#  u'available. Let me see to your comfort myself." He insisted on carrying',
#  u'my traps along the passage, and then up a great winding stair, and',
#  u'along another great passage, on whose stone floor our steps rang',
#  u'heavily. At the end of this he threw open a heavy door, and I rejoiced',
#  u'to see within a well-lit room in which a table was spread for supper,',
#  u'and on whose mighty hearth a great fire of logs, freshly replenished,',
#  u'flamed and flared.',
#  u'',
#  u'The Count halted, putting down my bags, closed the door, and crossing',
#  u'the room, opened another door, which led into a small octagonal room lit',
#  u'by a single lamp, and seemingly without a window of any sort. Passing',
#  u'through this, he opened another door, and motioned me to enter. It was a',
#  u'welcome sight; for here was a great bedroom well lighted and warmed with',
#  u'another log fire,--also added to but lately, for the top logs were',
#  u'fresh--which sent a hollow roar up the wide chimney. The Count himself',
#  u'left my luggage inside and withdrew, saying, before he closed the',
#  u'door:--',
#  u'',
#  u'"You will need, after your journey, to refresh yourself by making your',
#  u'toilet. I trust you will find all you wish. When you are ready, come',
#  u'into the other room, where you will find your supper prepared."',
#  u'',
#  u"The light and warmth and the Count's courteous welcome seemed to have",
#  u'dissipated all my doubts and fears. Having then reached my normal state,',
#  u'I discovered that I was half famished with hunger; so making a hasty',
#  u'toilet, I went into the other room.',
#  u'',
#  u'I found supper already laid out. My host, who stood on one side of the',
#  u'great fireplace, leaning against the stonework, made a graceful wave of',
#  u'his hand to the table, and said:--',
#  u'',
#  u'"I pray you, be seated and sup how you please. You will, I trust, excuse',
#  u'me that I do not join you; but I have dined already, and I do not sup."',
#  u'',
#  u'I handed to him the sealed letter which Mr. Hawkins had entrusted to me.',
#  u'He opened it and read it gravely; then, with a charming smile, he handed',
#  u'it to me to read. One passage of it, at least, gave me a thrill of',
#  u'pleasure.',
#  u'',
#  u'"I must regret that an attack of gout, from which malady I am a constant',
#  u'sufferer, forbids absolutely any travelling on my part for some time to',
#  u'come; but I am happy to say I can send a sufficient substitute, one in',
#  u'whom I have every possible confidence. He is a young man, full of energy',
#  u'and talent in his own way, and of a very faithful disposition. He is',
#  u'discreet and silent, and has grown into manhood in my service. He shall',
#  u'be ready to attend on you when you will during his stay, and shall take',
#  u'your instructions in all matters."',
#  u'',
#  u'The Count himself came forward and took off the cover of a dish, and I',
#  u'fell to at once on an excellent roast chicken. This, with some cheese',
#  u'and a salad and a bottle of old Tokay, of which I had two glasses, was',
#  u'my supper. During the time I was eating it the Count asked me many',
#  u'questions as to my journey, and I told him by degrees all I had',
#  u'experienced.',
#  u'',
#  u"By this time I had finished my supper, and by my host's desire had drawn",
#  u'up a chair by the fire and begun to smoke a cigar which he offered me,',
#  u'at the same time excusing himself that he did not smoke. I had now an',
#  u'opportunity of observing him, and found him of a very marked',
#  u'physiognomy.',
#  u'',
#  u'His face was a strong--a very strong--aquiline, with high bridge of the',
#  u'thin nose and peculiarly arched nostrils; with lofty domed forehead, and',
#  u'hair growing scantily round the temples but profusely elsewhere. His',
#  u'eyebrows were very massive, almost meeting over the nose, and with bushy',
#  u'hair that seemed to curl in its own profusion. The mouth, so far as I',
#  u'could see it under the heavy moustache, was fixed and rather',
#  u'cruel-looking, with peculiarly sharp white teeth; these protruded over',
#  u'the lips, whose remarkable ruddiness showed astonishing vitality in a',
#  u'man of his years. For the rest, his ears were pale, and at the tops',
#  u'extremely pointed; the chin was broad and strong, and the cheeks firm',
#  u'though thin. The general effect was one of extraordinary pallor.',
#  u'',
#  u'Hitherto I had noticed the backs of his hands as they lay on his knees',
#  u'in the firelight, and they had seemed rather white and fine; but seeing',
#  u'them now close to me, I could not but notice that they were rather',
#  u'coarse--broad, with squat fingers. Strange to say, there were hairs in',
#  u'the centre of the palm. The nails were long and fine, and cut to a sharp',
#  u'point. As the Count leaned over me and his hands touched me, I could not',
#  u'repress a shudder. It may have been that his breath was rank, but a',
#  u'horrible feeling of nausea came over me, which, do what I would, I could',
#  u'not conceal. The Count, evidently noticing it, drew back; and with a',
#  u'grim sort of smile, which showed more than he had yet done his',
#  u'protuberant teeth, sat himself down again on his own side of the',
#  u'fireplace. We were both silent for a while; and as I looked towards the',
#  u'window I saw the first dim streak of the coming dawn. There seemed a',
#  u'strange stillness over everything; but as I listened I heard as if from',
#  u"down below in the valley the howling of many wolves. The Count's eyes",
#  u'gleamed, and he said:--',
#  u'',
#  u'"Listen to them--the children of the night. What music they make!"',
#  u'Seeing, I suppose, some expression in my face strange to him, he',
#  u'added:--',
#  u'',
#  u'"Ah, sir, you dwellers in the city cannot enter into the feelings of the',
#  u'hunter." Then he rose and said:--',
#  u'',
#  u'"But you must be tired. Your bedroom is all ready, and to-morrow you',
#  u'shall sleep as late as you will. I have to be away till the afternoon;',
#  u'so sleep well and dream well!" With a courteous bow, he opened for me',
#  u'himself the door to the octagonal room, and I entered my bedroom....',
#  u'',
#  u'I am all in a sea of wonders. I doubt; I fear; I think strange things,',
#  u'which I dare not confess to my own soul. God keep me, if only for the',
#  u'sake of those dear to me!',
#  u'',
#  u'       *       *       *       *       *',
#  u'',
#  u'_7 May._--It is again early morning, but I have rested and enjoyed the',
#  u'last twenty-four hours. I slept till late in the day, and awoke of my',
#  u'own accord. When I had dressed myself I went into the room where we had',
#  u'supped, and found a cold breakfast laid out, with coffee kept hot by the',
#  u'pot being placed on the hearth. There was a card on the table, on which',
#  u'was written:--',
#  u'',
#  u'"I have to be absent for a while. Do not wait for me.--D." I set to and',
#  u'enjoyed a hearty meal. When I had done, I looked for a bell, so that I',
#  u'might let the servants know I had finished; but I could not find one.',
#  u'There are certainly odd deficiencies in the house, considering the',
#  u'extraordinary evidences of wealth which are round me. The table service',
#  u'is of gold, and so beautifully wrought that it must be of immense value.',
#  u'The curtains and upholstery of the chairs and sofas and the hangings of',
#  u'my bed are of the costliest and most beautiful fabrics, and must have',
#  u'been of fabulous value when they were made, for they are centuries old,',
#  u'though in excellent order. I saw something like them in Hampton Court,',
#  u'but there they were worn and frayed and moth-eaten. But still in none of',
#  u'the rooms is there a mirror. There is not even a toilet glass on my',
#  u'table, and I had to get the little shaving glass from my bag before I',
#  u'could either shave or brush my hair. I have not yet seen a servant',
#  u'anywhere, or heard a sound near the castle except the howling of wolves.',
#  u'Some time after I had finished my meal--I do not know whether to call it',
#  u"breakfast or dinner, for it was between five and six o'clock when I had",
#  u'it--I looked about for something to read, for I did not like to go about',
#  u"the castle until I had asked the Count's permission. There was",
#  u'absolutely nothing in the room, book, newspaper, or even writing',
#  u'materials; so I opened another door in the room and found a sort of',
#  u'library. The door opposite mine I tried, but found it locked.',
#  u'',
#  u'In the library I found, to my great delight, a vast number of English',
#  u'books, whole shelves full of them, and bound volumes of magazines and',
#  u'newspapers. A table in the centre was littered with English magazines',
#  u'and newspapers, though none of them were of very recent date. The books',
#  u'were of the most varied kind--history, geography, politics, political',
#  u'economy, botany, geology, law--all relating to England and English life',
#  u'and customs and manners. There were even such books of reference as the',
#  u'London Directory, the "Red" and "Blue" books, Whitaker\'s Almanac, the',
#  u'Army and Navy Lists, and--it somehow gladdened my heart to see it--the',
#  u'Law List.',
#  u'',
#  u'Whilst I was looking at the books, the door opened, and the Count',
#  u'entered. He saluted me in a hearty way, and hoped that I had had a good',
#  u"night's rest. Then he went on:--",
#  u'',
#  u'"I am glad you found your way in here, for I am sure there is much that',
#  u'will interest you. These companions"--and he laid his hand on some of',
#  u'the books--"have been good friends to me, and for some years past, ever',
#  u'since I had the idea of going to London, have given me many, many hours',
#  u'of pleasure. Through them I have come to know your great England; and to',
#  u'know her is to love her. I long to go through the crowded streets of',
#  u'your mighty London, to be in the midst of the whirl and rush of',
#  u'humanity, to share its life, its change, its death, and all that makes',
#  u'it what it is. But alas! as yet I only know your tongue through books.',
#  u'To you, my friend, I look that I know it to speak."',
#  u'',
#  u'"But, Count," I said, "you know and speak English thoroughly!" He bowed',
#  u'gravely.',
#  u'',
#  u'"I thank you, my friend, for your all too-flattering estimate, but yet I',
#  u'fear that I am but a little way on the road I would travel. True, I know',
#  u'the grammar and the words, but yet I know not how to speak them."',
#  u'',
#  u'"Indeed," I said, "you speak excellently."',
#  u'',
#  u'"Not so," he answered. "Well, I know that, did I move and speak in your',
#  u'London, none there are who would not know me for a stranger. That is not',
#  u'enough for me. Here I am noble; I am _boyar_; the common people know me,',
#  u'and I am master. But a stranger in a strange land, he is no one; men',
#  u'know him not--and to know not is to care not for. I am content if I am',
#  u'like the rest, so that no man stops if he see me, or pause in his',
#  u"speaking if he hear my words, 'Ha, ha! a stranger!' I have been so long",
#  u'master that I would be master still--or at least that none other should',
#  u'be master of me. You come to me not alone as agent of my friend Peter',
#  u'Hawkins, of Exeter, to tell me all about my new estate in London. You',
#  u'shall, I trust, rest here with me awhile, so that by our talking I may',
#  u'learn the English intonation; and I would that you tell me when I make',
#  u'error, even of the smallest, in my speaking. I am sorry that I had to be',
#  u'away so long to-day; but you will, I know, forgive one who has so many',
#  u'important affairs in hand."',
#  u'',
#  u'Of course I said all I could about being willing, and asked if I might',
#  u'come into that room when I chose. He answered: "Yes, certainly," and',
#  u'added:--',
#  u'',
#  u'"You may go anywhere you wish in the castle, except where the doors are',
#  u'locked, where of course you will not wish to go. There is reason that',
#  u'all things are as they are, and did you see with my eyes and know with',
#  u'my knowledge, you would perhaps better understand." I said I was sure of',
#  u'this, and then he went on:--',
#  u'',
#  u'"We are in Transylvania; and Transylvania is not England. Our ways are',
#  u'not your ways, and there shall be to you many strange things. Nay, from',
#  u'what you have told me of your experiences already, you know something of',
#  u'what strange things there may be."',
#  u'',
#  u'This led to much conversation; and as it was evident that he wanted to',
#  u"talk, if only for talking's sake, I asked him many questions regarding",
#  u'things that had already happened to me or come within my notice.',
#  u'Sometimes he sheered off the subject, or turned the conversation by',
#  u'pretending not to understand; but generally he answered all I asked most',
#  u'frankly. Then as time went on, and I had got somewhat bolder, I asked',
#  u'him of some of the strange things of the preceding night, as, for',
#  u'instance, why the coachman went to the places where he had seen the blue',
#  u'flames. He then explained to me that it was commonly believed that on a',
#  u'certain night of the year--last night, in fact, when all evil spirits',
#  u'are supposed to have unchecked sway--a blue flame is seen over any place',
#  u'where treasure has been concealed. "That treasure has been hidden," he',
#  u'went on, "in the region through which you came last night, there can be',
#  u'but little doubt; for it was the ground fought over for centuries by the',
#  u'Wallachian, the Saxon, and the Turk. Why, there is hardly a foot of soil',
#  u'in all this region that has not been enriched by the blood of men,',
#  u'patriots or invaders. In old days there were stirring times, when the',
#  ...]

# %% [markdown]
# With the RDD `data`, from the previous cell, execute a `flatMap()` for each line in the input and then convert it to lower case, remove the commas, split the words on a space and store in the RDD `words`

# %%
# Creating a RDD containing the words of the text

# We use flatMap to execute the required actions for each line of data and to "flatten" the result
words=data.flatMap(lambda line : line.lower().replace(',','').split(' '))

# We display the RDD words
words.collect()

# Comment : we observe a u before each string, this corresponds to the encoding of the word (unicode) 
# and can be useful for some symbols. Thus, we decided not to remove it.
# Out:
# [u'the',
#  u'project',
#  u'gutenberg',
#  u'ebook',
#  u'of',
#  u'dracula',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'',
#  u'this',
#  u'ebook',
#  u'is',
#  u'for',
#  u'the',
#  u'use',
#  u'of',
#  u'anyone',
#  u'anywhere',
#  u'at',
#  u'no',
#  u'cost',
#  u'and',
#  u'with',
#  u'almost',
#  u'no',
#  u'restrictions',
#  u'whatsoever.',
#  u'',
#  u'you',
#  u'may',
#  u'copy',
#  u'it',
#  u'give',
#  u'it',
#  u'away',
#  u'or',
#  u're-use',
#  u'it',
#  u'under',
#  u'the',
#  u'terms',
#  u'of',
#  u'the',
#  u'project',
#  u'gutenberg',
#  u'license',
#  u'included',
#  u'with',
#  u'this',
#  u'ebook',
#  u'or',
#  u'online',
#  u'at',
#  u'www.gutenberg.org/license',
#  u'',
#  u'',
#  u'title:',
#  u'dracula',
#  u'',
#  u'author:',
#  u'bram',
#  u'stoker',
#  u'',
#  u'release',
#  u'date:',
#  u'august',
#  u'16',
#  u'2013',
#  u'[ebook',
#  u'#345]',
#  u'',
#  u'language:',
#  u'english',
#  u'',
#  u'',
#  u'***',
#  u'start',
#  u'of',
#  u'this',
#  u'project',
#  u'gutenberg',
#  u'ebook',
#  u'dracula',
#  u'***',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'produced',
#  u'by',
#  u'chuck',
#  u'greif',
#  u'and',
#  u'the',
#  u'online',
#  u'distributed',
#  u'proofreading',
#  u'team',
#  u'at',
#  u'http://www.pgdp.net',
#  u'(this',
#  u'file',
#  u'was',
#  u'produced',
#  u'from',
#  u'images',
#  u'generously',
#  u'made',
#  u'available',
#  u'by',
#  u'the',
#  u'internet',
#  u'archive)',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'dracula',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'dracula',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'_by_',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'bram',
#  u'stoker',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'[illustration:',
#  u'colophon]',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'new',
#  u'york',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'grosset',
#  u'&',
#  u'dunlap',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'_publishers_',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'copyright',
#  u'1897',
#  u'in',
#  u'the',
#  u'united',
#  u'states',
#  u'of',
#  u'america',
#  u'according',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'to',
#  u'act',
#  u'of',
#  u'congress',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'[_all',
#  u'rights',
#  u'reserved._]',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'printed',
#  u'in',
#  u'the',
#  u'united',
#  u'states',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'at',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'the',
#  u'country',
#  u'life',
#  u'press',
#  u'garden',
#  u'city',
#  u'n.y.',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'to',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'my',
#  u'dear',
#  u'friend',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'hommy-beg',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'contents',
#  u'',
#  u'',
#  u'chapter',
#  u'i',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'page',
#  u'',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'1',
#  u'',
#  u'chapter',
#  u'ii',
#  u'',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'14',
#  u'',
#  u'chapter',
#  u'iii',
#  u'',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'26',
#  u'',
#  u'chapter',
#  u'iv',
#  u'',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'38',
#  u'',
#  u'chapter',
#  u'v',
#  u'',
#  u'letters--lucy',
#  u'and',
#  u'mina',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'51',
#  u'',
#  u'chapter',
#  u'vi',
#  u'',
#  u'mina',
#  u"murray's",
#  u'journal',
#  u'',
#  u'',
#  u'',
#  u'',
#  u'',
#  ...]

# %%
# Removing the empty rows (rows with only " u'' ") using the action filter

words=words.filter(lambda x: x is not u'')
words.collect()
# Out:
# [u'the',
#  u'project',
#  u'gutenberg',
#  u'ebook',
#  u'of',
#  u'dracula',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'this',
#  u'ebook',
#  u'is',
#  u'for',
#  u'the',
#  u'use',
#  u'of',
#  u'anyone',
#  u'anywhere',
#  u'at',
#  u'no',
#  u'cost',
#  u'and',
#  u'with',
#  u'almost',
#  u'no',
#  u'restrictions',
#  u'whatsoever.',
#  u'you',
#  u'may',
#  u'copy',
#  u'it',
#  u'give',
#  u'it',
#  u'away',
#  u'or',
#  u're-use',
#  u'it',
#  u'under',
#  u'the',
#  u'terms',
#  u'of',
#  u'the',
#  u'project',
#  u'gutenberg',
#  u'license',
#  u'included',
#  u'with',
#  u'this',
#  u'ebook',
#  u'or',
#  u'online',
#  u'at',
#  u'www.gutenberg.org/license',
#  u'title:',
#  u'dracula',
#  u'author:',
#  u'bram',
#  u'stoker',
#  u'release',
#  u'date:',
#  u'august',
#  u'16',
#  u'2013',
#  u'[ebook',
#  u'#345]',
#  u'language:',
#  u'english',
#  u'***',
#  u'start',
#  u'of',
#  u'this',
#  u'project',
#  u'gutenberg',
#  u'ebook',
#  u'dracula',
#  u'***',
#  u'produced',
#  u'by',
#  u'chuck',
#  u'greif',
#  u'and',
#  u'the',
#  u'online',
#  u'distributed',
#  u'proofreading',
#  u'team',
#  u'at',
#  u'http://www.pgdp.net',
#  u'(this',
#  u'file',
#  u'was',
#  u'produced',
#  u'from',
#  u'images',
#  u'generously',
#  u'made',
#  u'available',
#  u'by',
#  u'the',
#  u'internet',
#  u'archive)',
#  u'dracula',
#  u'dracula',
#  u'_by_',
#  u'bram',
#  u'stoker',
#  u'[illustration:',
#  u'colophon]',
#  u'new',
#  u'york',
#  u'grosset',
#  u'&',
#  u'dunlap',
#  u'_publishers_',
#  u'copyright',
#  u'1897',
#  u'in',
#  u'the',
#  u'united',
#  u'states',
#  u'of',
#  u'america',
#  u'according',
#  u'to',
#  u'act',
#  u'of',
#  u'congress',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'[_all',
#  u'rights',
#  u'reserved._]',
#  u'printed',
#  u'in',
#  u'the',
#  u'united',
#  u'states',
#  u'at',
#  u'the',
#  u'country',
#  u'life',
#  u'press',
#  u'garden',
#  u'city',
#  u'n.y.',
#  u'to',
#  u'my',
#  u'dear',
#  u'friend',
#  u'hommy-beg',
#  u'contents',
#  u'chapter',
#  u'i',
#  u'page',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'1',
#  u'chapter',
#  u'ii',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'14',
#  u'chapter',
#  u'iii',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'26',
#  u'chapter',
#  u'iv',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'38',
#  u'chapter',
#  u'v',
#  u'letters--lucy',
#  u'and',
#  u'mina',
#  u'51',
#  u'chapter',
#  u'vi',
#  u'mina',
#  u"murray's",
#  u'journal',
#  u'59',
#  u'chapter',
#  u'vii',
#  u'cutting',
#  u'from',
#  u'"the',
#  u'dailygraph"',
#  u'8',
#  u'august',
#  u'71',
#  u'chapter',
#  u'viii',
#  u'mina',
#  u"murray's",
#  u'journal',
#  u'84',
#  u'chapter',
#  u'ix',
#  u'mina',
#  u"murray's",
#  u'journal',
#  u'98',
#  u'chapter',
#  u'x',
#  u'mina',
#  u"murray's",
#  u'journal',
#  u'111',
#  u'chapter',
#  u'xi',
#  u'lucy',
#  u"westenra's",
#  u'diary',
#  u'124',
#  u'chapter',
#  u'xii',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'136',
#  u'chapter',
#  u'xiii',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'152',
#  u'chapter',
#  u'xiv',
#  u'mina',
#  u"harker's",
#  u'journal',
#  u'167',
#  u'chapter',
#  u'xv',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'181',
#  u'chapter',
#  u'xvi',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'194',
#  u'chapter',
#  u'xvii',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'204',
#  u'chapter',
#  u'xviii',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'216',
#  u'chapter',
#  u'xix',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'231',
#  u'chapter',
#  u'xx',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'243',
#  u'chapter',
#  u'xxi',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'256',
#  u'chapter',
#  u'xxii',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'269',
#  u'chapter',
#  u'xxiii',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'281',
#  u'chapter',
#  u'xxiv',
#  u'dr.',
#  u"seward's",
#  u'phonograph',
#  u'diary',
#  u'spoken',
#  u'by',
#  u'van',
#  u'helsing',
#  u'294',
#  u'chapter',
#  u'xxv',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'308',
#  u'chapter',
#  u'xxvi',
#  u'dr.',
#  u"seward's",
#  u'diary',
#  u'322',
#  u'chapter',
#  u'xxvii',
#  u'mina',
#  u"harker's",
#  u'journal',
#  u'338',
#  u'dracula',
#  u'chapter',
#  u'i',
#  u'jonathan',
#  u"harker's",
#  u'journal',
#  u'(_kept',
#  u'in',
#  u'shorthand._)',
#  u'_3',
#  u'may.',
#  u'bistritz._--left',
#  u'munich',
#  u'at',
#  u'8:35',
#  u'p.',
#  u'm.',
#  u'on',
#  u'1st',
#  u'may',
#  u'arriving',
#  u'at',
#  u'vienna',
#  u'early',
#  u'next',
#  u'morning;',
#  u'should',
#  u'have',
#  u'arrived',
#  u'at',
#  u'6:46',
#  u'but',
#  u'train',
#  u'was',
#  u'an',
#  u'hour',
#  u'late.',
#  u'buda-pesth',
#  u'seems',
#  u'a',
#  u'wonderful',
#  u'place',
#  u'from',
#  u'the',
#  u'glimpse',
#  u'which',
#  u'i',
#  u'got',
#  u'of',
#  u'it',
#  u'from',
#  u'the',
#  u'train',
#  u'and',
#  u'the',
#  u'little',
#  u'i',
#  u'could',
#  u'walk',
#  u'through',
#  u'the',
#  u'streets.',
#  u'i',
#  u'feared',
#  u'to',
#  u'go',
#  u'very',
#  u'far',
#  u'from',
#  u'the',
#  u'station',
#  u'as',
#  u'we',
#  u'had',
#  u'arrived',
#  u'late',
#  u'and',
#  u'would',
#  u'start',
#  u'as',
#  u'near',
#  u'the',
#  u'correct',
#  u'time',
#  u'as',
#  u'possible.',
#  u'the',
#  u'impression',
#  u'i',
#  u'had',
#  u'was',
#  u'that',
#  u'we',
#  u'were',
#  u'leaving',
#  u'the',
#  u'west',
#  u'and',
#  u'entering',
#  u'the',
#  u'east;',
#  u'the',
#  u'most',
#  u'western',
#  u'of',
#  u'splendid',
#  u'bridges',
#  u'over',
#  u'the',
#  u'danube',
#  u'which',
#  u'is',
#  u'here',
#  u'of',
#  u'noble',
#  u'width',
#  u'and',
#  u'depth',
#  u'took',
#  u'us',
#  u'among',
#  u'the',
#  u'traditions',
#  u'of',
#  u'turkish',
#  u'rule.',
#  u'we',
#  u'left',
#  u'in',
#  u'pretty',
#  u'good',
#  u'time',
#  u'and',
#  u'came',
#  u'after',
#  u'nightfall',
#  u'to',
#  u'klausenburgh.',
#  u'here',
#  u'i',
#  u'stopped',
#  u'for',
#  u'the',
#  u'night',
#  u'at',
#  u'the',
#  u'hotel',
#  u'royale.',
#  u'i',
#  u'had',
#  u'for',
#  u'dinner',
#  u'or',
#  u'rather',
#  u'supper',
#  u'a',
#  u'chicken',
#  u'done',
#  u'up',
#  u'some',
#  u'way',
#  u'with',
#  u'red',
#  u'pepper',
#  u'which',
#  u'was',
#  u'very',
#  u'good',
#  u'but',
#  u'thirsty.',
#  u'(_mem._',
#  u'get',
#  u'recipe',
#  u'for',
#  u'mina.)',
#  u'i',
#  u'asked',
#  u'the',
#  u'waiter',
#  u'and',
#  u'he',
#  u'said',
#  u'it',
#  u'was',
#  u'called',
#  u'"paprika',
#  u'hendl"',
#  u'and',
#  u'that',
#  u'as',
#  u'it',
#  u'was',
#  u'a',
#  u'national',
#  u'dish',
#  u'i',
#  u'should',
#  u'be',
#  u'able',
#  u'to',
#  u'get',
#  u'it',
#  u'anywhere',
#  u'along',
#  u'the',
#  u'carpathians.',
#  u'i',
#  u'found',
#  u'my',
#  u'smattering',
#  u'of',
#  u'german',
#  u'very',
#  u'useful',
#  u'here;',
#  u'indeed',
#  u'i',
#  u"don't",
#  u'know',
#  u'how',
#  u'i',
#  u'should',
#  u'be',
#  u'able',
#  u'to',
#  u'get',
#  u'on',
#  u'without',
#  u'it.',
#  u'having',
#  u'had',
#  u'some',
#  u'time',
#  u'at',
#  u'my',
#  u'disposal',
#  u'when',
#  u'in',
#  u'london',
#  u'i',
#  u'had',
#  u'visited',
#  u'the',
#  u'british',
#  u'museum',
#  u'and',
#  u'made',
#  u'search',
#  u'among',
#  u'the',
#  u'books',
#  u'and',
#  u'maps',
#  u'in',
#  u'the',
#  u'library',
#  u'regarding',
#  u'transylvania;',
#  u'it',
#  u'had',
#  u'struck',
#  u'me',
#  u'that',
#  u'some',
#  u'foreknowledge',
#  u'of',
#  u'the',
#  u'country',
#  u'could',
#  u'hardly',
#  u'fail',
#  u'to',
#  u'have',
#  u'some',
#  u'importance',
#  u'in',
#  u'dealing',
#  u'with',
#  u'a',
#  u'nobleman',
#  u'of',
#  u'that',
#  u'country.',
#  u'i',
#  u'find',
#  u'that',
#  u'the',
#  u'district',
#  u'he',
#  u'named',
#  u'is',
#  u'in',
#  u'the',
#  u'extreme',
#  u'east',
#  u'of',
#  u'the',
#  u'country',
#  u'just',
#  u'on',
#  u'the',
#  u'borders',
#  u'of',
#  u'three',
#  u'states',
#  u'transylvania',
#  u'moldavia',
#  u'and',
#  u'bukovina',
#  u'in',
#  u'the',
#  u'midst',
#  u'of',
#  u'the',
#  u'carpathian',
#  u'mountains;',
#  u'one',
#  u'of',
#  u'the',
#  u'wildest',
#  u'and',
#  u'least',
#  u'known',
#  u'portions',
#  u'of',
#  u'europe.',
#  u'i',
#  u'was',
#  u'not',
#  u'able',
#  u'to',
#  u'light',
#  u'on',
#  u'any',
#  u'map',
#  u'or',
#  u'work',
#  u'giving',
#  u'the',
#  u'exact',
#  u'locality',
#  u'of',
#  u'the',
#  u'castle',
#  u'dracula',
#  u'as',
#  u'there',
#  u'are',
#  u'no',
#  u'maps',
#  u'of',
#  u'this',
#  u'country',
#  u'as',
#  u'yet',
#  u'to',
#  u'compare',
#  u'with',
#  u'our',
#  u'own',
#  u'ordnance',
#  u'survey',
#  u'maps;',
#  u'but',
#  u'i',
#  u'found',
#  u'that',
#  u'bistritz',
#  u'the',
#  u'post',
#  u'town',
#  u'named',
#  u'by',
#  u'count',
#  u'dracula',
#  u'is',
#  u'a',
#  u'fairly',
#  u'well-known',
#  u'place.',
#  u'i',
#  u'shall',
#  u'enter',
#  u'here',
#  u'some',
#  u'of',
#  u'my',
#  u'notes',
#  u'as',
#  u'they',
#  u'may',
#  u'refresh',
#  u'my',
#  u'memory',
#  u'when',
#  u'i',
#  u'talk',
#  u'over',
#  u'my',
#  u'travels',
#  u'with',
#  u'mina.',
#  u'in',
#  u'the',
#  u'population',
#  u'of',
#  u'transylvania',
#  u'there',
#  u'are',
#  u'four',
#  u'distinct',
#  u'nationalities:',
#  u'saxons',
#  u'in',
#  u'the',
#  u'south',
#  u'and',
#  u'mixed',
#  u'with',
#  u'them',
#  u'the',
#  u'wallachs',
#  u'who',
#  u'are',
#  u'the',
#  u'descendants',
#  u'of',
#  u'the',
#  u'dacians;',
#  u'magyars',
#  u'in',
#  u'the',
#  u'west',
#  u'and',
#  u'szekelys',
#  u'in',
#  u'the',
#  u'east',
#  u'and',
#  u'north.',
#  u'i',
#  u'am',
#  u'going',
#  u'among',
#  u'the',
#  u'latter',
#  u'who',
#  u'claim',
#  u'to',
#  u'be',
#  u'descended',
#  u'from',
#  u'attila',
#  u'and',
#  u'the',
#  u'huns.',
#  u'this',
#  u'may',
#  u'be',
#  u'so',
#  u'for',
#  u'when',
#  u'the',
#  u'magyars',
#  u'conquered',
#  u'the',
#  u'country',
#  u'in',
#  u'the',
#  u'eleventh',
#  u'century',
#  u'they',
#  u'found',
#  u'the',
#  u'huns',
#  u'settled',
#  u'in',
#  u'it.',
#  u'i',
#  u'read',
#  u'that',
#  u'every',
#  u'known',
#  u'superstition',
#  u'in',
#  u'the',
#  u'world',
#  u'is',
#  u'gathered',
#  u'into',
#  u'the',
#  u'horseshoe',
#  u'of',
#  u'the',
#  u'carpathians',
#  u'as',
#  u'if',
#  u'it',
#  u'were',
#  u'the',
#  u'centre',
#  u'of',
#  u'some',
#  u'sort',
#  u'of',
#  u'imaginative',
#  u'whirlpool;',
#  u'if',
#  u'so',
#  u'my',
#  u'stay',
#  u'may',
#  u'be',
#  u'very',
#  u'interesting.',
#  u'(_mem._',
#  u'i',
#  u'must',
#  u'ask',
#  u'the',
#  u'count',
#  u'all',
#  u'about',
#  u'them.)',
#  u'i',
#  u'did',
#  u'not',
#  u'sleep',
#  u'well',
#  u'though',
#  u'my',
#  u'bed',
#  u'was',
#  u'comfortable',
#  u'enough',
#  u'for',
#  u'i',
#  u'had',
#  u'all',
#  u'sorts',
#  u'of',
#  u'queer',
#  u'dreams.',
#  u'there',
#  u'was',
#  u'a',
#  u'dog',
#  u'howling',
#  u'all',
#  u'night',
#  u'under',
#  u'my',
#  u'window',
#  u'which',
#  u'may',
#  u'have',
#  u'had',
#  u'something',
#  u'to',
#  u'do',
#  u'with',
#  u'it;',
#  u'or',
#  u'it',
#  u'may',
#  u'have',
#  u'been',
#  u'the',
#  u'paprika',
#  u'for',
#  u'i',
#  u'had',
#  u'to',
#  u'drink',
#  u'up',
#  u'all',
#  u'the',
#  u'water',
#  u'in',
#  u'my',
#  u'carafe',
#  u'and',
#  u'was',
#  u'still',
#  u'thirsty.',
#  u'towards',
#  u'morning',
#  u'i',
#  u'slept',
#  u'and',
#  u'was',
#  u'wakened',
#  u'by',
#  u'the',
#  u'continuous',
#  u'knocking',
#  u'at',
#  u'my',
#  u'door',
#  u'so',
#  u'i',
#  u'guess',
#  u'i',
#  u'must',
#  u'have',
#  u'been',
#  u'sleeping',
#  u'soundly',
#  u'then.',
#  u'i',
#  u'had',
#  u'for',
#  u'breakfast',
#  u'more',
#  u'paprika',
#  u'and',
#  u'a',
#  u'sort',
#  u'of',
#  u'porridge',
#  u'of',
#  u'maize',
#  u'flour',
#  u'which',
#  u'they',
#  u'said',
#  u'was',
#  u'"mamaliga"',
#  u'and',
#  u'egg-plant',
#  u'stuffed',
#  u'with',
#  u'forcemeat',
#  u'a',
#  u'very',
#  u'excellent',
#  u'dish',
#  u'which',
#  u'they',
#  u'call',
#  u'"impletata."',
#  u'(_mem._',
#  u'get',
#  u'recipe',
#  u'for',
#  u'this',
#  u'also.)',
#  u'i',
#  u'had',
#  u'to',
#  u'hurry',
#  u'breakfast',
#  u'for',
#  u'the',
#  u'train',
#  u'started',
#  u'a',
#  u'little',
#  u'before',
#  u'eight',
#  u'or',
#  u'rather',
#  u'it',
#  u'ought',
#  u'to',
#  u'have',
#  u'done',
#  u'so',
#  u'for',
#  u'after',
#  u'rushing',
#  u'to',
#  u'the',
#  u'station',
#  u'at',
#  u'7:30',
#  u'i',
#  ...]

# %% [markdown]
# Execute the command with the action `take()` and retrieve the first 10 words from the `flatMap()`transformation

# %%
# Executing the action take() to collect the first 10 words of the RDD words

words.take(10)

# Comment : it creates a list with those words.
# Out:
# [u'the',
#  u'project',
#  u'gutenberg',
#  u'ebook',
#  u'of',
#  u'dracula',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'this']

# %% [markdown]
# Perform a classic `map()` to create a tuple where each word has a count of 1

# %%
# Creation of a list of tuples with each word and an associated count of 1 using map()

map_words=words.map(lambda word : (word,1))
map_words.collect()
# Out:
# [(u'the', 1),
#  (u'project', 1),
#  (u'gutenberg', 1),
#  (u'ebook', 1),
#  (u'of', 1),
#  (u'dracula', 1),
#  (u'by', 1),
#  (u'bram', 1),
#  (u'stoker', 1),
#  (u'this', 1),
#  (u'ebook', 1),
#  (u'is', 1),
#  (u'for', 1),
#  (u'the', 1),
#  (u'use', 1),
#  (u'of', 1),
#  (u'anyone', 1),
#  (u'anywhere', 1),
#  (u'at', 1),
#  (u'no', 1),
#  (u'cost', 1),
#  (u'and', 1),
#  (u'with', 1),
#  (u'almost', 1),
#  (u'no', 1),
#  (u'restrictions', 1),
#  (u'whatsoever.', 1),
#  (u'you', 1),
#  (u'may', 1),
#  (u'copy', 1),
#  (u'it', 1),
#  (u'give', 1),
#  (u'it', 1),
#  (u'away', 1),
#  (u'or', 1),
#  (u're-use', 1),
#  (u'it', 1),
#  (u'under', 1),
#  (u'the', 1),
#  (u'terms', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'project', 1),
#  (u'gutenberg', 1),
#  (u'license', 1),
#  (u'included', 1),
#  (u'with', 1),
#  (u'this', 1),
#  (u'ebook', 1),
#  (u'or', 1),
#  (u'online', 1),
#  (u'at', 1),
#  (u'www.gutenberg.org/license', 1),
#  (u'title:', 1),
#  (u'dracula', 1),
#  (u'author:', 1),
#  (u'bram', 1),
#  (u'stoker', 1),
#  (u'release', 1),
#  (u'date:', 1),
#  (u'august', 1),
#  (u'16', 1),
#  (u'2013', 1),
#  (u'[ebook', 1),
#  (u'#345]', 1),
#  (u'language:', 1),
#  (u'english', 1),
#  (u'***', 1),
#  (u'start', 1),
#  (u'of', 1),
#  (u'this', 1),
#  (u'project', 1),
#  (u'gutenberg', 1),
#  (u'ebook', 1),
#  (u'dracula', 1),
#  (u'***', 1),
#  (u'produced', 1),
#  (u'by', 1),
#  (u'chuck', 1),
#  (u'greif', 1),
#  (u'and', 1),
#  (u'the', 1),
#  (u'online', 1),
#  (u'distributed', 1),
#  (u'proofreading', 1),
#  (u'team', 1),
#  (u'at', 1),
#  (u'http://www.pgdp.net', 1),
#  (u'(this', 1),
#  (u'file', 1),
#  (u'was', 1),
#  (u'produced', 1),
#  (u'from', 1),
#  (u'images', 1),
#  (u'generously', 1),
#  (u'made', 1),
#  (u'available', 1),
#  (u'by', 1),
#  (u'the', 1),
#  (u'internet', 1),
#  (u'archive)', 1),
#  (u'dracula', 1),
#  (u'dracula', 1),
#  (u'_by_', 1),
#  (u'bram', 1),
#  (u'stoker', 1),
#  (u'[illustration:', 1),
#  (u'colophon]', 1),
#  (u'new', 1),
#  (u'york', 1),
#  (u'grosset', 1),
#  (u'&', 1),
#  (u'dunlap', 1),
#  (u'_publishers_', 1),
#  (u'copyright', 1),
#  (u'1897', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'united', 1),
#  (u'states', 1),
#  (u'of', 1),
#  (u'america', 1),
#  (u'according', 1),
#  (u'to', 1),
#  (u'act', 1),
#  (u'of', 1),
#  (u'congress', 1),
#  (u'by', 1),
#  (u'bram', 1),
#  (u'stoker', 1),
#  (u'[_all', 1),
#  (u'rights', 1),
#  (u'reserved._]', 1),
#  (u'printed', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'united', 1),
#  (u'states', 1),
#  (u'at', 1),
#  (u'the', 1),
#  (u'country', 1),
#  (u'life', 1),
#  (u'press', 1),
#  (u'garden', 1),
#  (u'city', 1),
#  (u'n.y.', 1),
#  (u'to', 1),
#  (u'my', 1),
#  (u'dear', 1),
#  (u'friend', 1),
#  (u'hommy-beg', 1),
#  (u'contents', 1),
#  (u'chapter', 1),
#  (u'i', 1),
#  (u'page', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'1', 1),
#  (u'chapter', 1),
#  (u'ii', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'14', 1),
#  (u'chapter', 1),
#  (u'iii', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'26', 1),
#  (u'chapter', 1),
#  (u'iv', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'38', 1),
#  (u'chapter', 1),
#  (u'v', 1),
#  (u'letters--lucy', 1),
#  (u'and', 1),
#  (u'mina', 1),
#  (u'51', 1),
#  (u'chapter', 1),
#  (u'vi', 1),
#  (u'mina', 1),
#  (u"murray's", 1),
#  (u'journal', 1),
#  (u'59', 1),
#  (u'chapter', 1),
#  (u'vii', 1),
#  (u'cutting', 1),
#  (u'from', 1),
#  (u'"the', 1),
#  (u'dailygraph"', 1),
#  (u'8', 1),
#  (u'august', 1),
#  (u'71', 1),
#  (u'chapter', 1),
#  (u'viii', 1),
#  (u'mina', 1),
#  (u"murray's", 1),
#  (u'journal', 1),
#  (u'84', 1),
#  (u'chapter', 1),
#  (u'ix', 1),
#  (u'mina', 1),
#  (u"murray's", 1),
#  (u'journal', 1),
#  (u'98', 1),
#  (u'chapter', 1),
#  (u'x', 1),
#  (u'mina', 1),
#  (u"murray's", 1),
#  (u'journal', 1),
#  (u'111', 1),
#  (u'chapter', 1),
#  (u'xi', 1),
#  (u'lucy', 1),
#  (u"westenra's", 1),
#  (u'diary', 1),
#  (u'124', 1),
#  (u'chapter', 1),
#  (u'xii', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'136', 1),
#  (u'chapter', 1),
#  (u'xiii', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'152', 1),
#  (u'chapter', 1),
#  (u'xiv', 1),
#  (u'mina', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'167', 1),
#  (u'chapter', 1),
#  (u'xv', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'181', 1),
#  (u'chapter', 1),
#  (u'xvi', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'194', 1),
#  (u'chapter', 1),
#  (u'xvii', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'204', 1),
#  (u'chapter', 1),
#  (u'xviii', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'216', 1),
#  (u'chapter', 1),
#  (u'xix', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'231', 1),
#  (u'chapter', 1),
#  (u'xx', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'243', 1),
#  (u'chapter', 1),
#  (u'xxi', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'256', 1),
#  (u'chapter', 1),
#  (u'xxii', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'269', 1),
#  (u'chapter', 1),
#  (u'xxiii', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'281', 1),
#  (u'chapter', 1),
#  (u'xxiv', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'phonograph', 1),
#  (u'diary', 1),
#  (u'spoken', 1),
#  (u'by', 1),
#  (u'van', 1),
#  (u'helsing', 1),
#  (u'294', 1),
#  (u'chapter', 1),
#  (u'xxv', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'308', 1),
#  (u'chapter', 1),
#  (u'xxvi', 1),
#  (u'dr.', 1),
#  (u"seward's", 1),
#  (u'diary', 1),
#  (u'322', 1),
#  (u'chapter', 1),
#  (u'xxvii', 1),
#  (u'mina', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'338', 1),
#  (u'dracula', 1),
#  (u'chapter', 1),
#  (u'i', 1),
#  (u'jonathan', 1),
#  (u"harker's", 1),
#  (u'journal', 1),
#  (u'(_kept', 1),
#  (u'in', 1),
#  (u'shorthand._)', 1),
#  (u'_3', 1),
#  (u'may.', 1),
#  (u'bistritz._--left', 1),
#  (u'munich', 1),
#  (u'at', 1),
#  (u'8:35', 1),
#  (u'p.', 1),
#  (u'm.', 1),
#  (u'on', 1),
#  (u'1st', 1),
#  (u'may', 1),
#  (u'arriving', 1),
#  (u'at', 1),
#  (u'vienna', 1),
#  (u'early', 1),
#  (u'next', 1),
#  (u'morning;', 1),
#  (u'should', 1),
#  (u'have', 1),
#  (u'arrived', 1),
#  (u'at', 1),
#  (u'6:46', 1),
#  (u'but', 1),
#  (u'train', 1),
#  (u'was', 1),
#  (u'an', 1),
#  (u'hour', 1),
#  (u'late.', 1),
#  (u'buda-pesth', 1),
#  (u'seems', 1),
#  (u'a', 1),
#  (u'wonderful', 1),
#  (u'place', 1),
#  (u'from', 1),
#  (u'the', 1),
#  (u'glimpse', 1),
#  (u'which', 1),
#  (u'i', 1),
#  (u'got', 1),
#  (u'of', 1),
#  (u'it', 1),
#  (u'from', 1),
#  (u'the', 1),
#  (u'train', 1),
#  (u'and', 1),
#  (u'the', 1),
#  (u'little', 1),
#  (u'i', 1),
#  (u'could', 1),
#  (u'walk', 1),
#  (u'through', 1),
#  (u'the', 1),
#  (u'streets.', 1),
#  (u'i', 1),
#  (u'feared', 1),
#  (u'to', 1),
#  (u'go', 1),
#  (u'very', 1),
#  (u'far', 1),
#  (u'from', 1),
#  (u'the', 1),
#  (u'station', 1),
#  (u'as', 1),
#  (u'we', 1),
#  (u'had', 1),
#  (u'arrived', 1),
#  (u'late', 1),
#  (u'and', 1),
#  (u'would', 1),
#  (u'start', 1),
#  (u'as', 1),
#  (u'near', 1),
#  (u'the', 1),
#  (u'correct', 1),
#  (u'time', 1),
#  (u'as', 1),
#  (u'possible.', 1),
#  (u'the', 1),
#  (u'impression', 1),
#  (u'i', 1),
#  (u'had', 1),
#  (u'was', 1),
#  (u'that', 1),
#  (u'we', 1),
#  (u'were', 1),
#  (u'leaving', 1),
#  (u'the', 1),
#  (u'west', 1),
#  (u'and', 1),
#  (u'entering', 1),
#  (u'the', 1),
#  (u'east;', 1),
#  (u'the', 1),
#  (u'most', 1),
#  (u'western', 1),
#  (u'of', 1),
#  (u'splendid', 1),
#  (u'bridges', 1),
#  (u'over', 1),
#  (u'the', 1),
#  (u'danube', 1),
#  (u'which', 1),
#  (u'is', 1),
#  (u'here', 1),
#  (u'of', 1),
#  (u'noble', 1),
#  (u'width', 1),
#  (u'and', 1),
#  (u'depth', 1),
#  (u'took', 1),
#  (u'us', 1),
#  (u'among', 1),
#  (u'the', 1),
#  (u'traditions', 1),
#  (u'of', 1),
#  (u'turkish', 1),
#  (u'rule.', 1),
#  (u'we', 1),
#  (u'left', 1),
#  (u'in', 1),
#  (u'pretty', 1),
#  (u'good', 1),
#  (u'time', 1),
#  (u'and', 1),
#  (u'came', 1),
#  (u'after', 1),
#  (u'nightfall', 1),
#  (u'to', 1),
#  (u'klausenburgh.', 1),
#  (u'here', 1),
#  (u'i', 1),
#  (u'stopped', 1),
#  (u'for', 1),
#  (u'the', 1),
#  (u'night', 1),
#  (u'at', 1),
#  (u'the', 1),
#  (u'hotel', 1),
#  (u'royale.', 1),
#  (u'i', 1),
#  (u'had', 1),
#  (u'for', 1),
#  (u'dinner', 1),
#  (u'or', 1),
#  (u'rather', 1),
#  (u'supper', 1),
#  (u'a', 1),
#  (u'chicken', 1),
#  (u'done', 1),
#  (u'up', 1),
#  (u'some', 1),
#  (u'way', 1),
#  (u'with', 1),
#  (u'red', 1),
#  (u'pepper', 1),
#  (u'which', 1),
#  (u'was', 1),
#  (u'very', 1),
#  (u'good', 1),
#  (u'but', 1),
#  (u'thirsty.', 1),
#  (u'(_mem._', 1),
#  (u'get', 1),
#  (u'recipe', 1),
#  (u'for', 1),
#  (u'mina.)', 1),
#  (u'i', 1),
#  (u'asked', 1),
#  (u'the', 1),
#  (u'waiter', 1),
#  (u'and', 1),
#  (u'he', 1),
#  (u'said', 1),
#  (u'it', 1),
#  (u'was', 1),
#  (u'called', 1),
#  (u'"paprika', 1),
#  (u'hendl"', 1),
#  (u'and', 1),
#  (u'that', 1),
#  (u'as', 1),
#  (u'it', 1),
#  (u'was', 1),
#  (u'a', 1),
#  (u'national', 1),
#  (u'dish', 1),
#  (u'i', 1),
#  (u'should', 1),
#  (u'be', 1),
#  (u'able', 1),
#  (u'to', 1),
#  (u'get', 1),
#  (u'it', 1),
#  (u'anywhere', 1),
#  (u'along', 1),
#  (u'the', 1),
#  (u'carpathians.', 1),
#  (u'i', 1),
#  (u'found', 1),
#  (u'my', 1),
#  (u'smattering', 1),
#  (u'of', 1),
#  (u'german', 1),
#  (u'very', 1),
#  (u'useful', 1),
#  (u'here;', 1),
#  (u'indeed', 1),
#  (u'i', 1),
#  (u"don't", 1),
#  (u'know', 1),
#  (u'how', 1),
#  (u'i', 1),
#  (u'should', 1),
#  (u'be', 1),
#  (u'able', 1),
#  (u'to', 1),
#  (u'get', 1),
#  (u'on', 1),
#  (u'without', 1),
#  (u'it.', 1),
#  (u'having', 1),
#  (u'had', 1),
#  (u'some', 1),
#  (u'time', 1),
#  (u'at', 1),
#  (u'my', 1),
#  (u'disposal', 1),
#  (u'when', 1),
#  (u'in', 1),
#  (u'london', 1),
#  (u'i', 1),
#  (u'had', 1),
#  (u'visited', 1),
#  (u'the', 1),
#  (u'british', 1),
#  (u'museum', 1),
#  (u'and', 1),
#  (u'made', 1),
#  (u'search', 1),
#  (u'among', 1),
#  (u'the', 1),
#  (u'books', 1),
#  (u'and', 1),
#  (u'maps', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'library', 1),
#  (u'regarding', 1),
#  (u'transylvania;', 1),
#  (u'it', 1),
#  (u'had', 1),
#  (u'struck', 1),
#  (u'me', 1),
#  (u'that', 1),
#  (u'some', 1),
#  (u'foreknowledge', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'country', 1),
#  (u'could', 1),
#  (u'hardly', 1),
#  (u'fail', 1),
#  (u'to', 1),
#  (u'have', 1),
#  (u'some', 1),
#  (u'importance', 1),
#  (u'in', 1),
#  (u'dealing', 1),
#  (u'with', 1),
#  (u'a', 1),
#  (u'nobleman', 1),
#  (u'of', 1),
#  (u'that', 1),
#  (u'country.', 1),
#  (u'i', 1),
#  (u'find', 1),
#  (u'that', 1),
#  (u'the', 1),
#  (u'district', 1),
#  (u'he', 1),
#  (u'named', 1),
#  (u'is', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'extreme', 1),
#  (u'east', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'country', 1),
#  (u'just', 1),
#  (u'on', 1),
#  (u'the', 1),
#  (u'borders', 1),
#  (u'of', 1),
#  (u'three', 1),
#  (u'states', 1),
#  (u'transylvania', 1),
#  (u'moldavia', 1),
#  (u'and', 1),
#  (u'bukovina', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'midst', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'carpathian', 1),
#  (u'mountains;', 1),
#  (u'one', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'wildest', 1),
#  (u'and', 1),
#  (u'least', 1),
#  (u'known', 1),
#  (u'portions', 1),
#  (u'of', 1),
#  (u'europe.', 1),
#  (u'i', 1),
#  (u'was', 1),
#  (u'not', 1),
#  (u'able', 1),
#  (u'to', 1),
#  (u'light', 1),
#  (u'on', 1),
#  (u'any', 1),
#  (u'map', 1),
#  (u'or', 1),
#  (u'work', 1),
#  (u'giving', 1),
#  (u'the', 1),
#  (u'exact', 1),
#  (u'locality', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'castle', 1),
#  (u'dracula', 1),
#  (u'as', 1),
#  (u'there', 1),
#  (u'are', 1),
#  (u'no', 1),
#  (u'maps', 1),
#  (u'of', 1),
#  (u'this', 1),
#  (u'country', 1),
#  (u'as', 1),
#  (u'yet', 1),
#  (u'to', 1),
#  (u'compare', 1),
#  (u'with', 1),
#  (u'our', 1),
#  (u'own', 1),
#  (u'ordnance', 1),
#  (u'survey', 1),
#  (u'maps;', 1),
#  (u'but', 1),
#  (u'i', 1),
#  (u'found', 1),
#  (u'that', 1),
#  (u'bistritz', 1),
#  (u'the', 1),
#  (u'post', 1),
#  (u'town', 1),
#  (u'named', 1),
#  (u'by', 1),
#  (u'count', 1),
#  (u'dracula', 1),
#  (u'is', 1),
#  (u'a', 1),
#  (u'fairly', 1),
#  (u'well-known', 1),
#  (u'place.', 1),
#  (u'i', 1),
#  (u'shall', 1),
#  (u'enter', 1),
#  (u'here', 1),
#  (u'some', 1),
#  (u'of', 1),
#  (u'my', 1),
#  (u'notes', 1),
#  (u'as', 1),
#  (u'they', 1),
#  (u'may', 1),
#  (u'refresh', 1),
#  (u'my', 1),
#  (u'memory', 1),
#  (u'when', 1),
#  (u'i', 1),
#  (u'talk', 1),
#  (u'over', 1),
#  (u'my', 1),
#  (u'travels', 1),
#  (u'with', 1),
#  (u'mina.', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'population', 1),
#  (u'of', 1),
#  (u'transylvania', 1),
#  (u'there', 1),
#  (u'are', 1),
#  (u'four', 1),
#  (u'distinct', 1),
#  (u'nationalities:', 1),
#  (u'saxons', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'south', 1),
#  (u'and', 1),
#  (u'mixed', 1),
#  (u'with', 1),
#  (u'them', 1),
#  (u'the', 1),
#  (u'wallachs', 1),
#  (u'who', 1),
#  (u'are', 1),
#  (u'the', 1),
#  (u'descendants', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'dacians;', 1),
#  (u'magyars', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'west', 1),
#  (u'and', 1),
#  (u'szekelys', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'east', 1),
#  (u'and', 1),
#  (u'north.', 1),
#  (u'i', 1),
#  (u'am', 1),
#  (u'going', 1),
#  (u'among', 1),
#  (u'the', 1),
#  (u'latter', 1),
#  (u'who', 1),
#  (u'claim', 1),
#  (u'to', 1),
#  (u'be', 1),
#  (u'descended', 1),
#  (u'from', 1),
#  (u'attila', 1),
#  (u'and', 1),
#  (u'the', 1),
#  (u'huns.', 1),
#  (u'this', 1),
#  (u'may', 1),
#  (u'be', 1),
#  (u'so', 1),
#  (u'for', 1),
#  (u'when', 1),
#  (u'the', 1),
#  (u'magyars', 1),
#  (u'conquered', 1),
#  (u'the', 1),
#  (u'country', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'eleventh', 1),
#  (u'century', 1),
#  (u'they', 1),
#  (u'found', 1),
#  (u'the', 1),
#  (u'huns', 1),
#  (u'settled', 1),
#  (u'in', 1),
#  (u'it.', 1),
#  (u'i', 1),
#  (u'read', 1),
#  (u'that', 1),
#  (u'every', 1),
#  (u'known', 1),
#  (u'superstition', 1),
#  (u'in', 1),
#  (u'the', 1),
#  (u'world', 1),
#  (u'is', 1),
#  (u'gathered', 1),
#  (u'into', 1),
#  (u'the', 1),
#  (u'horseshoe', 1),
#  (u'of', 1),
#  (u'the', 1),
#  (u'carpathians', 1),
#  (u'as', 1),
#  (u'if', 1),
#  (u'it', 1),
#  (u'were', 1),
#  (u'the', 1),
#  (u'centre', 1),
#  (u'of', 1),
#  (u'some', 1),
#  (u'sort', 1),
#  (u'of', 1),
#  (u'imaginative', 1),
#  (u'whirlpool;', 1),
#  (u'if', 1),
#  (u'so', 1),
#  (u'my', 1),
#  (u'stay', 1),
#  (u'may', 1),
#  (u'be', 1),
#  (u'very', 1),
#  (u'interesting.', 1),
#  (u'(_mem._', 1),
#  (u'i', 1),
#  (u'must', 1),
#  (u'ask', 1),
#  (u'the', 1),
#  (u'count', 1),
#  (u'all', 1),
#  (u'about', 1),
#  (u'them.)', 1),
#  (u'i', 1),
#  (u'did', 1),
#  (u'not', 1),
#  (u'sleep', 1),
#  (u'well', 1),
#  (u'though', 1),
#  (u'my', 1),
#  (u'bed', 1),
#  (u'was', 1),
#  (u'comfortable', 1),
#  (u'enough', 1),
#  (u'for', 1),
#  (u'i', 1),
#  (u'had', 1),
#  (u'all', 1),
#  (u'sorts', 1),
#  (u'of', 1),
#  (u'queer', 1),
#  (u'dreams.', 1),
#  (u'there', 1),
#  (u'was', 1),
#  (u'a', 1),
#  (u'dog', 1),
#  (u'howling', 1),
#  (u'all', 1),
#  (u'night', 1),
#  (u'under', 1),
#  (u'my', 1),
#  (u'window', 1),
#  (u'which', 1),
#  (u'may', 1),
#  (u'have', 1),
#  (u'had', 1),
#  (u'something', 1),
#  (u'to', 1),
#  (u'do', 1),
#  (u'with', 1),
#  (u'it;', 1),
#  (u'or', 1),
#  (u'it', 1),
#  (u'may', 1),
#  (u'have', 1),
#  (u'been', 1),
#  (u'the', 1),
#  (u'paprika', 1),
#  (u'for', 1),
#  (u'i', 1),
#  (u'had', 1),
#  (u'to', 1),
#  (u'drink', 1),
#  (u'up', 1),
#  (u'all', 1),
#  (u'the', 1),
#  (u'water', 1),
#  (u'in', 1),
#  (u'my', 1),
#  (u'carafe', 1),
#  (u'and', 1),
#  (u'was', 1),
#  (u'still', 1),
#  (u'thirsty.', 1),
#  (u'towards', 1),
#  (u'morning', 1),
#  (u'i', 1),
#  (u'slept', 1),
#  (u'and', 1),
#  (u'was', 1),
#  (u'wakened', 1),
#  (u'by', 1),
#  (u'the', 1),
#  (u'continuous', 1),
#  (u'knocking', 1),
#  (u'at', 1),
#  (u'my', 1),
#  (u'door', 1),
#  (u'so', 1),
#  (u'i', 1),
#  (u'guess', 1),
#  (u'i', 1),
#  (u'must', 1),
#  (u'have', 1),
#  (u'been', 1),
#  (u'sleeping', 1),
#  (u'soundly', 1),
#  (u'then.', 1),
#  (u'i', 1),
#  (u'had', 1),
#  (u'for', 1),
#  (u'breakfast', 1),
#  (u'more', 1),
#  (u'paprika', 1),
#  (u'and', 1),
#  (u'a', 1),
#  (u'sort', 1),
#  (u'of', 1),
#  (u'porridge', 1),
#  (u'of', 1),
#  (u'maize', 1),
#  (u'flour', 1),
#  (u'which', 1),
#  (u'they', 1),
#  (u'said', 1),
#  (u'was', 1),
#  (u'"mamaliga"', 1),
#  (u'and', 1),
#  (u'egg-plant', 1),
#  (u'stuffed', 1),
#  (u'with', 1),
#  (u'forcemeat', 1),
#  (u'a', 1),
#  (u'very', 1),
#  (u'excellent', 1),
#  (u'dish', 1),
#  (u'which', 1),
#  (u'they', 1),
#  (u'call', 1),
#  (u'"impletata."', 1),
#  (u'(_mem._', 1),
#  (u'get', 1),
#  (u'recipe', 1),
#  (u'for', 1),
#  (u'this', 1),
#  (u'also.)', 1),
#  (u'i', 1),
#  (u'had', 1),
#  (u'to', 1),
#  (u'hurry', 1),
#  (u'breakfast', 1),
#  (u'for', 1),
#  (u'the', 1),
#  (u'train', 1),
#  (u'started', 1),
#  (u'a', 1),
#  (u'little', 1),
#  (u'before', 1),
#  (u'eight', 1),
#  (u'or', 1),
#  (u'rather', 1),
#  (u'it', 1),
#  (u'ought', 1),
#  (u'to', 1),
#  (u'have', 1),
#  (u'done', 1),
#  (u'so', 1),
#  (u'for', 1),
#  (u'after', 1),
#  (u'rushing', 1),
#  (u'to', 1),
#  (u'the', 1),
#  (u'station', 1),
#  (u'at', 1),
#  (u'7:30', 1),
#  (u'i', 1),
#  ...]

# %% [markdown]
# Write the reducing function

# %%
# Reducing function :

# We want to sum the counts by word. We use the reduceByKey transformation and display the result.

from operator import add

reduce_words=map_words.reduceByKey(add)
reduce_words.collect()
# Out:
# [(u'funereal', 1),
#  (u'shouted.', 1),
#  (u'"_czarina', 2),
#  (u'yellow', 6),
#  (u'four', 23),
#  (u"friend's", 2),
#  (u"bringin'", 1),
#  (u'increase', 2),
#  (u'_might_', 1),
#  (u'lore', 1),
#  (u'should.', 1),
#  (u'sinking', 6),
#  (u'spider.', 1),
#  (u'wood.', 3),
#  (u'fingers"', 1),
#  (u'foul', 13),
#  (u'fingers.', 4),
#  (u'screaming', 2),
#  (u'writing.', 3),
#  (u'disturb', 9),
#  (u'stars;', 1),
#  (u'wooden', 6),
#  (u"everything.'", 1),
#  (u"lor'", 3),
#  (u'straight', 20),
#  (u'colophon]', 1),
#  (u'nigh', 8),
#  (u'ate.', 1),
#  (u'bacon', 1),
#  (u'pulse', 2),
#  (u'her;', 16),
#  (u'second', 17),
#  (u'her?', 2),
#  (u'sailed', 4),
#  (u'misjudge;', 1),
#  (u'ruthless', 2),
#  (u'comically', 1),
#  (u'nature.', 6),
#  (u"madman's", 1),
#  (u'understood.', 2),
#  (u'up.', 22),
#  (u'so."', 5),
#  (u'hero', 1),
#  (u'here', 211),
#  (u'china', 2),
#  (u'hers', 7),
#  (u'chink', 1),
#  (u'shock.', 2),
#  (u'elaborate', 1),
#  (u'"why', 11),
#  (u'"paprika', 1),
#  (u'finger.', 2),
#  (u'pursuers.', 1),
#  (u'dimness', 1),
#  (u'"who', 1),
#  (u'criticism', 1),
#  (u'classification', 1),
#  (u'psychological', 1),
#  (u'remnant', 2),
#  (u'anywhere.', 6),
#  (u'"what?"', 1),
#  (u'police;', 1),
#  (u'common.', 5),
#  (u'sternest', 1),
#  (u'"forgive', 4),
#  (u'fierce-falling', 1),
#  (u'dinner-knife', 1),
#  (u'moth', 1),
#  (u'music', 7),
#  (u'strike', 8),
#  (u'harker.', 9),
#  (u'paperwork', 1),
#  (u'beset?', 1),
#  (u'successful', 4),
#  (u'whirling', 4),
#  (u'gravediggers', 1),
#  (u'dry;', 1),
#  (u'beset!', 1),
#  (u'hole', 6),
#  (u'mirth.', 1),
#  (u'gals.', 1),
#  (u'locked', 26),
#  (u'pursue', 3),
#  (u'plunged', 2),
#  (u'sweeter', 2),
#  (u'moonrise', 1),
#  (u'household', 3),
#  (u'type!', 1),
#  (u'updated', 1),
#  (u'malign', 2),
#  (u"that.'", 1),
#  (u'want', 107),
#  (u'feet-folks', 1),
#  (u'around.', 2),
#  (u'admission', 1),
#  (u'travel', 7),
#  (u'gravely:--', 4),
#  (u'hot', 8),
#  (u'laneway', 1),
#  (u'turk', 5),
#  (u'classify', 1),
#  (u'beauty', 14),
#  (u"'here", 2),
#  (u'diagram', 1),
#  (u'wrong', 20),
#  (u'_interview', 1),
#  (u'destined', 1),
#  (u'dough', 1),
#  (u'unselfish', 5),
#  (u'outcry', 1),
#  (u'types', 1),
#  (u'matter-of-fact', 1),
#  (u'some;', 2),
#  (u'effective', 1),
#  (u'drowse', 1),
#  (u'heaven-kissed', 1),
#  (u'spot--i', 1),
#  (u'floridas', 1),
#  (u'wind', 38),
#  (u'blind', 13),
#  (u'effect.', 4),
#  (u'afoot!', 1),
#  (u'telephoned', 1),
#  (u'soothingly', 1),
#  (u'effect:', 2),
#  (u'lovingly', 2),
#  (u'fit', 8),
#  (u'bringing', 7),
#  (u'fix', 3),
#  (u'closed;', 1),
#  (u'died;', 1),
#  (u'vast', 5),
#  (u'_i', 1),
#  (u'hidden', 6),
#  (u'mentally-accomplished', 1),
#  (u'anxiety.', 2),
#  (u'_a', 2),
#  (u'corridor', 4),
#  (u'slate', 1),
#  (u'bukovina.', 2),
#  (u'interrupt', 1),
#  (u'undeveloped', 1),
#  (u'_9', 3),
#  (u'_7', 2),
#  (u'_5', 9),
#  (u'_3', 7),
#  (u'it--no', 1),
#  (u'anticipation.', 1),
#  (u'arrow', 1),
#  (u'organized', 1),
#  (u'coffin?"', 1),
#  (u'preceded', 3),
#  (u'financial', 1),
#  (u'cart--with', 1),
#  (u'correct.', 2),
#  (u'porch.', 1),
#  (u'knitting', 1),
#  (u'allay', 1),
#  (u'ring', 16),
#  (u'whip', 3),
#  (u'ice-cold', 1),
#  (u'prescribed.', 1),
#  (u'at.', 3),
#  (u'elephant-house', 1),
#  (u'outburst', 2),
#  (u'agonising', 3),
#  (u'assured', 8),
#  (u'precede.', 1),
#  (u'threatened', 1),
#  (u'fool-talk', 1),
#  (u'_her_', 2),
#  (u'checked', 2),
#  (u'estimate', 1),
#  (u'horizon."', 1),
#  (u'occasionally.', 1),
#  (u"several.'", 1),
#  (u'enormous', 1),
#  (u'fret-saw.', 1),
#  (u'would--unless', 1),
#  (u'receipted', 1),
#  (u'shipped', 1),
#  (u'dinner-hour', 1),
#  (u'coquettishly', 1),
#  (u'r.', 4),
#  (u'airly', 1),
#  (u'likes.', 1),
#  (u'me!', 21),
#  (u'reward.', 1),
#  (u'bitten', 2),
#  (u'households', 1),
#  (u'service', 11),
#  (u'sure:', 1),
#  (u'restless.', 1),
#  (u'done--whatever', 1),
#  (u'master', 20),
#  (u'xiv', 2),
#  (u'xix', 2),
#  (u'bitter', 21),
#  (u'her!', 2),
#  (u'sure.', 3),
#  (u'was;', 2),
#  (u'tenderness:--', 1),
#  (u'end--the', 1),
#  (u'exulted', 1),
#  (u'[_all', 1),
#  (u'chin;', 1),
#  (u'_the', 3),
#  (u'kind--and', 1),
#  (u'crawl', 2),
#  (u'positively', 10),
#  (u'look!"', 3),
#  (u'showed', 22),
#  (u'coward', 2),
#  (u'tree', 3),
#  (u'rusty', 6),
#  (u'idly', 1),
#  (u'project', 83),
#  (u'idle', 4),
#  (u'october._--i', 2),
#  (u'exactly?"', 1),
#  (u'well?', 2),
#  (u'well;', 6),
#  (u'runner', 1),
#  (u'stertorous', 5),
#  (u'(_x_)', 1),
#  (u'transaction.', 1),
#  (u'well!', 1),
#  (u'mostly', 2),
#  (u'loathing', 1),
#  (u'drunk.', 1),
#  (u'aboard.', 1),
#  (u'lives."', 1),
#  (u'absorbed', 2),
#  (u'doors', 9),
#  (u'harker._', 3),
#  (u'yours!"', 2),
#  (u'fast;', 1),
#  (u'fellow-passengers', 1),
#  (u'thrilled', 1),
#  (u'screwing', 1),
#  (u'looming', 1),
#  (u'fees.', 1),
#  (u'mouth', 31),
#  (u'inexpressible', 1),
#  (u'letter', 40),
#  (u'command;', 2),
#  (u'episode', 2),
#  (u'professor', 134),
#  (u"donelson's", 1),
#  (u'nineteenth', 3),
#  (u'affair.', 2),
#  (u'came', 301),
#  (u'testily:--', 1),
#  (u'prig', 1),
#  (u'padded', 4),
#  (u'asia', 1),
#  (u'cannot.', 2),
#  (u'lethal', 4),
#  (u'fortitude:', 1),
#  (u'touches', 1),
#  (u'quaint', 4),
#  (u'maids.', 1),
#  (u'bust', 1),
#  (u'bush', 2),
#  (u'tight.', 2),
#  (u'rich', 3),
#  (u'mend', 1),
#  (u'other"--here', 1),
#  (u'books--"have', 1),
#  (u'terrors', 3),
#  (u'_absolutely_', 1),
#  (u'"nay!', 1),
#  (u'lies.', 3),
#  (u'dawn;', 1),
#  (u'telegram.', 1),
#  (u'"men', 1),
#  (u'nicely', 1),
#  (u'dipping', 1),
#  (u'eyelids', 3),
#  (u'them!', 4),
#  (u'release', 3),
#  (u'typewriter.', 2),
#  (u'boarded', 1),
#  (u'respond', 1),
#  (u'blew', 9),
#  (u'fair', 21),
#  (u'all-important.', 1),
#  (u'fail', 12),
#  (u'fain', 1),
#  (u'claw.', 1),
#  (u'alternative', 2),
#  (u'best', 42),
#  (u'sooner', 1),
#  (u'lots', 2),
#  (u'quest.', 1),
#  (u'rings', 1),
#  (u'adventure.', 2),
#  (u'pit!', 1),
#  (u'"heavens', 1),
#  (u'preserve', 3),
#  (u'gasps.', 2),
#  (u'extend', 1),
#  (u'rolled', 6),
#  (u'lapping', 7),
#  (u'means"', 1),
#  (u'paddington', 3),
#  (u'extent', 3),
#  (u'wile.', 1),
#  (u'do!"', 1),
#  (u'pity', 21),
#  (u'experimentally.', 1),
#  (u'pressure.', 1),
#  (u'glass.', 4),
#  (u'tinge', 1),
#  (u'ladies!', 1),
#  (u'doubt.', 6),
#  (u'money.', 2),
#  (u'fissures', 1),
#  (u'solemnly:--', 8),
#  (u'gleaming', 3),
#  (u'humming', 1),
#  (u'256', 1),
#  (u'lighthouse', 2),
#  (u'laughed--such', 1),
#  (u'union', 1),
#  (u'fro', 4),
#  (u'breathlessly', 2),
#  (u'brusquely:--', 1),
#  (u'reasons;', 1),
#  (u'privilege', 8),
#  (u'deliberately', 2),
#  (u'home"--as', 1),
#  (u'"one', 2),
#  (u'dots', 2),
#  (u'life', 108),
#  (u'needed.', 2),
#  (u'athwart', 1),
#  (u'snap', 1),
#  (u'mrrning', 1),
#  (u'held.', 1),
#  (u'worked', 8),
#  (u'spin', 2),
#  (u'tried.', 2),
#  (u'contingencies', 1),
#  (u'professionally', 1),
#  (u'angry;', 1),
#  (u'rests', 1),
#  (u'"dr.', 12),
#  (u'answered:--', 10),
#  (u'silence;', 1),
#  (u'remembering', 1),
#  (u'said:', 19),
#  (u'jutting', 1),
#  (u'reports', 1),
#  (u'hay-ricks', 1),
#  (u'said.', 38),
#  (u'hell-home', 1),
#  (u'now!"', 1),
#  (u'reflectively', 1),
#  (u'"before', 1),
#  (u'increased.', 1),
#  (u'shock:', 1),
#  (u'light!"', 1),
#  (u'tops', 3),
#  (u'ownership', 1),
#  (u'expostulate.', 1),
#  (u"i'm", 13),
#  (u'tune', 1),
#  (u'thing:', 1),
#  (u'hoarsely:--', 1),
#  (u'attempted.', 1),
#  (u'stupendous', 1),
#  (u'gateway.', 2),
#  (u'redeem', 2),
#  (u'echoed', 1),
#  (u'victim."', 1),
#  (u'unhook', 1),
#  (u'thing.', 2),
#  (u'ascending.', 1),
#  (u'rally.', 1),
#  (u'addresses.', 1),
#  (u'sleeps', 8),
#  (u'sleepy', 12),
#  (u'beset', 2),
#  (u'succeeding', 1),
#  (u'handshake', 1),
#  (u'old-fashioned', 2),
#  (u'had', 1034),
#  (u'september_.--jonathan', 1),
#  (u'telegram:--', 1),
#  (u'beloved', 6),
#  (u'hap', 1),
#  (u'hat', 12),
#  (u'good-humoured', 1),
#  (u'"pearl', 1),
#  (u'delay."', 1),
#  (u'casually', 1),
#  (u'sleep?', 2),
#  (u'sleep;', 8),
#  (u'grey.', 1),
#  (u'indicative', 2),
#  (u'clustered', 1),
#  (u'imposed', 1),
#  (u'shadow', 14),
#  (u'opinion.', 1),
#  (u'massively', 1),
#  (u'desire', 11),
#  (u'brought', 36),
#  (u'misled', 2),
#  (u'steps', 15),
#  (u'enter.', 4),
#  (u'beneficial', 2),
#  (u'old', 182),
#  (u'jackets', 1),
#  (u'crowd', 7),
#  (u'creed', 1),
#  (u'crown', 1),
#  (u'begin', 22),
#  (u'rested.', 1),
#  (u'tooked', 1),
#  (u'left.', 1),
#  (u'creep', 3),
#  (u'chorus', 2),
#  (u'perchance', 1),
#  (u'for', 1514),
#  (u'fox', 4),
#  (u'him--without', 1),
#  (u'shelter;', 1),
#  (u'horrors;', 1),
#  (u'yields', 2),
#  (u'pinched', 2),
#  (u'"she\'s', 1),
#  (u'brain-matter', 1),
#  (u'rail._--there', 1),
#  (u'1.f.5.', 1),
#  (u'mad?"', 1),
#  (u'yoke', 1),
#  (u'losing', 4),
#  (u'conclusion.', 3),
#  (u'shaken', 2),
#  (u'stoker', 5),
#  (u'said:--', 106),
#  (u'hoast', 1),
#  (u'recollect', 1),
#  (u'slightly', 8),
#  (u'interrogatively:--', 1),
#  (u'raised', 35),
#  (u'statements', 1),
#  (u"potter's", 2),
#  (u'beings', 2),
#  (u'magazines', 2),
#  (u'could....', 1),
#  (u'wrap', 1),
#  (u'journeying', 1),
#  (u'due.', 2),
#  (u'sails--no', 1),
#  (u'clever.', 2),
#  (u'lay.', 3),
#  (u'support', 4),
#  (u'turn:--', 1),
#  (u'avail', 2),
#  (u'absolutely', 11),
#  (u'despises', 1),
#  (u'out-argue', 1),
#  (u'call', 48),
#  (u'so!', 4),
#  (u'spurting', 1),
#  (u'right"', 1),
#  (u'course!"', 1),
#  (u'fascination', 4),
#  (u'tigers', 1),
#  (u'kiss?', 1),
#  (u'ears:--', 1),
#  (u'brute.', 1),
#  (u'beech', 1),
#  (u'wedding-day', 1),
#  (u'right.', 15),
#  (u'so?', 8),
#  (u'hall.', 4),
#  (u'mirthless', 1),
#  (u'ignorance.', 1),
#  (u'type', 3),
#  (u'inside', 4),
#  (u'sobbing.', 1),
#  (u'floor--indeed', 1),
#  (u'nicest', 1),
#  (u'_20', 3),
#  (u'solicitor.', 1),
#  (u'soldering', 1),
#  (u'mighty', 11),
#  (u'menace:--', 1),
#  (u'proved', 8),
#  (u'bigamist."', 1),
#  (u'unnerve', 1),
#  (u'soothe', 1),
#  (u'melan', 1),
#  (u'say."', 1),
#  (u'typescript.', 1),
#  (u'"yours', 7),
#  (u'holy', 12),
#  (u'protect."', 1),
#  (u'count!', 2),
#  (u'learn----"', 1),
#  (u'smell', 11),
#  (u'mina"', 5),
#  (u'intend', 2),
#  (u'mourner.', 1),
#  (u'palms', 4),
#  (u'mina.', 14),
#  (u"'e", 6),
#  (u'intent', 6),
#  (u'rolling', 6),
#  (u"'i", 4),
#  (u'restored;', 1),
#  (u'fastened', 10),
#  (u'beamed', 1),
#  (u'push', 5),
#  (u'decision', 1),
#  (u'detective', 1),
#  (u'chain', 3),
#  (u'stay.', 1),
#  (u'"_it_', 1),
#  (u'chair', 11),
#  (u'noon._--most', 1),
#  (u'midst', 11),
#  (u'quartered', 1),
#  (u'ballet', 1),
#  (u'good"', 1),
#  (u'suppressed;', 1),
#  (u'tea"', 1),
#  (u'fatigues', 1),
#  (u'recipe', 2),
#  (u'child:', 1),
#  (u'manifested;', 1),
#  (u'child"', 1),
#  (u'mourn', 1),
#  (u'exact', 9),
#  (u'child.', 10),
#  (u'howling.', 1),
#  (u'tear', 5),
#  (u'leave', 54),
#  (u'resolutely', 3),
#  (u'unaware', 1),
#  (u'spiritual', 8),
#  (u'attic', 1),
#  (u'hush!', 4),
#  (u'carpet.', 1),
#  (u'saw?', 1),
#  (u'dust;', 2),
#  (u'pretty;', 1),
#  (u'melt', 3),
#  (u'current', 2),
#  (u'deadening', 1),
#  (u'falling', 19),
#  (u'peculiarly', 3),
#  (u'chapel?"', 1),
#  (u'funeral', 7),
#  (u'trail.', 1),
#  (u'yards', 2),
#  (u'alone', 55),
#  (u'along', 44),
#  (u'momentous', 2),
#  (u'howled.', 1),
#  (u'brilliant', 5),
#  (u'banqueted', 1),
#  (u'commonly', 1),
#  (u'accomplished', 1),
#  (u'crumbled', 1),
#  (u'god!"', 7),
#  (u'copper.', 1),
#  (u'night-existence', 1),
#  (u'safety-pin;', 1),
#  (u'love', 69),
#  (u'terribly.', 2),
#  (u'logical', 2),
#  (u'betraying', 2),
#  (u'undergone', 1),
#  (u'wounded?"', 1),
#  (u'working', 18),
#  (u'angry', 12),
#  (u'preternatural', 1),
#  (u'tightly', 1),
#  (u'good-bye."', 1),
#  (u'wondering', 1),
#  (u'bank-notes', 1),
#  (u'sunburst', 1),
#  (u'_later._--another', 2),
#  (u'triumphantly.', 1),
#  (u'not--take?"', 1),
#  (u'thought."', 2),
#  (u'wonders.', 1),
#  (u'"monster', 1),
#  (u'everywhere', 5),
#  (u'blood.', 13),
#  (u'behalf', 2),
#  (u'passing....', 1),
#  (u'shrill', 1),
#  (u'originally', 1),
#  (u'imagination.', 1),
#  (u"'bloofer", 2),
#  (u'nether', 2),
#  (u'values', 1),
#  (u'slowness', 1),
#  (u'believed', 3),
#  (u'caution', 4),
#  (u'unequalled', 1),
#  (u'heard.', 4),
#  (u'stole', 7),
#  (u'kindness.', 2),
#  (u'suspicion--which', 1),
#  (u'grosset', 4),
#  (u'divided', 1),
#  (u'thunder.', 1),
#  (u'thanking', 1),
#  (u'underneath;', 1),
#  (u'"there\'s', 3),
#  (u'echo.', 1),
#  (u'spot', 7),
#  (u'chimney-pots', 1),
#  (u'date', 3),
#  (u'mirror.', 1),
#  (u'dove', 1),
#  (u'there?"', 3),
#  (u'lids', 1),
#  (u'stress', 1),
#  (u'natural', 9),
#  (u'("the', 1),
#  (u'so', 1031),
#  (u'doom.', 2),
#  (u'wolves', 32),
#  (u'pulled', 17),
#  (u'_rufus', 2),
#  (u'themes;', 1),
#  (u"'avin'", 1),
#  (u'unsolicited', 1),
#  (u'"god!', 2),
#  (u'heraldic', 1),
#  (u'record.', 3),
#  (u'tired!"', 1),
#  (u'yearn', 1),
#  (u'horrify', 1),
#  (u'lovelier', 1),
#  (u'tore', 4),
#  (u'machine', 2),
#  (u'limbs', 3),
#  (u'did!', 1),
#  (u'troubles', 2),
#  (u'shape--saw', 1),
#  (u'suspicion', 5),
#  (u'celebrate', 1),
#  (u'"excuse', 1),
#  (u'dead!', 1),
#  (u'relapsed', 1),
#  (u'petition', 1),
#  (u'matches', 1),
#  (u'experiment.', 1),
#  (u'year.', 2),
#  (u'compelled', 1),
#  (u'shudder;', 1),
#  (u'arriving', 2),
#  (u'twilight', 2),
#  (u'maintaining', 1),
#  (u'trouble?', 3),
#  (u'trouble;', 1),
#  (u'fully.', 1),
#  (u'creation.', 1),
#  (u'imprisoned;', 1),
#  (u'veins', 16),
#  (u'repaired', 1),
#  (u'seldom', 1),
#  (u'quit.', 1),
#  (u'bursting', 2),
#  (u'small;', 1),
#  (u'concerned;', 1),
#  (u'were:--', 1),
#  (u'entering', 11),
#  (u'neighbourhood', 6),
#  (u'canvas', 1),
#  (u'organize.', 1),
#  (u'her--even', 1),
#  (u'log-book', 1),
#  (u'holmwood.', 4),
#  (u'astray', 1),
#  (u'profanation', 1),
#  (u'seriously', 1),
#  (u'dead."', 2),
#  (u'suggesting', 2),
#  (u'flurries', 1),
#  (u'siege', 1),
#  (u'seventh', 1),
#  (u'possibility', 7),
#  (u'"right', 3),
#  (u'route_', 1),
#  (u'besides', 14),
#  (u'yews', 1),
#  (u'disguised', 1),
#  (u'what--have', 1),
#  (u'discussing', 1),
#  (u'modest', 1),
#  (u'husband', 40),
#  (u'magnifico_;', 1),
#  (u'emotion', 4),
#  (u'intuition', 1),
#  (u'laws--why', 1),
#  (u'spoken', 22),
#  (u'consultation:--', 1),
#  (u'gases', 1),
#  (u'vote', 1),
#  (u'\xa31', 1),
#  (u'open', 92),
#  (u'help--that', 1),
#  (u'bite', 2),
#  (u'coat.', 1),
#  (u'careful.', 1),
#  (u'work?"', 2),
#  (u'stuffed', 1),
#  (u'1.f.3.', 2),
#  (u'on"', 3),
#  (u'shawl', 3),
#  (u'proving', 1),
#  (u'much.', 13),
#  (u'on:', 12),
#  (u'cold;', 3),
#  (u'berserker', 1),
#  (u'representing', 1),
#  (u'much-tried', 1),
#  (u"a-belderin'.", 1),
#  (u'depressed', 1),
#  (u'bit;', 4),
#  (u'blood-dripping', 1),
#  (u'backsheesh.', 1),
#  (u'wandering', 2),
#  (u'chaplet', 1),
#  (u'prospect', 2),
#  (u'addressing', 2),
#  (u'coroner.', 1),
#  (u'sam', 5),
#  (u"forest.'", 1),
#  (u'turned', 83),
#  (u'alley', 2),
#  (u'tastes', 1),
#  (u'be--no', 1),
#  (u'look:--', 1),
#  (u'saw', 211),
#  (u'this."', 2),
#  (u'law.', 3),
#  (u'locations.', 1),
#  (u'touch;', 1),
#  (u'downwards', 2),
#  (u'still.', 13),
#  (u'note', 17),
#  (u'unmoved.', 1),
#  (u'them--cracked', 1),
#  (u'handing', 2),
#  (u'worn-looking', 1),
#  (u'afternoon.', 1),
#  (u'abut', 1),
#  (u'inserted', 1),
#  (u'death-robe.', 1),
#  (u'lawn', 6),
#  (u'average', 1),
#  (u'not;', 9),
#  (u'something.', 7),
#  (u'ways', 17),
#  (u'bade', 4),
#  (u'october._', 1),
#  (u'salt', 2),
#  (u'schoolmistress', 1),
#  (u'operations', 2),
#  (u'walking', 6),
#  (u'vulgarised', 1),
#  (u'lotus', 1),
#  (u'bright', 24),
#  (u'helpless;', 2),
#  (u'imagined', 2),
#  (u'line', 12),
#  (u'relief.', 1),
#  (u'lanterns:', 1),
#  (u'case....', 1),
#  (u'hieroglyphical', 1),
#  (u'cause."', 2),
#  (u'3', 3),
#  (u'enclose', 2),
#  (u'tears', 17),
#  (u'outrage', 1),
#  (u'blinds', 3),
#  (u'darkness.', 6),
#  (u'usual.', 6),
#  (u'infallibly', 2),
#  (u'shining.', 1),
#  (u'clang', 1),
#  (u'usual:', 1),
#  (u'keys;', 1),
#  (u'to-night."', 1),
#  (u'keys?', 1),
#  (u'life."', 1),
#  (u'resource', 1),
#  (u'keenly', 5),
#  (u'blind!', 1),
#  (u'hinges', 4),
#  (u'lunatic:--', 1),
#  (u'befall', 1),
#  (u'blind;', 1),
#  (u'landlord', 2),
#  (u'where', 210),
#  (u'"quick!"', 1),
#  (u'home-coming', 2),
#  (u'screwed', 1),
#  (u'hastened', 1),
#  (u'aroused', 2),
#  (u'compliance.', 1),
#  (u'cheerfully:', 2),
#  (u'navigated', 1),
#  (u'enjoys', 1),
#  (u'presage', 4),
#  (u'man.', 18),
#  (u'jobs', 1),
#  (u'spare', 2),
#  (u'quondam', 1),
#  (u'deathly', 4),
#  (u'spark', 1),
#  (u'emblemship', 1),
#  (u'concentrated', 3),
#  (u'deck.', 1),
#  (u'moon.', 2),
#  (u'west.', 2),
#  (u'fear."', 1),
#  (u'expression', 8),
#  (u'ready;', 2),
#  (u"can't", 29),
#  (u'side.', 11),
#  (u'inclining', 1),
#  (u'furtherer', 1),
#  (u'superstition--are', 1),
#  (u'compels', 1),
#  (u'settled;', 1),
#  (u'fly-box', 1),
#  (u'reading.', 1),
#  (u'"agreed!"', 1),
#  (u'dutiful', 1),
#  (u'boat', 15),
#  (u'stretch', 3),
#  (u'reveal.', 1),
#  (u'breath', 18),
#  (u'raging', 1),
#  (u'mutilating', 1),
#  (u'motives', 1),
#  (u'reflex', 1),
#  (u'distorted--nay', 1),
#  (u'wants', 17),
#  (u'"life"', 1),
#  (u'life-giving', 1),
#  (u'influence', 6),
#  (u'thousand', 10),
#  (u'singly', 2),
#  (u'acquiring', 1),
#  (u'folding', 1),
#  (u'september._--after', 2),
#  (u'admirable', 1),
#  (u'prominence', 1),
#  (u'single', 7),
#  (u'confidently', 1),
#  (u'newspaper', 1),
#  (u'trephining', 1),
#  (u'endured', 2),
#  (u'fail;', 1),
#  (u'journal--_continued_', 3),
#  (u'brow', 1),
#  (u'engaged', 8),
#  (u'regularity', 1),
#  (u'trained', 1),
#  (u'pleading--i', 1),
#  (u'wire.', 1),
#  (u'death--nay', 1),
#  (u'verified', 2),
#  (u'concealment', 2),
#  (u'preparatory', 1),
#  (u'perpetually', 3),
#  (u'data', 3),
#  (u'slovaks', 12),
#  (u'alight.', 1),
#  (u'defy', 1),
#  (u'night._--all', 1),
#  (u'_is_', 2),
#  (u"host's", 2),
#  (u'way!', 1),
#  (u'heart--of', 1),
#  (u'shut;', 1),
#  (u'jonathan--nay', 1),
#  (u'masks', 1),
#  (u'persistently', 1),
#  (u'216', 1),
#  (u'manifold', 2),
#  (u'officers.', 1),
#  (u'disconcert', 1),
#  (u'rest', 74),
#  (u'necessary."', 1),
#  (u'fateful', 1),
#  (u'snarled', 1),
#  (u'mattock', 1),
#  (u'"doctor', 1),
#  (u'depity"', 1),
#  (u'loudly.', 2),
#  (u'prominently', 2),
#  (u'strange.', 2),
#  (u'woman!"', 2),
#  (u"bein'", 2),
#  (u"arthur's", 13),
#  (u'sums', 1),
#  (u'dark', 61),
#  (u'remaining.', 1),
#  (u'traffic', 1),
#  (u'snare', 1),
#  (u'dare', 20),
#  (u'60', 1),
#  (u'posted.', 2),
#  (u'stranger', 7),
#  (u'clad', 3),
#  (u'experimenting?', 1),
#  (u'warmly;', 1),
#  (u'dizzy.', 1),
#  (u'clap', 1),
#  (u'obstruct', 1),
#  (u'completest', 1),
#  (u'superintendent', 1),
#  (u'learning', 3),
#  (u'lowrey--i', 1),
#  (u'grup', 1),
#  (u'_1', 12),
#  (u'suffer--both', 1),
#  (u'accidental', 1),
#  (u'noon', 12),
#  (u'tots', 1),
#  (u'neck.', 7),
#  (u'exit', 1),
#  (u'charge....', 1),
#  (u'tubs', 1),
#  (u'restoring', 2),
#  (u'think.', 13),
#  (u'precious;', 1),
#  (u'power', 36),
#  (u'exultantly', 1),
#  (u'waited;', 1),
#  (u'facts--bare', 1),
#  (u'went', 296),
#  (u'_later._--glad', 1),
#  (u'stone', 19),
#  (u'slender', 2),
#  (u'wodin', 1),
#  (u'countenance;', 1),
#  (u'stony', 2),
#  (u'forehead!', 1),
#  (u'hypnotism', 2),
#  (u'antidote', 2),
#  (u'hypnotise', 12),
#  (u'clarion.', 1),
#  (u'rest....', 1),
#  (u'burglar', 1),
#  (u'woes', 2),
#  (u'her', 948),
#  (u'bristles', 1),
#  (u'glean', 1),
#  (u'sealed', 6),
#  (u'punished', 1),
#  (u'slopes', 1),
#  (u'animiles', 3),
#  (u'another;', 1),
#  (u'6:46', 1),
#  (u'foreheads', 1),
#  (u'survived', 3),
#  (u'another!', 1),
#  (u'with', 1314),
#  (u'buying', 1),
#  (u'rush', 7),
#  (u'wafer', 9),
#  (u'matters:--', 1),
#  (u'intrude', 1),
#  (u'thought....', 1),
#  (u'sisters;', 1),
#  (u'lunatic-asylum', 1),
#  (u'500', 1),
#  (u'age', 13),
#  (u'rust', 1),
#  (u'buoyancy;', 1),
#  (u'fright', 6),
#  (u'exhausted', 7),
#  (u'wards', 1),
#  (u'ak', 1),
#  (u'am', 327),
#  (u'or----"', 1),
#  (u'watches', 1),
#  (u'as', 1573),
#  (u'fumbling', 2),
#  (u'ay', 5),
#  (u'tranquil', 1),
#  (u'tremble', 4),
#  (u'whit', 1),
#  (u'shakes.', 1),
#  (u'novice', 1),
#  (u'lightly--for', 1),
#  ...]

# %% [markdown]
# Get all words that occur more than once and sort them alphabetically:

# %%
# Sorting alphabetically the words occuring more than once :

# First, we use filter to take only the tuples where the second element is strictly higher than 1.
frequent_words=reduce_words.filter(lambda (x,y) : y>1)

# Then, we sort the corresponding list.
sorted(frequent_words.collect())
# Out:
# [(u'"\'my', 2),
#  (u'"_17', 4),
#  (u'"_2', 2),
#  (u'"_24', 2),
#  (u'"_25', 4),
#  (u'"_6', 2),
#  (u'"_czarina', 2),
#  (u'"a', 12),
#  (u'"ah', 18),
#  (u'"aha!"', 2),
#  (u'"all', 8),
#  (u'"am', 2),
#  (u'"and', 53),
#  (u'"are', 5),
#  (u'"arthur!', 2),
#  (u'"as', 6),
#  (u'"at', 3),
#  (u'"be', 2),
#  (u'"because', 8),
#  (u'"because"', 2),
#  (u'"believe', 3),
#  (u'"bloofer', 6),
#  (u'"brave', 2),
#  (u'"but', 36),
#  (u'"but"', 4),
#  (u'"by', 3),
#  (u'"can', 4),
#  (u'"certainly', 2),
#  (u'"come', 14),
#  (u'"come!"', 3),
#  (u'"come"', 4),
#  (u'"count', 4),
#  (u'"darkness', 3),
#  (u'"dear', 6),
#  (u'"did', 3),
#  (u'"do', 20),
#  (u'"don\'t', 3),
#  (u'"dr.', 12),
#  (u'"except', 2),
#  (u'"fifty', 2),
#  (u'"for', 8),
#  (u'"forgive', 4),
#  (u'"friend', 11),
#  (u'"go', 8),
#  (u'"god', 4),
#  (u'"god!', 2),
#  (u'"good', 7),
#  (u'"good!"', 4),
#  (u'"good-bye', 2),
#  (u'"have', 6),
#  (u'"he', 15),
#  (u'"here', 2),
#  (u'"his', 3),
#  (u'"how', 16),
#  (u'"hush!', 2),
#  (u'"i', 169),
#  (u'"i\'ll', 3),
#  (u'"i\'m', 3),
#  (u'"if', 9),
#  (u'"in', 10),
#  (u'"is', 7),
#  (u'"it', 32),
#  (u'"jack', 4),
#  (u'"john', 2),
#  (u'"jonathan', 5),
#  (u'"just', 2),
#  (u'"let', 8),
#  (u'"little', 2),
#  (u'"look', 4),
#  (u'"look!', 3),
#  (u'"lord', 2),
#  (u'"lucy', 2),
#  (u'"lucy.', 3),
#  (u'"madam', 3),
#  (u'"may', 10),
#  (u'"me', 2),
#  (u'"mein', 2),
#  (u'"mina', 4),
#  (u'"mrs.', 2),
#  (u'"must', 2),
#  (u'"my', 41),
#  (u'"nay', 3),
#  (u'"new', 2),
#  (u'"new-fangled', 2),
#  (u'"no', 13),
#  (u'"no!', 3),
#  (u'"no!"', 2),
#  (u'"no"', 6),
#  (u'"not', 12),
#  (u'"now', 14),
#  (u'"now"', 2),
#  (u'"of', 4),
#  (u'"oh', 36),
#  (u'"oh"', 2),
#  (u'"one', 2),
#  (u'"our', 2),
#  (u'"p.', 3),
#  (u'"perhaps', 3),
#  (u'"plain', 2),
#  (u'"professor', 3),
#  (u'"project', 5),
#  (u'"quincey', 3),
#  (u'"quite', 3),
#  (u'"read', 2),
#  (u'"right', 3),
#  (u'"see"', 2),
#  (u'"shall', 2),
#  (u'"she', 10),
#  (u'"shut', 2),
#  (u'"so', 8),
#  (u'"such', 2),
#  (u'"take', 7),
#  (u'"tell', 7),
#  (u'"thank', 3),
#  (u'"that', 21),
#  (u'"that\'s', 6),
#  (u'"the', 43),
#  (u'"then', 26),
#  (u'"there', 15),
#  (u'"there\'s', 3),
#  (u'"they', 8),
#  (u'"this', 9),
#  (u'"to', 9),
#  (u'"to-morrow', 2),
#  (u'"unless', 2),
#  (u'"van', 4),
#  (u'"we', 33),
#  (u'"welcome', 2),
#  (u'"well', 20),
#  (u'"well"', 2),
#  (u'"well?"', 3),
#  (u'"what', 34),
#  (u'"when', 13),
#  (u'"where', 3),
#  (u'"why', 11),
#  (u'"why?"', 3),
#  (u'"will', 2),
#  (u'"with', 2),
#  (u'"would', 4),
#  (u'"yes', 7),
#  (u'"yes"', 3),
#  (u'"you', 61),
#  (u'"your', 11),
#  (u'"yours', 7),
#  (u'"yus;', 2),
#  (u'&', 21),
#  (u"'a'", 3),
#  (u"'ad", 6),
#  (u"'all", 2),
#  (u"'are", 2),
#  (u"'arf-quid", 2),
#  (u"'armony", 2),
#  (u"'at", 2),
#  (u"'ave", 2),
#  (u"'bloofer", 2),
#  (u"'e", 6),
#  (u"'elped", 2),
#  (u"'ere", 8),
#  (u"'here", 2),
#  (u"'i", 4),
#  (u"'igh", 2),
#  (u"'im", 6),
#  (u"'im.", 2),
#  (u"'is", 2),
#  (u"'isself", 2),
#  (u"'ittin'", 2),
#  (u"'no';", 2),
#  (u"'ole", 2),
#  (u"'ome", 2),
#  (u"'ouse", 5),
#  (u"'ow", 3),
#  (u"'owl", 2),
#  (u"'rats", 2),
#  (u'(_mem._', 6),
#  (u'(or', 3),
#  (u'(this', 2),
#  (u'(unopened', 2),
#  (u'*', 655),
#  (u'***', 6),
#  (u'*****', 2),
#  (u'-', 7),
#  (u'...', 11),
#  (u'1.', 2),
#  (u'1.e.1', 3),
#  (u'1.e.1.', 2),
#  (u'1.e.7', 2),
#  (u'1.e.8', 2),
#  (u'1.e.8.', 2),
#  (u'1.e.9.', 3),
#  (u'1.f.3', 3),
#  (u'1.f.3.', 2),
#  (u'10:30', 2),
#  (u'11', 2),
#  (u'12', 2),
#  (u'14', 2),
#  (u'16', 4),
#  (u'18', 2),
#  (u'2.', 2),
#  (u'24', 3),
#  (u'25', 4),
#  (u'3', 3),
#  (u'3.', 2),
#  (u'30', 2),
#  (u'4', 5),
#  (u'5', 2),
#  (u'501(c)(3)', 2),
#  (u'6', 2),
#  (u'6:30', 2),
#  (u'7', 4),
#  (u'8', 2),
#  (u'90', 2),
#  (u'_"the', 3),
#  (u'_1', 12),
#  (u'_10', 3),
#  (u'_11', 5),
#  (u'_12', 3),
#  (u'_13', 2),
#  (u'_15', 3),
#  (u'_17', 6),
#  (u'_18', 5),
#  (u'_19', 5),
#  (u'_2', 8),
#  (u'_20', 3),
#  (u'_22', 3),
#  (u'_23', 2),
#  (u'_24', 5),
#  (u'_25', 6),
#  (u'_26', 4),
#  (u'_27', 3),
#  (u'_28', 5),
#  (u'_29', 9),
#  (u'_3', 7),
#  (u'_30', 11),
#  (u'_31', 3),
#  (u'_4', 8),
#  (u'_5', 9),
#  (u'_6', 3),
#  (u'_7', 2),
#  (u'_8', 4),
#  (u'_9', 3),
#  (u'_a', 2),
#  (u'_all_', 2),
#  (u'_always_', 2),
#  (u'_boyar_', 2),
#  (u'_by', 3),
#  (u'_czarina', 15),
#  (u'_demeter_', 2),
#  (u'_dr.', 27),
#  (u'_en', 3),
#  (u'_he_', 2),
#  (u'_her_', 2),
#  (u'_him_!"', 2),
#  (u'_in', 2),
#  (u'_is_', 2),
#  (u'_jonathan', 9),
#  (u'_knew_', 2),
#  (u'_know_', 5),
#  (u'_later._--another', 2),
#  (u'_later._--i', 3),
#  (u'_later._--it', 2),
#  (u'_later._--lord', 2),
#  (u'_letter', 20),
#  (u'_lucy', 4),
#  (u'_memorandum', 2),
#  (u'_mina', 16),
#  (u'_my_', 2),
#  (u'_nosferatu_', 2),
#  (u'_publishers_', 2),
#  (u'_rufus', 2),
#  (u'_same', 4),
#  (u'_something_', 2),
#  (u'_telegram', 8),
#  (u'_the', 3),
#  (u'_was_', 2),
#  (u'a', 2933),
#  (u"a'", 2),
#  (u"a-'idin'", 2),
#  (u"a-comin'", 3),
#  (u'a.', 7),
#  (u'abaft', 2),
#  (u'abandoned', 2),
#  (u'abating;', 2),
#  (u'abbey', 5),
#  (u'abbey.', 4),
#  (u'abide', 2),
#  (u'able', 47),
#  (u'abnormally', 2),
#  (u'aboard', 6),
#  (u'aboon', 2),
#  (u'aboot', 3),
#  (u'about', 233),
#  (u'about.', 5),
#  (u'above', 16),
#  (u'abraham', 3),
#  (u'abreast', 3),
#  (u'abroad', 4),
#  (u'abroad.', 2),
#  (u'absent', 2),
#  (u'absolute', 8),
#  (u'absolutely', 11),
#  (u'absorbed', 2),
#  (u'absorbing', 2),
#  (u'accept', 14),
#  (u'accept.', 2),
#  (u'accepted', 4),
#  (u'accepting', 3),
#  (u'accepts', 2),
#  (u'access', 11),
#  (u'accident', 5),
#  (u'accident.', 2),
#  (u'accord', 4),
#  (u'accord.', 2),
#  (u'accordance', 5),
#  (u'accordingly', 2),
#  (u'account', 21),
#  (u'accumulation', 2),
#  (u'accuracy', 3),
#  (u'accurate', 8),
#  (u'accurately', 2),
#  (u'accustomed', 7),
#  (u'achieve', 4),
#  (u'achieved', 3),
#  (u'acquiesced', 2),
#  (u'acquiesced.', 2),
#  (u'acquiescence', 3),
#  (u'acrid', 3),
#  (u'across', 25),
#  (u'across.', 3),
#  (u'act', 27),
#  (u'act.', 4),
#  (u'action', 14),
#  (u'action.', 5),
#  (u'actions', 3),
#  (u'active', 8),
#  (u'actual', 4),
#  (u'actually', 15),
#  (u'add', 9),
#  (u'added', 16),
#  (u'added:', 3),
#  (u'added:--', 6),
#  (u'addition', 3),
#  (u'additional', 6),
#  (u'address', 8),
#  (u'addressed', 4),
#  (u'addresses', 2),
#  (u'addressing', 2),
#  (u'adjusted', 2),
#  (u'admit', 7),
#  (u'advance', 4),
#  (u'advanced', 8),
#  (u'advanced.', 2),
#  (u'advantage', 3),
#  (u'adventure', 7),
#  (u'adventure.', 2),
#  (u'advise', 2),
#  (u'afar', 4),
#  (u'affair', 6),
#  (u'affair.', 2),
#  (u'affairs', 12),
#  (u'affect', 2),
#  (u'affected', 5),
#  (u'affects', 2),
#  (u'afford', 5),
#  (u'afield', 2),
#  (u'afore', 7),
#  (u'afraid', 36),
#  (u'afraid;', 2),
#  (u'afresh', 2),
#  (u'after', 206),
#  (u'afternoon', 15),
#  (u'afterwards', 11),
#  (u'afterwards.', 2),
#  (u'again', 169),
#  (u'again!', 6),
#  (u'again.', 52),
#  (u'again:', 3),
#  (u'again:--', 3),
#  (u'again;', 8),
#  (u'again?"', 3),
#  (u'against', 65),
#  (u'agatha', 4),
#  (u'age', 13),
#  (u'agency', 2),
#  (u'agent', 12),
#  (u'agents', 2),
#  (u'ages', 2),
#  (u'ago', 20),
#  (u'ago.', 5),
#  (u'agonised', 7),
#  (u'agonising', 3),
#  (u'agony', 7),
#  (u'agree', 14),
#  (u'agreed', 12),
#  (u'agreeing', 2),
#  (u'agreement', 18),
#  (u'agreement.', 3),
#  (u'ah', 9),
#  (u'ah!', 2),
#  (u'ahead', 7),
#  (u'aid', 15),
#  (u'aiding', 2),
#  (u'aids', 2),
#  (u'ain', 2),
#  (u"ain't", 12),
#  (u'air', 39),
#  (u'air.', 7),
#  (u'air;', 4),
#  (u'ajar', 2),
#  (u'alacrity', 2),
#  (u'alarm', 2),
#  (u'alarmed', 4),
#  (u'alas!', 16),
#  (u'alive', 8),
#  (u'all', 1089),
#  (u'all!', 4),
#  (u'all!"', 3),
#  (u'all.', 36),
#  (u'all."', 4),
#  (u'all;', 9),
#  (u'all?', 4),
#  (u'alley', 2),
#  (u'allow', 7),
#  (u'allowed', 3),
#  (u'almighty', 4),
#  (u'almost', 69),
#  (u'alone', 55),
#  (u'alone.', 18),
#  (u'alone."', 3),
#  (u'alone;', 4),
#  (u'along', 44),
#  (u'along.', 10),
#  (u'alongside', 2),
#  (u'already', 51),
#  (u'already.', 5),
#  (u'already."', 2),
#  (u'already;', 2),
#  (u'also', 36),
#  (u'also.', 2),
#  (u'also;', 2),
#  (u'also?"', 2),
#  (u'alternative', 2),
#  (u'although', 17),
#  (u'altogether', 10),
#  (u'altogether.', 4),
#  (u'always', 60),
#  (u'always.', 2),
#  (u'am', 327),
#  (u'am.', 2),
#  (u'amazed', 6),
#  (u'amazement', 5),
#  (u'amenable', 2),
#  (u'america', 3),
#  (u'american', 4),
#  (u'amid', 4),
#  (u'amidst', 2),
#  (u'among', 8),
#  (u'amongst', 40),
#  (u'amount', 9),
#  (u'amsterdam', 5),
#  (u'amsterdam.', 4),
#  (u'amsterdam._', 3),
#  (u'amused', 3),
#  (u'an', 296),
#  (u"an'", 61),
#  (u'analogy', 2),
#  (u'anchor', 3),
#  (u'ancient', 4),
#  (u'ancients', 2),
#  (u'and', 5840),
#  (u'and--and', 3),
#  (u'anent', 2),
#  (u'angel', 5),
#  (u'angels', 2),
#  (u'anger', 5),
#  (u'angle', 4),
#  (u'angrily', 3),
#  (u'angry', 12),
#  (u'angry.', 2),
#  (u'anguish', 3),
#  (u'animal', 7),
#  (u'animal.', 2),
#  (u'animals', 2),
#  (u'animals.', 2),
#  (u'animation', 2),
#  (u'animiles', 3),
#  (u'another', 71),
#  (u'another.', 6),
#  (u'answer', 36),
#  (u'answer.', 4),
#  (u'answer:--', 2),
#  (u'answered', 39),
#  (u'answered.', 8),
#  (u'answered:', 3),
#  (u'answered:--', 10),
#  (u'answering', 2),
#  (u'antidote', 2),
#  (u'anxiety', 12),
#  (u'anxiety.', 2),
#  (u'anxious', 22),
#  (u'anxious.', 4),
#  (u'anxiously', 2),
#  (u'any', 319),
#  (u'anybody', 2),
#  (u'anyhow', 5),
#  (u'anyhow.', 5),
#  (u'anyone', 5),
#  (u'anything', 82),
#  (u'anything!', 3),
#  (u'anything.', 9),
#  (u'anything."', 3),
#  (u'anywhere', 11),
#  (u'anywhere.', 6),
#  (u'an\xe6mic', 3),
#  (u'apart', 2),
#  (u'aperture', 3),
#  (u'apologised', 2),
#  (u'apology', 4),
#  (u'appalled', 5),
#  (u'appalling', 2),
#  (u'apparent', 5),
#  (u'apparently', 2),
#  (u'appeal', 3),
#  (u'appealing', 3),
#  (u'appealingly', 3),
#  (u'appear', 8),
#  (u'appearance', 4),
#  (u'appearance;', 2),
#  (u'appeared', 11),
#  (u'appears', 2),
#  (u'appeased', 3),
#  (u'appetite', 3),
#  (u'applicable', 3),
#  (u'apply', 2),
#  (u'approach', 5),
#  (u'approach.', 2),
#  (u'approved.', 2),
#  (u'apt', 2),
#  (u'aquiline', 3),
#  (u'arched', 4),
#  (u'archive', 13),
#  (u'archive)', 2),
#  (u'are', 583),
#  (u'are.', 4),
#  (u'are."', 2),
#  (u'are;', 2),
#  (u'area', 3),
#  (u'argue', 5),
#  (u'argument', 2),
#  (u'arguments', 2),
#  (u'arise', 2),
#  (u'arm', 22),
#  (u'arm.', 2),
#  (u'armed', 9),
#  (u'arminius', 2),
#  (u'armour', 2),
#  (u'arms', 24),
#  (u'arms.', 6),
#  (u'army', 2),
#  (u'around', 43),
#  (u'around.', 2),
#  (u'arouse', 3),
#  (u'aroused', 2),
#  (u'arrange', 9),
#  (u'arranged', 12),
#  (u'arranged.', 2),
#  (u'arrangements', 4),
#  (u'arranging', 2),
#  (u'arrayed', 3),
#  (u'arrival', 8),
#  (u'arrive', 16),
#  (u'arrived', 17),
#  (u'arrived.', 3),
#  (u'arrives', 3),
#  (u'arrives.', 2),
#  (u'arriving', 2),
#  (u'arsk', 5),
#  (u'art', 16),
#  (u'art--', 3),
#  (u'art.', 2),
#  (u'art."', 2),
#  (u'arter', 3),
#  (u'arthur', 111),
#  (u"arthur's", 13),
#  (u'arthur.', 11),
#  (u'arthur."', 2),
#  (u'arthur;', 2),
#  (u'as', 1573),
#  (u'ascended', 4),
#  (u'ascertain', 3),
#  (u'ascertained', 2),
#  (u'ascii"', 2),
#  (u'ashamed', 3),
#  (u'ashen', 3),
#  (u'aside', 5),
#  (u'aside.', 2),
#  (u'ask', 63),
#  (u'ask.', 3),
#  (u'asked', 121),
#  (u'asked.', 17),
#  (u'asked:--', 4),
#  (u'asking', 14),
#  (u'asks', 5),
#  (u'asleep', 34),
#  (u'asleep.', 10),
#  (u'asleep;', 2),
#  (u'assembled', 2),
#  (u'assent', 3),
#  (u'assented', 2),
#  (u'asserting', 2),
#  (u'assistant', 2),
#  (u'associated', 7),
#  (u'assurance', 3),
#  (u'assure', 3),
#  (u'assured', 8),
#  (u'astonished', 3),
#  (u'astonishment', 6),
#  (u'asylum', 10),
#  (u'asylum.', 2),
#  (u'at', 1084),
#  (u'at.', 3),
#  (u'ate', 2),
#  (u'atmosphere', 2),
#  (u'attached', 2),
#  (u'attack', 9),
#  (u'attack.', 4),
#  (u'attacked', 5),
#  (u'attempt', 6),
#  (u'attempt.', 2),
#  (u'attempting', 2),
#  (u'attend', 12),
#  (u'attendant', 23),
#  (u'attendants', 12),
#  (u'attended', 7),
#  (u'attending', 2),
#  (u'attention', 11),
#  (u'attention.', 3),
#  (u'attila', 2),
#  (u'attitude', 5),
#  (u'attract', 5),
#  (u'attributed', 2),
#  (u'aud', 3),
#  (u'aught', 2),
#  (u'aught.', 2),
#  (u'august', 5),
#  (u'august._', 6),
#  (u'august._--another', 4),
#  (u'august._--i', 3),
#  (u'august._--the', 3),
#  (u'austrian', 2),
#  (u'author', 2),
#  (u'authority', 2),
#  (u'autumn', 6),
#  (u'avail', 2),
#  (u'available', 7),
#  (u'available.', 2),
#  (u'avenue', 2),
#  (u'avenue.', 2),
#  (u'avoid', 8),
#  (u'avoided', 2),
#  (u'await', 4),
#  (u'awake', 21),
#  (u'awake.', 5),
#  (u'awaked', 2),
#  (u'awakened', 6),
#  (u'aware', 3),
#  (u'away', 149),
#  (u'away.', 31),
#  (u'away."', 2),
#  (u'away;', 3),
#  (u'awe', 2),
#  (u'awful', 29),
#  (u'awfully', 2),
#  (u'awhile', 7),
#  (u'awoke', 5),
#  (u'awoke.', 2),
#  (u'ay', 5),
#  (u'a\xebrial', 2),
#  (u'b.', 3),
#  (u'baby', 2),
#  (u'back', 235),
#  (u'back.', 14),
#  (u'back."', 2),
#  (u'back;', 4),
#  (u'backed', 2),
#  (u'background', 2),
#  (u'bad', 30),
#  (u'bad.', 2),
#  (u'bade', 4),
#  (u'baffle', 3),
#  (u'baffled', 3),
#  (u'bag', 24),
#  (u'bag.', 5),
#  (u'bag;', 2),
#  (u'bags', 2),
#  (u'balance', 3),
#  (u'balanced', 3),
#  (u'band', 9),
#  (u'bank', 6),
#  (u'banking', 2),
#  (u'banks', 3),
#  (u'baptism', 2),
#  (u'bare', 5),
#  (u'barely', 2),
#  (u'bark', 2),
#  (u'barking', 3),
#  (u'barred', 2),
#  (u'barren', 3),
#  (u'bars', 3),
#  (u'based', 3),
#  (u'basket', 2),
#  (u'bat', 9),
#  (u'batches', 2),
#  (u'bath', 3),
#  (u'bathed', 2),
#  (u'bats', 6),
#  (u'battle', 5),
#  (u'battlements', 3),
#  (u'bay', 6),
#  (u'be', 1074),
#  (u'be!', 2),
#  (u'be.', 28),
#  (u'be."', 4),
#  (u'be;', 12),
#  (u'beads', 3),
#  (u"bean't", 2),
#  (u'bear', 19),
#  (u'bear.', 2),
#  (u'bear;', 3),
#  (u'beard', 3),
#  (u'bearing', 6),
#  (u'beast', 4),
#  (u'beast.', 2),
#  (u'beasts', 2),
#  (u'beat', 16),
#  (u'beaten', 5),
#  (u'beating', 9),
#  (u'beats', 2),
#  (u'beautiful', 31),
#  (u'beautifully', 2),
#  (u'beauty', 14),
#  (u'became', 42),
#  (u'because', 45),
#  (u'beckoned', 4),
#  (u'become', 27),
#  (u'becomes', 2),
#  (u'becoming', 9),
#  (u'bed', 63),
#  (u'bed.', 21),
#  (u'bed;', 3),
#  (u'bedroom', 4),
#  (u'bedside', 3),
#  (u'been', 382),
#  (u'been.', 6),
#  (u'been."', 2),
#  (u'beer', 2),
#  (u'before', 254),
#  (u'before.', 14),
#  (u'before;', 4),
#  (u'beforehand', 2),
#  (u'beg', 3),
#  (u'began', 108),
#  (u'began:--', 4),
#  (u'begin', 22),
#  (u'begin."', 3),
#  (u'beginning', 31),
#  (u'begins', 7),
#  (u'begun', 9),
#  (u'begun.', 4),
#  (u'behalf', 2),
#  (u'behind', 51),
#  (u"bein'", 2),
#  (u'being', 81),
#  (u'beings', 2),
#  (u'belief', 16),
#  (u'belief.', 3),
#  (u'beliefs', 2),
#  (u'believe', 69),
#  (u'believed', 3),
#  (u'believes', 3),
#  (u'bell', 9),
#  (u'bells', 3),
#  (u'belly', 2),
#  (u'belonging', 2),
#  (u'belongings', 2),
#  (u'belongs', 2),
#  (u'beloved', 6),
#  (u'below', 17),
#  (u'below.', 8),
#  (u'belt', 4),
#  (u'belts', 2),
#  (u'bench', 2),
#  (u'bending', 5),
#  (u'beneath', 2),
#  (u'beneficent', 2),
#  (u'beneficial', 2),
#  (u'bent', 26),
#  (u'berkeley', 5),
#  (u'bermondsey', 2),
#  (u'bersicker', 6),
#  (u'beset', 2),
#  (u'beside', 33),
#  (u'besides', 14),
#  (u'best', 42),
#  (u'best.', 8),
#  (u'bethnal', 2),
#  (u'betray', 5),
#  (u'betrayed', 2),
#  (u'betraying', 2),
#  (u'better', 65),
#  (u'better.', 10),
#  (u'between', 70),
#  (u'bewildered', 5),
#  (u'beyond', 22),
#  (u'beyond.', 2),
#  (u'bid', 2),
#  (u'bidding', 3),
#  (u'big', 44),
#  (u'bigger', 2),
#  (u'bilder', 5),
#  (u'billington', 8),
#  (u'binding', 2),
#  (u'bird', 3),
#  (u'birds', 6),
#  (u'bistritz', 8),
#  (u'bistritz.', 2),
#  (u'bistritza', 4),
#  (u'bit', 11),
#  (u'bit.', 3),
#  (u'bit;', 4),
#  (u'bite', 2),
#  (u'bitten', 2),
#  (u'bitter', 21),
#  (u'black', 30),
#  (u'black.', 2),
#  (u'blackness', 2),
#  (u'blade', 2),
#  (u'blame', 2),
#  (u'blank', 5),
#  (u'blanket', 2),
#  (u'blast;', 2),
#  (u'blazed', 5),
#  (u'blazing', 3),
#  (u'bleating', 2),
#  (u'bled', 3),
#  (u'bleeding', 3),
#  (u'bless', 16),
#  (u'blessed', 11),
#  (u'blessing', 3),
#  (u'blessings', 5),
#  (u'blew', 9),
#  (u'blind', 13),
#  (u'blind.', 2),
#  (u'blindfold', 2),
#  (u'blinds', 3),
#  (u'blinked', 2),
#  (u'bloated', 3),
#  (u'blood', 80),
#  (u'blood-stained', 2),
#  (u'blood.', 13),
#  (u'blood."', 2),
#  (u'blood;', 6),
#  (u'bloody', 4),
#  (u'bloom', 5),
#  (u"bloomin'", 7),
#  (u'blot', 2),
#  (u'blotted', 3),
#  (u'blow', 7),
#  (u'blow-fly', 2),
#  (u'blowing', 4),
#  (u'bloxam', 4),
#  (u'blue', 14),
#  (u'blush', 5),
#  (u'blushing', 2),
#  (u'board', 13),
#  (u'board.', 4),
#  (u'boat', 15),
#  (u'boats', 7),
#  (u'bodies', 6),
#  (u'body', 48),
#  (u'body.', 4),
#  (u'bold', 2),
#  (u'boldly', 2),
#  (u'bolt', 6),
#  (u'bolts', 5),
#  (u'bone.', 2),
#  (u'bones', 6),
#  (u'book', 14),
#  (u'book.', 4),
#  (u'books', 17),
#  (u'boon', 2),
#  (u'boots', 2),
#  (u'bore', 7),
#  (u'borgo', 11),
#  (u'borne', 2),
#  (u'bosom', 4),
#  (u'both', 79),
#  (u'both.', 4),
#  (u'bottle', 5),
#  (u'bottom', 3),
#  (u'boudoir', 2),
#  (u'bought', 2),
#  (u'bound', 11),
#  (u'bow', 11),
#  (u'bowed', 11),
#  (u'bowed.', 2),
#  (u'bowie', 2),
#  (u'bows', 2),
#  (u'box', 42),
#  (u'box.', 7),
#  (u'box;', 2),
#  (u'boxes', 37),
#  (u'boxes.', 7),
#  (u'boy', 8),
#  (u'boy.', 3),
#  (u'braced', 2),
#  (u'brain', 34),
#  (u'brain.', 4),
#  (u'brains', 8),
#  (u'bram', 5),
#  (u'branch', 5),
#  (u'brandy', 7),
#  (u'brass', 2),
#  (u'brave', 30),
#  (u'bravely', 4),
#  (u'bravery', 2),
#  (u'breach', 2),
#  (u'break', 19),
#  (u'breakfast', 20),
#  (u'breakfast.', 3),
#  (u'breakfasted', 2),
#  (u'breaking', 4),
#  (u'breast', 13),
#  (u'breast.', 6),
#  (u'breast;', 3),
#  (u'breath', 18),
#  (u'breath.', 2),
#  (u'breathe', 2),
#  (u'breathes', 2),
#  (u'breathing', 26),
#  (u'breathlessly', 2),
#  (u'breeding', 2),
#  (u'breeze.', 2),
#  (u'bridge', 3),
#  (u'bright', 24),
#  (u'brightened', 4),
#  (u'brightly', 3),
#  (u'brilliant', 5),
#  (u'bring', 30),
#  (u'bringing', 7),
#  (u'brings', 6),
#  (u'british', 4),
#  (u'broad', 10),
#  (u'broke', 18),
#  (u'broke.', 2),
#  (u'broken', 27),
#  (u'broken.', 5),
#  (u'broken;', 2),
#  (u'brooding', 4),
#  (u'brother', 3),
#  (u'brought', 36),
#  (u'brown', 4),
#  (u'brows', 8),
#  (u'bruised', 2),
#  (u'brush', 3),
#  (u'brushed', 2),
#  (u'brute', 5),
#  (u'brutes', 2),
#  (u'bucharest', 2),
#  (u'buda-pesth', 4),
#  (u'buffeting', 4),
#  (u'building', 7),
#  (u'built', 5),
#  (u'bukovina', 4),
#  (u'bukovina.', 2),
#  (u'bulky', 2),
#  (u'bullet', 3),
#  (u'bunch', 6),
#  (u'bundle', 6),
#  (u'burden', 4),
#  (u'burglary', 2),
#  (u'burial', 5),
#  (u'buried', 10),
#  (u'burn', 4),
#  (u'burned', 6),
#  (u'burning', 8),
#  (u'burning.', 2),
#  (u'burnt', 2),
#  (u'burst', 7),
#  (u'bursting', 2),
#  (u'bursts', 2),
#  (u'bush', 2),
#  (u'bushy', 5),
#  (u'business', 18),
#  (u'business.', 2),
#  (u'busy', 8),
#  (u'but', 1028),
#  (u'buy', 4),
#  (u'buzzing', 5),
#  (u'by', 520),
#  (u'by-and-by', 5),
#  ...]

# %% [markdown]
# Now, get all words that occur more than once and sort them by frequency. Select the first 20. Hints : look at the `takeOrdered` action.

# %%
# Sorting by frequency the words occuring more than once :

# We use the takeOrdered action. The first argument corresponds to the number of words we want to select.
# We need to consider the opposite of the number of times a words appears, as takeOrdered uses an ascending order.
frequent_words.takeOrdered(20,key=lambda x: -x[1])
# Out:
# [(u'the', 7984),
#  (u'and', 5840),
#  (u'i', 4527),
#  (u'to', 4518),
#  (u'of', 3719),
#  (u'a', 2933),
#  (u'he', 2523),
#  (u'in', 2512),
#  (u'that', 2415),
#  (u'it', 1876),
#  (u'was', 1848),
#  (u'as', 1573),
#  (u'for', 1514),
#  (u'we', 1499),
#  (u'is', 1489),
#  (u'his', 1457),
#  (u'not', 1350),
#  (u'with', 1314),
#  (u'you', 1302),
#  (u'my', 1213)]

# %% [markdown]
# ### A simple exercice
#
# + Create a Python collection of 10,000 integers
# + Create a Spark base RDD from that collection
# + Subtract one from each value using map
# + Perform action collect to view results
# + Perform action count to view counts
# + Apply transformation filter and view results with collect

# %%
# We create a python collection (a list) of 10,000 random integers going from 0 to 4999 using numpy randint function.

import numpy as np

int_list = [ np.random.randint(5000) for i in range(10000)]

# %%
# We transform this list into a RDD with the function parallelize.

int_RDD = sc.parallelize(int_list)

# Checking the type of int_RDD :
type(int_RDD)
# Out:
# pyspark.rdd.RDD

# %%
# Then, we subtract one from each value.

# We use the map function :
sub_RDD = int_RDD.map(lambda x: x-1)

# We display the result by performing the action collect :
sub_RDD.collect()
# Out:
# [3039,
#  4141,
#  4778,
#  1468,
#  3638,
#  1012,
#  2976,
#  3859,
#  42,
#  3545,
#  4813,
#  2057,
#  598,
#  2928,
#  1724,
#  1466,
#  4859,
#  2491,
#  3309,
#  2102,
#  1407,
#  4609,
#  3783,
#  4300,
#  4927,
#  1299,
#  1450,
#  2345,
#  3616,
#  4251,
#  1589,
#  2629,
#  2790,
#  1430,
#  448,
#  3434,
#  4498,
#  3341,
#  1501,
#  1811,
#  4344,
#  2088,
#  4570,
#  1807,
#  3888,
#  2201,
#  1214,
#  3269,
#  1610,
#  780,
#  4028,
#  3936,
#  880,
#  1989,
#  1425,
#  4668,
#  4403,
#  4420,
#  2495,
#  4768,
#  1100,
#  789,
#  4440,
#  1279,
#  704,
#  3234,
#  179,
#  2968,
#  1369,
#  1834,
#  1030,
#  4198,
#  3003,
#  1670,
#  2842,
#  1931,
#  1634,
#  1125,
#  1065,
#  504,
#  1789,
#  293,
#  4455,
#  3589,
#  3522,
#  4477,
#  3089,
#  1156,
#  2395,
#  708,
#  1256,
#  2307,
#  1670,
#  2769,
#  1960,
#  4855,
#  3846,
#  3017,
#  3875,
#  476,
#  4915,
#  413,
#  2786,
#  3609,
#  738,
#  2148,
#  977,
#  4373,
#  3893,
#  1883,
#  3269,
#  987,
#  1028,
#  3898,
#  2465,
#  2253,
#  1485,
#  2064,
#  2072,
#  1508,
#  1409,
#  914,
#  4,
#  862,
#  4741,
#  4708,
#  422,
#  2626,
#  1495,
#  4174,
#  2091,
#  4765,
#  4070,
#  199,
#  3526,
#  4945,
#  3364,
#  3651,
#  2427,
#  3298,
#  1168,
#  1335,
#  1410,
#  2221,
#  4245,
#  4753,
#  3835,
#  1224,
#  4378,
#  3954,
#  1339,
#  703,
#  1980,
#  1802,
#  3089,
#  3844,
#  1856,
#  2788,
#  1050,
#  4836,
#  2571,
#  2743,
#  3560,
#  4805,
#  1679,
#  3895,
#  652,
#  4547,
#  1822,
#  4378,
#  1928,
#  2068,
#  914,
#  3852,
#  3964,
#  4424,
#  3909,
#  1863,
#  2605,
#  646,
#  2124,
#  3423,
#  3712,
#  4992,
#  1581,
#  2106,
#  3335,
#  4747,
#  1226,
#  1603,
#  3163,
#  3323,
#  4409,
#  2220,
#  3211,
#  868,
#  1769,
#  1108,
#  3719,
#  954,
#  1339,
#  3825,
#  2586,
#  4865,
#  3154,
#  1396,
#  1990,
#  2781,
#  2719,
#  1487,
#  947,
#  3718,
#  3179,
#  2277,
#  2983,
#  4036,
#  955,
#  3935,
#  1477,
#  1514,
#  1408,
#  297,
#  374,
#  1349,
#  3116,
#  1152,
#  2711,
#  1141,
#  2496,
#  2070,
#  691,
#  1713,
#  3393,
#  3059,
#  3012,
#  1704,
#  950,
#  1145,
#  3609,
#  1736,
#  1778,
#  2581,
#  4462,
#  1868,
#  1197,
#  3280,
#  876,
#  42,
#  1549,
#  542,
#  921,
#  4376,
#  4942,
#  1219,
#  3263,
#  3547,
#  835,
#  3201,
#  3569,
#  4896,
#  235,
#  1364,
#  4192,
#  4473,
#  2683,
#  4727,
#  153,
#  25,
#  639,
#  1468,
#  4250,
#  2455,
#  1810,
#  72,
#  4498,
#  1932,
#  4810,
#  278,
#  4455,
#  2019,
#  3876,
#  3250,
#  4316,
#  4450,
#  1244,
#  4818,
#  3946,
#  802,
#  2492,
#  236,
#  768,
#  4020,
#  4829,
#  741,
#  2165,
#  249,
#  1592,
#  1867,
#  2768,
#  4347,
#  756,
#  602,
#  4176,
#  4176,
#  4584,
#  4384,
#  945,
#  63,
#  785,
#  2326,
#  565,
#  335,
#  2792,
#  4784,
#  4413,
#  4277,
#  1109,
#  118,
#  130,
#  3902,
#  1335,
#  329,
#  3528,
#  4829,
#  186,
#  3936,
#  1145,
#  4967,
#  4247,
#  889,
#  2317,
#  2856,
#  2056,
#  2943,
#  1379,
#  104,
#  3795,
#  1593,
#  2479,
#  4494,
#  738,
#  3976,
#  1493,
#  3931,
#  4892,
#  1540,
#  1287,
#  4456,
#  1049,
#  3977,
#  2014,
#  1287,
#  183,
#  3540,
#  4339,
#  3159,
#  3911,
#  348,
#  4617,
#  2287,
#  2314,
#  4490,
#  4057,
#  2616,
#  4379,
#  1263,
#  2417,
#  2612,
#  591,
#  4609,
#  3060,
#  596,
#  1955,
#  4780,
#  281,
#  1071,
#  2715,
#  641,
#  3881,
#  4417,
#  1501,
#  4191,
#  4154,
#  4359,
#  290,
#  1161,
#  3229,
#  3204,
#  4987,
#  4660,
#  4796,
#  4173,
#  73,
#  454,
#  4182,
#  1383,
#  3046,
#  869,
#  610,
#  4490,
#  3683,
#  3491,
#  86,
#  2708,
#  1875,
#  2208,
#  1927,
#  1672,
#  2242,
#  2905,
#  1809,
#  1728,
#  2413,
#  2609,
#  1265,
#  2216,
#  165,
#  2972,
#  886,
#  4115,
#  969,
#  4112,
#  1164,
#  4158,
#  1681,
#  3243,
#  4136,
#  4583,
#  4841,
#  1663,
#  4935,
#  1406,
#  2933,
#  169,
#  4094,
#  4493,
#  3240,
#  4847,
#  3954,
#  1904,
#  4766,
#  715,
#  4125,
#  2880,
#  983,
#  4926,
#  1563,
#  2789,
#  4174,
#  3017,
#  1810,
#  3311,
#  1575,
#  4121,
#  1345,
#  3977,
#  4865,
#  3834,
#  4312,
#  4013,
#  4994,
#  1439,
#  2680,
#  1588,
#  1794,
#  4963,
#  712,
#  4724,
#  1276,
#  3293,
#  2965,
#  4074,
#  4352,
#  1826,
#  3330,
#  2731,
#  2708,
#  3673,
#  4887,
#  4959,
#  1913,
#  1888,
#  3136,
#  2734,
#  4864,
#  3729,
#  2023,
#  4530,
#  908,
#  611,
#  4953,
#  1526,
#  2094,
#  4223,
#  2993,
#  1430,
#  21,
#  818,
#  3948,
#  317,
#  672,
#  330,
#  1045,
#  2318,
#  1087,
#  301,
#  2031,
#  4460,
#  191,
#  65,
#  2746,
#  2272,
#  2635,
#  1765,
#  1279,
#  1830,
#  2522,
#  4853,
#  1429,
#  1153,
#  1599,
#  3240,
#  911,
#  3661,
#  1117,
#  3252,
#  1455,
#  1179,
#  1959,
#  1609,
#  3036,
#  748,
#  2536,
#  2822,
#  4548,
#  4974,
#  4096,
#  2455,
#  1749,
#  1644,
#  2494,
#  3828,
#  2139,
#  2717,
#  2863,
#  1730,
#  1914,
#  1255,
#  3123,
#  3210,
#  1126,
#  3898,
#  3787,
#  724,
#  4799,
#  4584,
#  2337,
#  3930,
#  2905,
#  521,
#  43,
#  3102,
#  1912,
#  4218,
#  2844,
#  3308,
#  877,
#  2707,
#  2417,
#  2386,
#  4839,
#  1052,
#  2072,
#  2365,
#  48,
#  4515,
#  2285,
#  2193,
#  1056,
#  2563,
#  1990,
#  562,
#  4673,
#  1138,
#  2478,
#  2392,
#  4789,
#  603,
#  2557,
#  3872,
#  4754,
#  785,
#  2361,
#  3593,
#  4332,
#  4980,
#  97,
#  4189,
#  3704,
#  3573,
#  4435,
#  35,
#  4453,
#  2230,
#  717,
#  1277,
#  3296,
#  1916,
#  919,
#  2916,
#  3127,
#  4899,
#  377,
#  4850,
#  1400,
#  1403,
#  674,
#  62,
#  1153,
#  4614,
#  2772,
#  3248,
#  262,
#  2280,
#  1451,
#  3888,
#  2729,
#  1102,
#  2363,
#  296,
#  714,
#  3434,
#  1789,
#  4075,
#  3426,
#  3386,
#  3984,
#  1615,
#  2337,
#  1241,
#  1252,
#  1677,
#  4327,
#  4005,
#  4155,
#  2962,
#  213,
#  216,
#  4993,
#  3059,
#  1569,
#  4496,
#  566,
#  4725,
#  20,
#  762,
#  1939,
#  3145,
#  3986,
#  2005,
#  2337,
#  1165,
#  1678,
#  4981,
#  2835,
#  4108,
#  3048,
#  3802,
#  1190,
#  3868,
#  257,
#  1846,
#  4978,
#  278,
#  991,
#  3448,
#  4458,
#  328,
#  81,
#  3995,
#  4779,
#  164,
#  3558,
#  3171,
#  3582,
#  3632,
#  3561,
#  3229,
#  1098,
#  2481,
#  3829,
#  4467,
#  1087,
#  1550,
#  4221,
#  4947,
#  2950,
#  3848,
#  2663,
#  2682,
#  2948,
#  1968,
#  4114,
#  2431,
#  4720,
#  3798,
#  2201,
#  4247,
#  4648,
#  2377,
#  1596,
#  753,
#  3519,
#  1631,
#  749,
#  3542,
#  3374,
#  555,
#  2087,
#  1237,
#  2139,
#  1797,
#  2537,
#  668,
#  972,
#  1076,
#  1638,
#  2223,
#  1292,
#  2679,
#  1077,
#  2608,
#  2199,
#  2578,
#  4097,
#  3648,
#  982,
#  4142,
#  3823,
#  867,
#  1348,
#  113,
#  378,
#  2871,
#  1416,
#  2193,
#  3025,
#  884,
#  2869,
#  152,
#  1836,
#  2157,
#  927,
#  4491,
#  4776,
#  4400,
#  2864,
#  4998,
#  170,
#  998,
#  1164,
#  4404,
#  469,
#  695,
#  2668,
#  1958,
#  2334,
#  1521,
#  706,
#  3315,
#  3524,
#  2897,
#  4344,
#  4371,
#  4458,
#  2662,
#  2115,
#  213,
#  1729,
#  1944,
#  3803,
#  4416,
#  1032,
#  2365,
#  1951,
#  3722,
#  4212,
#  2383,
#  120,
#  3470,
#  801,
#  2052,
#  4609,
#  4712,
#  3683,
#  979,
#  3653,
#  2561,
#  18,
#  3269,
#  4909,
#  2904,
#  4852,
#  1913,
#  616,
#  4254,
#  3347,
#  3307,
#  1998,
#  2257,
#  3191,
#  3971,
#  646,
#  2657,
#  2347,
#  3044,
#  4173,
#  3644,
#  3124,
#  2699,
#  3149,
#  1184,
#  2146,
#  3919,
#  1987,
#  1577,
#  3125,
#  1029,
#  1628,
#  4229,
#  552,
#  4990,
#  1602,
#  3710,
#  309,
#  1675,
#  3046,
#  2466,
#  1964,
#  3391,
#  2526,
#  2866,
#  1804,
#  2845,
#  1746,
#  1147,
#  2459,
#  2565,
#  3719,
#  3489,
#  3960,
#  508,
#  3484,
#  1316,
#  690,
#  2695,
#  2372,
#  127,
#  372,
#  2656,
#  1493,
#  1611,
#  3842,
#  1912,
#  4885,
#  3071,
#  827,
#  3374,
#  4847,
#  3048,
#  2642,
#  2379,
#  2474,
#  4476,
#  3473,
#  2770,
#  1015,
#  197,
#  4326,
#  2841,
#  2604,
#  3093,
#  1686,
#  993,
#  4679,
#  2501,
#  2758,
#  1687,
#  2119,
#  2613,
#  4105,
#  106,
#  3883,
#  1418,
#  272,
#  3868,
#  1409,
#  4927,
#  2778,
#  272,
#  3620,
#  2001,
#  4117,
#  1431,
#  99,
#  4865,
#  1624,
#  2754,
#  2906,
#  2368,
#  1324,
#  2878,
#  2687,
#  2663,
#  1942,
#  4479,
#  50,
#  2460,
#  1333,
#  3537,
#  3189,
#  1209,
#  322,
#  3948,
#  4863,
#  2720,
#  1202,
#  4348,
#  4777,
#  4546,
#  752,
#  1536,
#  1608,
#  4038,
#  220,
#  4516,
#  1169,
#  33,
#  1287,
#  1665,
#  4292,
#  881,
#  4412,
#  3395,
#  303,
#  2005,
#  860,
#  4101,
#  2995,
#  3650,
#  689,
#  2944,
#  718,
#  4551,
#  483,
#  2111,
#  2157,
#  797,
#  97,
#  1491,
#  2329,
#  2444,
#  4169,
#  3970,
#  4899,
#  507,
#  3463,
#  310,
#  4507,
#  2011,
#  3420,
#  4921,
#  1880,
#  4491,
#  13,
#  4520,
#  2163,
#  4035,
#  3738,
#  4669,
#  2650,
#  3867,
#  2011,
#  1433,
#  4318,
#  4506,
#  982,
#  2623,
#  4661,
#  4606,
#  4804,
#  3261,
#  2540,
#  477,
#  4758,
#  4669,
#  4171,
#  1372,
#  2435,
#  1049,
#  ...]

# %%
# Following the same method as above, we create tuples with the counts of each number

# Mapping tuples with count of one for each word :
map_int=sub_RDD.map(lambda word : (word,1))

# Reducing by key to sum the counts by word : 
reduce_int=map_int.reduceByKey(add)

# Perfoming the action collect to view the results : 
reduce_int.collect()
# Out:
# [(0, 1),
#  (4096, 2),
#  (4228, 2),
#  (4, 2),
#  (2796, 1),
#  (2056, 3),
#  (4780, 3),
#  (2728, 1),
#  (4108, 5),
#  (3780, 1),
#  (2264, 5),
#  (2064, 1),
#  (4440, 2),
#  (20, 4),
#  (2592, 1),
#  (2072, 2),
#  (2052, 5),
#  (1160, 1),
#  (2076, 1),
#  (32, 2),
#  (2736, 1),
#  (2456, 2),
#  (4132, 1),
#  (3820, 1),
#  (2088, 1),
#  (1372, 2),
#  (956, 1),
#  (44, 3),
#  (4160, 2),
#  (2684, 2),
#  (48, 2),
#  (3080, 1),
#  (3944, 2),
#  (820, 1),
#  (56, 2),
#  (4788, 1),
#  (60, 1),
#  (4912, 4),
#  (64, 2),
#  (4448, 4),
#  (68, 3),
#  (2048, 1),
#  (72, 4),
#  (2060, 4),
#  (4776, 2),
#  (2124, 4),
#  (2128, 3),
#  (2744, 1),
#  (84, 3),
#  (3156, 2),
#  (2660, 1),
#  (2404, 1),
#  (3208, 1),
#  (92, 1),
#  (1776, 1),
#  (4192, 4),
#  (4112, 3),
#  (4504, 1),
#  (2148, 2),
#  (3928, 1),
#  (276, 1),
#  (104, 2),
#  (700, 2),
#  (2156, 1),
#  (4820, 1),
#  (112, 3),
#  (360, 1),
#  (4212, 2),
#  (1504, 1),
#  (120, 2),
#  (2068, 2),
#  (1436, 1),
#  (124, 4),
#  (128, 1),
#  (1728, 2),
#  (2732, 1),
#  (132, 2),
#  (28, 1),
#  (2184, 2),
#  (4460, 1),
#  (1232, 2),
#  (2192, 1),
#  (24, 3),
#  (148, 2),
#  (4188, 4),
#  (152, 2),
#  (708, 3),
#  (156, 4),
#  (2208, 3),
#  (4464, 2),
#  (3756, 1),
#  (164, 3),
#  (832, 1),
#  (2216, 3),
#  (3100, 2),
#  (3588, 1),
#  (2220, 3),
#  (4420, 5),
#  (176, 4),
#  (3784, 3),
#  (2228, 2),
#  (184, 2),
#  (4468, 1),
#  (688, 1),
#  (2236, 2),
#  (4848, 1),
#  (592, 1),
#  (2240, 1),
#  (4128, 2),
#  (4220, 1),
#  (2244, 3),
#  (4296, 1),
#  (716, 1),
#  (4300, 2),
#  (2256, 1),
#  (1400, 1),
#  (4884, 2),
#  (4308, 2),
#  (216, 3),
#  (36, 3),
#  (220, 2),
#  (3076, 1),
#  (2272, 2),
#  (2768, 3),
#  (228, 2),
#  (3148, 1),
#  (4372, 1),
#  (1576, 2),
#  (232, 3),
#  (380, 2),
#  (236, 2),
#  (240, 4),
#  (4136, 2),
#  (4236, 4),
#  (244, 5),
#  (2804, 1),
#  (4344, 3),
#  (724, 4),
#  (4348, 1),
#  (4352, 3),
#  (1408, 5),
#  (4216, 3),
#  (260, 2),
#  (540, 3),
#  (2600, 1),
#  (4360, 2),
#  (3116, 1),
#  (4364, 3),
#  (3896, 1),
#  (272, 5),
#  (1752, 2),
#  (2528, 1),
#  (2324, 2),
#  (4376, 4),
#  (4484, 3),
#  (284, 3),
#  (4384, 2),
#  (4144, 3),
#  (896, 2),
#  (2340, 5),
#  (3680, 1),
#  (2344, 4),
#  (2780, 6),
#  (1884, 1),
#  (4396, 3),
#  (4680, 2),
#  (2352, 1),
#  (1416, 1),
#  (3488, 2),
#  (2356, 2),
#  (4852, 4),
#  (3288, 3),
#  (2360, 2),
#  (3124, 4),
#  (316, 2),
#  (3440, 1),
#  (2368, 2),
#  (2428, 4),
#  (2116, 1),
#  (324, 1),
#  (328, 3),
#  (4492, 2),
#  (3216, 1),
#  (2648, 1),
#  (332, 3),
#  (1784, 3),
#  (336, 2),
#  (2104, 2),
#  (340, 2),
#  (2392, 5),
#  (4836, 4),
#  (348, 5),
#  (2400, 2),
#  (2448, 2),
#  (356, 3),
#  (344, 3),
#  (4456, 2),
#  (4156, 3),
#  (2412, 4),
#  (3276, 1),
#  (2416, 2),
#  (4840, 1),
#  (372, 1),
#  (4104, 1),
#  (4472, 1),
#  (4500, 3),
#  (4476, 4),
#  (2664, 1),
#  (3192, 1),
#  (2432, 2),
#  (848, 2),
#  (2436, 1),
#  (3900, 1),
#  (4488, 2),
#  (4844, 2),
#  (2468, 4),
#  (2444, 2),
#  (1036, 1),
#  (4496, 4),
#  (1432, 2),
#  (3764, 4),
#  (404, 7),
#  (1080, 1),
#  (408, 1),
#  (1092, 2),
#  (900, 4),
#  (2460, 1),
#  (3576, 1),
#  (3628, 2),
#  (416, 2),
#  (2800, 2),
#  (420, 2),
#  (4924, 3),
#  (4520, 2),
#  (4508, 3),
#  (3492, 1),
#  (2476, 3),
#  (4856, 1),
#  (4528, 2),
#  (2120, 2),
#  (4444, 1),
#  (2484, 2),
#  (2252, 1),
#  (440, 2),
#  (3828, 4),
#  (2492, 2),
#  (492, 1),
#  (4652, 1),
#  (2496, 2),
#  (2464, 4),
#  (2376, 1),
#  (2500, 2),
#  (4584, 3),
#  (2168, 1),
#  (4552, 3),
#  (4172, 1),
#  (2508, 3),
#  (3084, 1),
#  (4560, 5),
#  (2808, 2),
#  (468, 2),
#  (4380, 1),
#  (1584, 1),
#  (472, 6),
#  (4516, 3),
#  (476, 1),
#  (480, 1),
#  (4176, 4),
#  (484, 1),
#  (16, 4),
#  (2536, 1),
#  (1788, 1),
#  (2540, 3),
#  (496, 3),
#  (424, 1),
#  (2548, 5),
#  (504, 3),
#  (4180, 1),
#  (508, 5),
#  (512, 1),
#  (4864, 2),
#  (2564, 3),
#  (520, 1),
#  (428, 1),
#  (3768, 3),
#  (2572, 5),
#  (1640, 1),
#  (528, 1),
#  (4184, 2),
#  (904, 2),
#  (2580, 2),
#  (3904, 2),
#  (4968, 1),
#  (2584, 3),
#  (1796, 2),
#  (4996, 1),
#  (4636, 4),
#  (3564, 1),
#  (544, 1),
#  (3504, 2),
#  (1872, 1),
#  (2596, 1),
#  (4860, 1),
#  (552, 1),
#  (3164, 4),
#  (4792, 3),
#  (556, 4),
#  (2608, 3),
#  (4872, 3),
#  (2612, 3),
#  (2616, 2),
#  (4532, 1),
#  (4668, 1),
#  (4588, 1),
#  (576, 2),
#  (96, 1),
#  (2636, 1),
#  (2628, 3),
#  (1132, 1),
#  (3088, 1),
#  (292, 2),
#  (584, 1),
#  (1804, 3),
#  (588, 1),
#  (224, 1),
#  (2336, 1),
#  (4688, 1),
#  (1464, 3),
#  (596, 1),
#  (4696, 2),
#  (4196, 1),
#  (4248, 2),
#  (1452, 1),
#  (604, 5),
#  (2816, 2),
#  (2656, 2),
#  (4880, 4),
#  (4708, 2),
#  (4232, 1),
#  (616, 1),
#  (444, 6),
#  (2668, 3),
#  (3796, 5),
#  (4720, 1),
#  (1128, 2),
#  (4724, 3),
#  (3184, 1),
#  (2680, 4),
#  (2836, 1),
#  (636, 1),
#  (1044, 1),
#  (640, 2),
#  (448, 5),
#  (3772, 3),
#  (644, 2),
#  (4164, 3),
#  (2696, 3),
#  (108, 4),
#  (652, 6),
#  (3636, 5),
#  (656, 5),
#  (3864, 2),
#  (2204, 1),
#  (2708, 6),
#  (3568, 1),
#  (664, 5),
#  (4548, 2),
#  (668, 2),
#  (672, 2),
#  (2160, 4),
#  (676, 2),
#  (568, 1),
#  (680, 2),
#  (4892, 3),
#  (684, 3),
#  (2824, 2),
#  (4784, 1),
#  (456, 1),
#  (432, 1),
#  (2740, 2),
#  (4592, 1),
#  (696, 2),
#  (2164, 2),
#  (4524, 1),
#  (4796, 3),
#  (704, 1),
#  (4896, 3),
#  (2756, 3),
#  (100, 2),
#  (4388, 2),
#  (712, 4),
#  (460, 2),
#  (160, 3),
#  (2764, 4),
#  (4320, 2),
#  (720, 3),
#  (3428, 5),
#  (1456, 1),
#  (2772, 1),
#  (3416, 3),
#  (728, 1),
#  (1828, 3),
#  (732, 5),
#  (4116, 2),
#  (620, 1),
#  (4832, 1),
#  (2512, 2),
#  (2788, 4),
#  (2792, 4),
#  (1148, 2),
#  (3980, 3),
#  (748, 3),
#  (796, 1),
#  (752, 3),
#  (4904, 3),
#  (2480, 2),
#  (756, 2),
#  (760, 2),
#  (4564, 4),
#  (2812, 2),
#  (2760, 3),
#  (768, 4),
#  (4224, 5),
#  (772, 2),
#  (1212, 1),
#  (3640, 3),
#  (776, 3),
#  (2860, 2),
#  (780, 3),
#  (2832, 5),
#  (4568, 1),
#  (788, 1),
#  (320, 2),
#  (4888, 4),
#  (3204, 2),
#  (2844, 4),
#  (3544, 1),
#  (572, 1),
#  (2848, 2),
#  (1840, 3),
#  (4900, 2),
#  (3300, 3),
#  (2856, 6),
#  (4572, 3),
#  (436, 1),
#  (812, 4),
#  (4596, 4),
#  (2864, 3),
#  (368, 1),
#  (2868, 2),
#  (3096, 2),
#  (2872, 3),
#  (4916, 1),
#  (2624, 4),
#  (2876, 3),
#  (4392, 3),
#  (2880, 2),
#  (4576, 2),
#  (2960, 1),
#  (2884, 2),
#  (4324, 1),
#  (4868, 2),
#  (2888, 4),
#  (3212, 2),
#  (2892, 1),
#  (892, 1),
#  (2896, 3),
#  (824, 3),
#  (852, 3),
#  (4120, 1),
#  (2904, 4),
#  (3556, 1),
#  (2688, 1),
#  (860, 2),
#  (2620, 3),
#  (864, 4),
#  (4240, 3),
#  (868, 3),
#  (3408, 3),
#  (1124, 1),
#  (2920, 5),
#  (828, 1),
#  (876, 2),
#  (1656, 1),
#  (880, 2),
#  (1512, 3),
#  (884, 2),
#  (2348, 2),
#  (888, 1),
#  (4244, 2),
#  (2940, 1),
#  (2944, 4),
#  (4928, 3),
#  (2948, 4),
#  (4684, 2),
#  (2952, 5),
#  (2144, 2),
#  (3508, 1),
#  (908, 1),
#  (912, 2),
#  (1176, 3),
#  (4804, 2),
#  (3168, 5),
#  (3372, 1),
#  (2968, 1),
#  (4932, 1),
#  (2972, 2),
#  (3304, 4),
#  (2976, 2),
#  (2544, 1),
#  (4616, 1),
#  (932, 4),
#  (936, 2),
#  (4316, 3),
#  (940, 2),
#  (2424, 1),
#  (304, 2),
#  (944, 2),
#  (840, 2),
#  (948, 3),
#  (1220, 3),
#  (3000, 2),
#  (500, 2),
#  (2964, 1),
#  (3004, 4),
#  (4328, 2),
#  (960, 3),
#  (4256, 2),
#  (4260, 2),
#  (3012, 2),
#  (2828, 2),
#  (3016, 5),
#  (4940, 3),
#  (972, 3),
#  (3024, 4),
#  (4600, 4),
#  (3028, 4),
#  (1260, 1),
#  (984, 2),
#  (2212, 1),
#  (3036, 4),
#  (2516, 1),
#  (3040, 3),
#  (4944, 3),
#  (2488, 2),
#  (3044, 3),
#  (3048, 4),
#  (988, 1),
#  (1008, 1),
#  (4264, 2),
#  (3060, 1),
#  (1016, 2),
#  (2900, 3),
#  (784, 2),
#  (3072, 2),
#  (2560, 1),
#  (1028, 2),
#  (4876, 1),
#  (2080, 1),
#  (1032, 3),
#  (1196, 3),
#  (648, 2),
#  (4808, 2),
#  (3160, 1),
#  (3376, 3),
#  (1040, 2),
#  (4952, 4),
#  (3092, 2),
#  (3992, 2),
#  (1048, 2),
#  (4612, 1),
#  (1052, 1),
#  (1056, 3),
#  (1200, 5),
#  (1740, 1),
#  (4824, 5),
#  (308, 2),
#  (3112, 1),
#  (2908, 2),
#  (1068, 2),
#  (1072, 1),
#  (2568, 3),
#  (172, 1),
#  (1076, 4),
#  (4332, 1),
#  (3128, 6),
#  (1204, 1),
#  (3132, 3),
#  (3136, 4),
#  (3936, 4),
#  (3140, 2),
#  (1332, 2),
#  (1096, 3),
#  (3596, 1),
#  (1100, 2),
#  (3692, 2),
#  (1104, 3),
#  (3256, 3),
#  (4208, 3),
#  (1108, 2),
#  (1112, 1),
#  (2916, 2),
#  (1116, 2),
#  (836, 2),
#  (1120, 1),
#  (2576, 3),
#  (3172, 3),
#  (3176, 5),
#  (4284, 4),
#  (3180, 1),
#  (1136, 3),
#  (872, 2),
#  (4972, 1),
#  (3188, 2),
#  (1144, 1),
#  (532, 5),
#  (3516, 3),
#  (3196, 1),
#  (4672, 2),
#  (1152, 4),
#  (3264, 2),
#  (1156, 2),
#  (2408, 1),
#  (1900, 1),
#  (1948, 4),
#  (1164, 3),
#  (516, 2),
#  (1168, 2),
#  (536, 1),
#  (1172, 2),
#  (4608, 1),
#  (3224, 3),
#  (4292, 3),
#  (2200, 1),
#  (4540, 4),
#  (1180, 1),
#  (3108, 2),
#  (1184, 3),
#  (2928, 4),
#  (3236, 2),
#  (3240, 3),
#  (3612, 2),
#  (3244, 1),
#  (4336, 1),
#  (3248, 2),
#  (3272, 3),
#  (3252, 3),
#  (4816, 1),
#  (40, 1),
#  (1208, 3),
#  (4980, 1),
#  (3260, 3),
#  (608, 3),
#  (1336, 4),
#  (1216, 4),
#  (4640, 1),
#  (3268, 1),
#  (3104, 1),
#  (1224, 2),
#  (204, 3),
#  (1228, 1),
#  (3280, 2),
#  (3960, 3),
#  (1236, 2),
#  (3860, 1),
#  (2504, 1),
#  (1240, 3),
#  (3620, 1),
#  (1244, 2),
#  (3296, 2),
#  (208, 5),
#  (928, 2),
#  (1252, 3),
#  (2932, 4),
#  (1256, 2),
#  (3964, 3),
#  (2224, 3),
#  (3308, 2),
#  (2552, 1),
#  (792, 2),
#  (3312, 2),
#  (4648, 5),
#  (1268, 2),
#  (3444, 1),
#  (1272, 3),
#  (212, 3),
#  (1276, 3),
#  (1280, 1),
#  (4992, 5),
#  (4748, 1),
#  (3332, 1),
#  (1288, 7),
#  (2604, 3),
#  (1292, 1),
#  (1296, 4),
#  (4312, 2),
#  (1300, 4),
#  (3352, 1),
#  (3972, 4),
#  (4032, 2),
#  (3356, 3),
#  (1312, 2),
#  (4656, 2),
#  (180, 2),
#  (1316, 1),
#  (3368, 2),
#  (3292, 1),
#  (4272, 3),
#  (1324, 3),
#  (3144, 1),
#  (2840, 1),
#  (1328, 1),
#  (1928, 1),
#  (3380, 2),
#  (2000, 2),
#  (3384, 3),
#  (4660, 2),
#  (1340, 2),
#  (3916, 1),
#  (3392, 4),
#  (1248, 2),
#  (1348, 1),
#  (3400, 5),
#  (2956, 1),
#  (1356, 2),
#  (76, 1),
#  (1360, 2),
#  (4664, 1),
#  (4728, 2),
#  (1364, 2),
#  (3676, 2),
#  (2364, 3),
#  (1368, 2),
#  (2276, 2),
#  (3420, 5),
#  (1376, 1),
#  (1936, 3),
#  (1380, 2),
#  (3592, 3),
#  (1384, 3),
#  (3644, 3),
#  (3436, 2),
#  (2092, 4),
#  (1392, 2),
#  (2280, 2),
#  (1864, 1),
#  (1396, 5),
#  (2024, 1),
#  (3388, 1),
#  (3448, 1),
#  (3988, 4),
#  (4752, 2),
#  (3452, 2),
#  (3320, 3),
#  (3456, 1),
#  (1600, 3),
#  (1412, 1),
#  (1820, 1),
#  (3464, 4),
#  (2284, 1),
#  (388, 2),
#  (3468, 1),
#  (964, 4),
#  (1424, 1),
#  (920, 3),
#  (4480, 3),
#  (1428, 3),
#  (580, 1),
#  (3480, 1),
#  (4676, 1),
#  (3484, 3),
#  (364, 1),
#  (1440, 5),
#  (2288, 2),
#  (4276, 2),
#  (1444, 3),
#  (3496, 3),
#  (924, 1),
#  (1352, 2),
#  (3500, 2),
#  (1344, 2),
#  (1608, 4),
#  (1460, 1),
#  (3548, 3),
#  (2260, 1),
#  (3512, 3),
#  (3316, 2),
#  (4004, 1),
#  (1468, 3),
#  (1472, 1),
#  (4000, 2),
#  (3524, 1),
#  (3528, 3),
#  (3660, 2),
#  (1484, 1),
#  (1488, 2),
#  (248, 4),
#  (4988, 2),
#  (3540, 2),
#  (2300, 2),
#  (4800, 1),
#  (1496, 2),
#  (2980, 3),
#  (2232, 2),
#  (1500, 3),
#  (800, 5),
#  (3552, 1),
#  (1616, 2),
#  (1508, 4),
#  (2096, 3),
#  (3560, 2),
#  (252, 5),
#  (1516, 5),
#  (2028, 1),
#  (3536, 1),
#  (1520, 2),
#  (2984, 4),
#  (4756, 1),
#  (3572, 3),
#  (3324, 4),
#  (1528, 3),
#  (4692, 2),
#  (3580, 1),
#  (4620, 1),
#  (1824, 4),
#  (1536, 6),
#  (3328, 5),
#  (1892, 1),
#  (1524, 1),
#  (1540, 4),
#  (3120, 2),
#  (1544, 2),
#  (2988, 3),
#  (1548, 1),
#  (3052, 3),
#  (256, 1),
#  (1552, 2),
#  (3672, 3),
#  (188, 1),
#  (1556, 2),
#  (1284, 1),
#  (1564, 2),
#  (52, 3),
#  (3616, 1),
#  (1572, 2),
#  (3624, 4),
#  (2652, 3),
#  (1580, 3),
#  (3632, 3),
#  (264, 2),
#  (4008, 3),
#  (1588, 3),
#  (2520, 1),
#  (1592, 1),
#  (1972, 2),
#  (1596, 3),
#  (1388, 1),
#  (3648, 3),
#  (4704, 1),
#  (2440, 1),
#  (1604, 2),
#  (3656, 2),
#  (268, 3),
#  (1088, 2),
#  (1612, 1),
#  (2752, 3),
#  (3664, 2),
#  (4024, 2),
#  (1620, 5),
#  (3600, 2),
#  (804, 1),
#  (1624, 5),
#  (4964, 6),
#  (1628, 2),
#  (736, 4),
#  (2100, 1),
#  (1632, 3),
#  (4368, 2),
#  (3684, 2),
#  (3816, 1),
#  (3688, 4),
#  (4028, 4),
#  (1644, 2),
#  (1648, 2),
#  (4712, 3),
#  (2384, 2),
#  (3700, 4),
#  (4624, 1),
#  (3704, 3),
#  (3348, 4),
#  (396, 2),
#  (4556, 2),
#  (3712, 2),
#  (3008, 2),
#  (1668, 2),
#  (1672, 6),
#  (4716, 3),
#  (1676, 2),
#  (1680, 2),
#  (280, 2),
#  (1684, 1),
#  (352, 1),
#  (2852, 2),
#  (1688, 4),
#  (1988, 1),
#  (1420, 3),
#  (1692, 2),
#  (2784, 1),
#  (3284, 1),
#  (4148, 1),
#  (1696, 1),
#  (2672, 2),
#  (3748, 1),
#  (3752, 3),
#  (2332, 2),
#  (1708, 1),
#  (1712, 2),
#  (1992, 2),
#  (1716, 2),
#  (4744, 2),
#  (1720, 3),
#  (2676, 2),
#  (1724, 1),
#  (3808, 2),
#  (3776, 3),
#  (3360, 3),
#  (3740, 1),
#  (1732, 3),
#  (1736, 1),
#  (1996, 1),
#  (4976, 3),
#  (3788, 1),
#  (3604, 2),
#  (1744, 2),
#  (632, 3),
#  (1748, 2),
#  (740, 2),
#  (1308, 2),
#  (3800, 6),
#  (3364, 4),
#  (3804, 2),
#  (2036, 3),
#  (1760, 1),
#  (976, 2),
#  (1764, 1),
#  (1768, 1),
#  (1660, 1),
#  (2112, 1),
#  (1772, 5),
#  (4628, 6),
#  (3824, 4),
#  (296, 3),
#  (400, 1),
#  (2644, 1),
#  (1780, 2),
#  (3832, 3),
#  (3836, 1),
#  (1792, 3),
#  (1664, 2),
#  (3844, 2),
#  (3652, 2),
#  (3848, 1),
#  (300, 3),
#  (3852, 3),
#  (4544, 2),
#  (1808, 3),
#  (4056, 1),
#  (1812, 1),
#  (612, 1),
#  (4152, 3),
#  (1816, 1),
#  (3716, 2),
#  (3868, 6),
#  (3412, 1),
#  (3872, 2),
#  (4400, 3),
#  (3876, 1),
#  (4304, 4),
#  (3880, 3),
#  (844, 2),
#  (1836, 4),
#  (1084, 2),
#  (3888, 3),
#  (3720, 3),
#  (3892, 5),
#  (3812, 1),
#  (1848, 3),
#  (4404, 1),
#  (1852, 1),
#  (2312, 2),
#  (1856, 2),
#  (992, 4),
#  (3908, 1),
#  (3912, 4),
#  (2700, 2),
#  (2176, 1),
#  (1868, 3),
#  (744, 4),
#  (3920, 2),
#  (4408, 2),
#  ...]

# %%
# Displaying all numbers appearing more than 5 times, sorted in ascending order 

# We perform the transformation filter, then the action collect to turn the RDD into a list and finally we sort the result.
sorted(reduce_int.filter(lambda (x,y) : y>5).collect())
# Out:
# [(97, 6),
#  (257, 6),
#  (401, 7),
#  (404, 7),
#  (444, 6),
#  (472, 6),
#  (618, 6),
#  (652, 6),
#  (717, 10),
#  (749, 6),
#  (817, 7),
#  (827, 8),
#  (921, 6),
#  (977, 6),
#  (1113, 6),
#  (1288, 7),
#  (1431, 6),
#  (1517, 6),
#  (1536, 6),
#  (1672, 6),
#  (1870, 6),
#  (2102, 7),
#  (2305, 6),
#  (2337, 6),
#  (2478, 6),
#  (2486, 6),
#  (2537, 8),
#  (2581, 7),
#  (2686, 7),
#  (2699, 6),
#  (2708, 6),
#  (2711, 8),
#  (2717, 7),
#  (2780, 6),
#  (2803, 6),
#  (2813, 7),
#  (2856, 6),
#  (2899, 6),
#  (3025, 6),
#  (3046, 9),
#  (3128, 6),
#  (3251, 6),
#  (3269, 7),
#  (3270, 6),
#  (3307, 6),
#  (3309, 7),
#  (3491, 6),
#  (3800, 6),
#  (3831, 7),
#  (3862, 7),
#  (3868, 6),
#  (3878, 7),
#  (3911, 6),
#  (4013, 6),
#  (4048, 6),
#  (4158, 6),
#  (4162, 6),
#  (4241, 7),
#  (4386, 7),
#  (4436, 6),
#  (4450, 6),
#  (4494, 6),
#  (4538, 7),
#  (4628, 6),
#  (4737, 6),
#  (4747, 6),
#  (4753, 7),
#  (4829, 6),
#  (4841, 8),
#  (4887, 7),
#  (4938, 6),
#  (4964, 6)]

# %% [markdown]
# ### An improved WordCount
#
# Print the top 10 most frequent words with their probability of appearance

# %%
# Printing the 10 most frequent words with their probability of appearance :

#  We take the 10 words with the highest count with takeOrdered (as above)
ten_freq = frequent_words.takeOrdered(10,key=lambda x: -x[1])

# Using the count action, we compute the total number of words in the text
tot_words = words.count()

# For each word, we print the probability of appearance (nb of times it appears/total number of words)
for x in ten_freq:
    print("Word: {}, Proba of appearence: {:.2f}%".format(x[0], 100.0*x[1]/tot_words))
# Out:
# Word: the, Proba of appearence: 4.86%
# Word: and, Proba of appearence: 3.55%
# Word: i, Proba of appearence: 2.75%
# Word: to, Proba of appearence: 2.75%
# Word: of, Proba of appearence: 2.26%
# Word: a, Proba of appearence: 1.78%
# Word: he, Proba of appearence: 1.53%
# Word: in, Proba of appearence: 1.53%
# Word: that, Proba of appearence: 1.47%
# Word: it, Proba of appearence: 1.14%

# %% [markdown]
# Get rid of special characters (.,:!?')

# %%
# We want to remove the special characters, contained in string.punctuation

import string,re

# We use the compile function of re
regex = re.compile('[%s]' % re.escape(string.punctuation))

# and map it to each line with sub to replace the punctuation by '' (empty)
words_bis = words.map(lambda line : regex.sub('',line))

# Displaying the results
words_bis.collect()
# Out:
# [u'the',
#  u'project',
#  u'gutenberg',
#  u'ebook',
#  u'of',
#  u'dracula',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'this',
#  u'ebook',
#  u'is',
#  u'for',
#  u'the',
#  u'use',
#  u'of',
#  u'anyone',
#  u'anywhere',
#  u'at',
#  u'no',
#  u'cost',
#  u'and',
#  u'with',
#  u'almost',
#  u'no',
#  u'restrictions',
#  u'whatsoever',
#  u'you',
#  u'may',
#  u'copy',
#  u'it',
#  u'give',
#  u'it',
#  u'away',
#  u'or',
#  u'reuse',
#  u'it',
#  u'under',
#  u'the',
#  u'terms',
#  u'of',
#  u'the',
#  u'project',
#  u'gutenberg',
#  u'license',
#  u'included',
#  u'with',
#  u'this',
#  u'ebook',
#  u'or',
#  u'online',
#  u'at',
#  u'wwwgutenbergorglicense',
#  u'title',
#  u'dracula',
#  u'author',
#  u'bram',
#  u'stoker',
#  u'release',
#  u'date',
#  u'august',
#  u'16',
#  u'2013',
#  u'ebook',
#  u'345',
#  u'language',
#  u'english',
#  u'',
#  u'start',
#  u'of',
#  u'this',
#  u'project',
#  u'gutenberg',
#  u'ebook',
#  u'dracula',
#  u'',
#  u'produced',
#  u'by',
#  u'chuck',
#  u'greif',
#  u'and',
#  u'the',
#  u'online',
#  u'distributed',
#  u'proofreading',
#  u'team',
#  u'at',
#  u'httpwwwpgdpnet',
#  u'this',
#  u'file',
#  u'was',
#  u'produced',
#  u'from',
#  u'images',
#  u'generously',
#  u'made',
#  u'available',
#  u'by',
#  u'the',
#  u'internet',
#  u'archive',
#  u'dracula',
#  u'dracula',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'illustration',
#  u'colophon',
#  u'new',
#  u'york',
#  u'grosset',
#  u'',
#  u'dunlap',
#  u'publishers',
#  u'copyright',
#  u'1897',
#  u'in',
#  u'the',
#  u'united',
#  u'states',
#  u'of',
#  u'america',
#  u'according',
#  u'to',
#  u'act',
#  u'of',
#  u'congress',
#  u'by',
#  u'bram',
#  u'stoker',
#  u'all',
#  u'rights',
#  u'reserved',
#  u'printed',
#  u'in',
#  u'the',
#  u'united',
#  u'states',
#  u'at',
#  u'the',
#  u'country',
#  u'life',
#  u'press',
#  u'garden',
#  u'city',
#  u'ny',
#  u'to',
#  u'my',
#  u'dear',
#  u'friend',
#  u'hommybeg',
#  u'contents',
#  u'chapter',
#  u'i',
#  u'page',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'1',
#  u'chapter',
#  u'ii',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'14',
#  u'chapter',
#  u'iii',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'26',
#  u'chapter',
#  u'iv',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'38',
#  u'chapter',
#  u'v',
#  u'letterslucy',
#  u'and',
#  u'mina',
#  u'51',
#  u'chapter',
#  u'vi',
#  u'mina',
#  u'murrays',
#  u'journal',
#  u'59',
#  u'chapter',
#  u'vii',
#  u'cutting',
#  u'from',
#  u'the',
#  u'dailygraph',
#  u'8',
#  u'august',
#  u'71',
#  u'chapter',
#  u'viii',
#  u'mina',
#  u'murrays',
#  u'journal',
#  u'84',
#  u'chapter',
#  u'ix',
#  u'mina',
#  u'murrays',
#  u'journal',
#  u'98',
#  u'chapter',
#  u'x',
#  u'mina',
#  u'murrays',
#  u'journal',
#  u'111',
#  u'chapter',
#  u'xi',
#  u'lucy',
#  u'westenras',
#  u'diary',
#  u'124',
#  u'chapter',
#  u'xii',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'136',
#  u'chapter',
#  u'xiii',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'152',
#  u'chapter',
#  u'xiv',
#  u'mina',
#  u'harkers',
#  u'journal',
#  u'167',
#  u'chapter',
#  u'xv',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'181',
#  u'chapter',
#  u'xvi',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'194',
#  u'chapter',
#  u'xvii',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'204',
#  u'chapter',
#  u'xviii',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'216',
#  u'chapter',
#  u'xix',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'231',
#  u'chapter',
#  u'xx',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'243',
#  u'chapter',
#  u'xxi',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'256',
#  u'chapter',
#  u'xxii',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'269',
#  u'chapter',
#  u'xxiii',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'281',
#  u'chapter',
#  u'xxiv',
#  u'dr',
#  u'sewards',
#  u'phonograph',
#  u'diary',
#  u'spoken',
#  u'by',
#  u'van',
#  u'helsing',
#  u'294',
#  u'chapter',
#  u'xxv',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'308',
#  u'chapter',
#  u'xxvi',
#  u'dr',
#  u'sewards',
#  u'diary',
#  u'322',
#  u'chapter',
#  u'xxvii',
#  u'mina',
#  u'harkers',
#  u'journal',
#  u'338',
#  u'dracula',
#  u'chapter',
#  u'i',
#  u'jonathan',
#  u'harkers',
#  u'journal',
#  u'kept',
#  u'in',
#  u'shorthand',
#  u'3',
#  u'may',
#  u'bistritzleft',
#  u'munich',
#  u'at',
#  u'835',
#  u'p',
#  u'm',
#  u'on',
#  u'1st',
#  u'may',
#  u'arriving',
#  u'at',
#  u'vienna',
#  u'early',
#  u'next',
#  u'morning',
#  u'should',
#  u'have',
#  u'arrived',
#  u'at',
#  u'646',
#  u'but',
#  u'train',
#  u'was',
#  u'an',
#  u'hour',
#  u'late',
#  u'budapesth',
#  u'seems',
#  u'a',
#  u'wonderful',
#  u'place',
#  u'from',
#  u'the',
#  u'glimpse',
#  u'which',
#  u'i',
#  u'got',
#  u'of',
#  u'it',
#  u'from',
#  u'the',
#  u'train',
#  u'and',
#  u'the',
#  u'little',
#  u'i',
#  u'could',
#  u'walk',
#  u'through',
#  u'the',
#  u'streets',
#  u'i',
#  u'feared',
#  u'to',
#  u'go',
#  u'very',
#  u'far',
#  u'from',
#  u'the',
#  u'station',
#  u'as',
#  u'we',
#  u'had',
#  u'arrived',
#  u'late',
#  u'and',
#  u'would',
#  u'start',
#  u'as',
#  u'near',
#  u'the',
#  u'correct',
#  u'time',
#  u'as',
#  u'possible',
#  u'the',
#  u'impression',
#  u'i',
#  u'had',
#  u'was',
#  u'that',
#  u'we',
#  u'were',
#  u'leaving',
#  u'the',
#  u'west',
#  u'and',
#  u'entering',
#  u'the',
#  u'east',
#  u'the',
#  u'most',
#  u'western',
#  u'of',
#  u'splendid',
#  u'bridges',
#  u'over',
#  u'the',
#  u'danube',
#  u'which',
#  u'is',
#  u'here',
#  u'of',
#  u'noble',
#  u'width',
#  u'and',
#  u'depth',
#  u'took',
#  u'us',
#  u'among',
#  u'the',
#  u'traditions',
#  u'of',
#  u'turkish',
#  u'rule',
#  u'we',
#  u'left',
#  u'in',
#  u'pretty',
#  u'good',
#  u'time',
#  u'and',
#  u'came',
#  u'after',
#  u'nightfall',
#  u'to',
#  u'klausenburgh',
#  u'here',
#  u'i',
#  u'stopped',
#  u'for',
#  u'the',
#  u'night',
#  u'at',
#  u'the',
#  u'hotel',
#  u'royale',
#  u'i',
#  u'had',
#  u'for',
#  u'dinner',
#  u'or',
#  u'rather',
#  u'supper',
#  u'a',
#  u'chicken',
#  u'done',
#  u'up',
#  u'some',
#  u'way',
#  u'with',
#  u'red',
#  u'pepper',
#  u'which',
#  u'was',
#  u'very',
#  u'good',
#  u'but',
#  u'thirsty',
#  u'mem',
#  u'get',
#  u'recipe',
#  u'for',
#  u'mina',
#  u'i',
#  u'asked',
#  u'the',
#  u'waiter',
#  u'and',
#  u'he',
#  u'said',
#  u'it',
#  u'was',
#  u'called',
#  u'paprika',
#  u'hendl',
#  u'and',
#  u'that',
#  u'as',
#  u'it',
#  u'was',
#  u'a',
#  u'national',
#  u'dish',
#  u'i',
#  u'should',
#  u'be',
#  u'able',
#  u'to',
#  u'get',
#  u'it',
#  u'anywhere',
#  u'along',
#  u'the',
#  u'carpathians',
#  u'i',
#  u'found',
#  u'my',
#  u'smattering',
#  u'of',
#  u'german',
#  u'very',
#  u'useful',
#  u'here',
#  u'indeed',
#  u'i',
#  u'dont',
#  u'know',
#  u'how',
#  u'i',
#  u'should',
#  u'be',
#  u'able',
#  u'to',
#  u'get',
#  u'on',
#  u'without',
#  u'it',
#  u'having',
#  u'had',
#  u'some',
#  u'time',
#  u'at',
#  u'my',
#  u'disposal',
#  u'when',
#  u'in',
#  u'london',
#  u'i',
#  u'had',
#  u'visited',
#  u'the',
#  u'british',
#  u'museum',
#  u'and',
#  u'made',
#  u'search',
#  u'among',
#  u'the',
#  u'books',
#  u'and',
#  u'maps',
#  u'in',
#  u'the',
#  u'library',
#  u'regarding',
#  u'transylvania',
#  u'it',
#  u'had',
#  u'struck',
#  u'me',
#  u'that',
#  u'some',
#  u'foreknowledge',
#  u'of',
#  u'the',
#  u'country',
#  u'could',
#  u'hardly',
#  u'fail',
#  u'to',
#  u'have',
#  u'some',
#  u'importance',
#  u'in',
#  u'dealing',
#  u'with',
#  u'a',
#  u'nobleman',
#  u'of',
#  u'that',
#  u'country',
#  u'i',
#  u'find',
#  u'that',
#  u'the',
#  u'district',
#  u'he',
#  u'named',
#  u'is',
#  u'in',
#  u'the',
#  u'extreme',
#  u'east',
#  u'of',
#  u'the',
#  u'country',
#  u'just',
#  u'on',
#  u'the',
#  u'borders',
#  u'of',
#  u'three',
#  u'states',
#  u'transylvania',
#  u'moldavia',
#  u'and',
#  u'bukovina',
#  u'in',
#  u'the',
#  u'midst',
#  u'of',
#  u'the',
#  u'carpathian',
#  u'mountains',
#  u'one',
#  u'of',
#  u'the',
#  u'wildest',
#  u'and',
#  u'least',
#  u'known',
#  u'portions',
#  u'of',
#  u'europe',
#  u'i',
#  u'was',
#  u'not',
#  u'able',
#  u'to',
#  u'light',
#  u'on',
#  u'any',
#  u'map',
#  u'or',
#  u'work',
#  u'giving',
#  u'the',
#  u'exact',
#  u'locality',
#  u'of',
#  u'the',
#  u'castle',
#  u'dracula',
#  u'as',
#  u'there',
#  u'are',
#  u'no',
#  u'maps',
#  u'of',
#  u'this',
#  u'country',
#  u'as',
#  u'yet',
#  u'to',
#  u'compare',
#  u'with',
#  u'our',
#  u'own',
#  u'ordnance',
#  u'survey',
#  u'maps',
#  u'but',
#  u'i',
#  u'found',
#  u'that',
#  u'bistritz',
#  u'the',
#  u'post',
#  u'town',
#  u'named',
#  u'by',
#  u'count',
#  u'dracula',
#  u'is',
#  u'a',
#  u'fairly',
#  u'wellknown',
#  u'place',
#  u'i',
#  u'shall',
#  u'enter',
#  u'here',
#  u'some',
#  u'of',
#  u'my',
#  u'notes',
#  u'as',
#  u'they',
#  u'may',
#  u'refresh',
#  u'my',
#  u'memory',
#  u'when',
#  u'i',
#  u'talk',
#  u'over',
#  u'my',
#  u'travels',
#  u'with',
#  u'mina',
#  u'in',
#  u'the',
#  u'population',
#  u'of',
#  u'transylvania',
#  u'there',
#  u'are',
#  u'four',
#  u'distinct',
#  u'nationalities',
#  u'saxons',
#  u'in',
#  u'the',
#  u'south',
#  u'and',
#  u'mixed',
#  u'with',
#  u'them',
#  u'the',
#  u'wallachs',
#  u'who',
#  u'are',
#  u'the',
#  u'descendants',
#  u'of',
#  u'the',
#  u'dacians',
#  u'magyars',
#  u'in',
#  u'the',
#  u'west',
#  u'and',
#  u'szekelys',
#  u'in',
#  u'the',
#  u'east',
#  u'and',
#  u'north',
#  u'i',
#  u'am',
#  u'going',
#  u'among',
#  u'the',
#  u'latter',
#  u'who',
#  u'claim',
#  u'to',
#  u'be',
#  u'descended',
#  u'from',
#  u'attila',
#  u'and',
#  u'the',
#  u'huns',
#  u'this',
#  u'may',
#  u'be',
#  u'so',
#  u'for',
#  u'when',
#  u'the',
#  u'magyars',
#  u'conquered',
#  u'the',
#  u'country',
#  u'in',
#  u'the',
#  u'eleventh',
#  u'century',
#  u'they',
#  u'found',
#  u'the',
#  u'huns',
#  u'settled',
#  u'in',
#  u'it',
#  u'i',
#  u'read',
#  u'that',
#  u'every',
#  u'known',
#  u'superstition',
#  u'in',
#  u'the',
#  u'world',
#  u'is',
#  u'gathered',
#  u'into',
#  u'the',
#  u'horseshoe',
#  u'of',
#  u'the',
#  u'carpathians',
#  u'as',
#  u'if',
#  u'it',
#  u'were',
#  u'the',
#  u'centre',
#  u'of',
#  u'some',
#  u'sort',
#  u'of',
#  u'imaginative',
#  u'whirlpool',
#  u'if',
#  u'so',
#  u'my',
#  u'stay',
#  u'may',
#  u'be',
#  u'very',
#  u'interesting',
#  u'mem',
#  u'i',
#  u'must',
#  u'ask',
#  u'the',
#  u'count',
#  u'all',
#  u'about',
#  u'them',
#  u'i',
#  u'did',
#  u'not',
#  u'sleep',
#  u'well',
#  u'though',
#  u'my',
#  u'bed',
#  u'was',
#  u'comfortable',
#  u'enough',
#  u'for',
#  u'i',
#  u'had',
#  u'all',
#  u'sorts',
#  u'of',
#  u'queer',
#  u'dreams',
#  u'there',
#  u'was',
#  u'a',
#  u'dog',
#  u'howling',
#  u'all',
#  u'night',
#  u'under',
#  u'my',
#  u'window',
#  u'which',
#  u'may',
#  u'have',
#  u'had',
#  u'something',
#  u'to',
#  u'do',
#  u'with',
#  u'it',
#  u'or',
#  u'it',
#  u'may',
#  u'have',
#  u'been',
#  u'the',
#  u'paprika',
#  u'for',
#  u'i',
#  u'had',
#  u'to',
#  u'drink',
#  u'up',
#  u'all',
#  u'the',
#  u'water',
#  u'in',
#  u'my',
#  u'carafe',
#  u'and',
#  u'was',
#  u'still',
#  u'thirsty',
#  u'towards',
#  u'morning',
#  u'i',
#  u'slept',
#  u'and',
#  u'was',
#  u'wakened',
#  u'by',
#  u'the',
#  u'continuous',
#  u'knocking',
#  u'at',
#  u'my',
#  u'door',
#  u'so',
#  u'i',
#  u'guess',
#  u'i',
#  u'must',
#  u'have',
#  u'been',
#  u'sleeping',
#  u'soundly',
#  u'then',
#  u'i',
#  u'had',
#  u'for',
#  u'breakfast',
#  u'more',
#  u'paprika',
#  u'and',
#  u'a',
#  u'sort',
#  u'of',
#  u'porridge',
#  u'of',
#  u'maize',
#  u'flour',
#  u'which',
#  u'they',
#  u'said',
#  u'was',
#  u'mamaliga',
#  u'and',
#  u'eggplant',
#  u'stuffed',
#  u'with',
#  u'forcemeat',
#  u'a',
#  u'very',
#  u'excellent',
#  u'dish',
#  u'which',
#  u'they',
#  u'call',
#  u'impletata',
#  u'mem',
#  u'get',
#  u'recipe',
#  u'for',
#  u'this',
#  u'also',
#  u'i',
#  u'had',
#  u'to',
#  u'hurry',
#  u'breakfast',
#  u'for',
#  u'the',
#  u'train',
#  u'started',
#  u'a',
#  u'little',
#  u'before',
#  u'eight',
#  u'or',
#  u'rather',
#  u'it',
#  u'ought',
#  u'to',
#  u'have',
#  u'done',
#  u'so',
#  u'for',
#  u'after',
#  u'rushing',
#  u'to',
#  u'the',
#  u'station',
#  u'at',
#  u'730',
#  u'i',
#  ...]

# %% [markdown]
# ### Identify the transformations and the actions in your script (first wordcount)

# %% [markdown]
# > We have the following actions : take, takeOrdered, collect, count.
#
# > We used the following transformations : flatMap, map, filter, reduceByKey.

# %% [markdown]
# ### How many times are the transformations evaluated?

# %% [markdown]
# > Transformations are evaluated each time an action is taken on it. Thus, it depends.

# %% [markdown]
# ### Can you reduce this number?

# %% [markdown]
# > We can use persist or cache to cache the RDD in memory or on disk. It would avoid the recomputation of each transformation.

# %%
sc.stop()

# %% [markdown]
# ## Part 3 : Spark SQL and dataframes
#
# In this part, you will explore Spark DataFrames and the SQL Context. In particular, we will work on a database that contains a sample of the world population by working on data that comes from [pplapi](http://pplapi.com/). The file [agents.json](./SparkData/agents.json) is a file that was extracted from this api using the following command :
#
#
# `wget https://s3-eu-west-1.amazonaws.com/course.oc-static.com/courses/4297166/agents.json`

# %%
# Preparing the session
import pyspark # only run after findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# Reading the data
df = spark.read.json("./SparkData/agents.json")

# %% [markdown]
# Print the 5 first lines of the dataframe `df`

# %%
# Printing the 5 first lines of the spark dataframe with the head function

df.head(5)
# Out:
# [Row(country_name=u'China', id=227417393, latitude=33.15219798270325, longitude=100.85840672174572, sex=u'Male'),
#  Row(country_name=u'Haiti', id=6821129477, latitude=19.325567983697297, longitude=-72.43795260265814, sex=u'Female'),
#  Row(country_name=u'India', id=2078667700, latitude=23.645271492037235, longitude=80.85636526088884, sex=u'Female'),
#  Row(country_name=u'China', id=477556555, latitude=33.45864668881662, longitude=93.33604038078953, sex=u'Female'),
#  Row(country_name=u'India', id=1379059984, latitude=28.816938290678692, longitude=80.7728698035823, sex=u'Female')]

# %% [markdown]
# Write the spark instructions that enable to display the number of French agents.

# %%
# Displaying the number of French agents

# We use filter on the dataframe to select only French agents and then count to compute the number.
df.filter(df.country_name=='France').count()
# Out:
# 94

# %% [markdown]
# Write the spark instructions that enable to display the number of Indian female agents.

# %%
# Displaying the number of Indian female agents

# We use filter on the dataframe to select only Indian and female agents and then count to compute the number.

df.filter((df.country_name=='India')&(df.sex=='Female')).count()
# Out:
# 828

# %% [markdown]
# Using the notion of temporary view (function `createTempView`), create a temporary view associated to the dataframe `df`.

# %%
# We create a temporary view for the dataframe df : 

df.createTempView("temp_table")

# %% [markdown]
# Write some SQL query on the resulting table as shown in the example below.

# %%
spark.sql("SELECT country_name,id FROM temp_table ORDER BY id DESC LIMIT 10").show()
# Out:
# +-----------------+----------+
# |     country_name|        id|
# +-----------------+----------+
# | French Polynesia|7170821229|
# |       Cabo Verde|7167692449|
# |         Suriname|7166451460|
# |         Suriname|7166235088|
# |            Macau|7166034642|
# |       Montenegro|7164357515|
# |Equatorial Guinea|7163867872|
# |           Bhutan|7163256789|
# |           Bhutan|7163004645|
# |           Bhutan|7162877973|
# +-----------------+----------+

# %%
# 5 SQL queries run with spark.sql(QUERY).show() : 

# Displaying the latitude and longitude of French agents 
spark.sql("SELECT latitude,longitude FROM temp_table WHERE country_name = 'France' ").show()

# Displaying the country and id of agents located at a place with latitude & longitude between 0.5 and 1
spark.sql("SELECT country_name,id FROM temp_table WHERE latitude < 1 AND latitude > 0.5 AND longitude < 1 \
          AND longitude > 0.5 ").show()

# Displaying the countries sorted in alphabetical order 
spark.sql("SELECT country_name FROM temp_table GROUP BY country_name ORDER BY country_name").show()

# Displaying the number of agents in each country (with COUNT), sorted alphabetically
spark.sql("SELECT COUNT(id), country_name FROM temp_table GROUP BY country_name ORDER BY country_name").show()

# Displaying the average latitude and longitude of agents in Colombia
spark.sql("SELECT country_name, AVG(latitude), AVG(longitude) FROM temp_table \
          WHERE country_name='Colombia' GROUP BY country_name").show()
# Out:
# +--------------------+--------------------+
# |            latitude|           longitude|
# +--------------------+--------------------+
# |-0.21142875508479517|-0.00395021443374...|
# |  1.5099359591520582| -1.7155442515387973|
# | 0.06978158062530335|  -1.529365900793559|
# |-0.15326107452236482|  2.1243709186708934|
# |-0.06137848013048675| -1.4476884573473048|
# |  1.1828646583062592| -0.6655754887318799|
# |  -0.217260169262005| 0.25087488920444284|
# | 0.49047553633530405| 0.12140982654262467|
# | -0.4702673586856353|  0.9266846158973026|
# |  1.0264852068813861| -0.2140207779096717|
# | -0.3000128566536097| 0.38070406466183515|
# |  0.9474034213864879|  1.1594401098214056|
# |  1.2383110079391852| -0.8057894807391559|
# |  0.8804203939951878| -1.9584312089442544|
# | 0.36735236174643593|-0.08389139935919032|
# |  0.3357881974469305| 0.07190625070884477|
# | 0.25437723190280187| -0.2670049016944363|
# | -0.9793883947051585| 0.09417020992108467|
# |-0.00716727104203...|  -0.564196422329451|
# |  1.2161218788026498|  0.5966144433039097|
# +--------------------+--------------------+
# only showing top 20 rows
#
# +------------+----------+
# |country_name|        id|
# +------------+----------+
# |      France|5090792846|
# |      France|5094605749|
# +------------+----------+
#
# +--------------------+
# |        country_name|
# +--------------------+
# |         Afghanistan|
# |             Albania|
# |             Algeria|
# |              Angola|
# |           Argentina|
# |             Armenia|
# |           Australia|
# |             Austria|
# |          Azerbaijan|
# |             Bahrain|
# |          Bangladesh|
# |             Belarus|
# |             Belgium|
# |               Benin|
# |              Bhutan|
# |             Bolivia|
# |Bosnia and Herzeg...|
# |            Botswana|
# |              Brazil|
# |            Bulgaria|
# +--------------------+
# only showing top 20 rows
#
# +---------+--------------------+
# |count(id)|        country_name|
# +---------+--------------------+
# |       49|         Afghanistan|
# |        7|             Albania|
# |       54|             Algeria|
# |       28|              Angola|
# |       52|           Argentina|
# |        4|             Armenia|
# |       33|           Australia|
# |       16|             Austria|
# |       18|          Azerbaijan|
# |        2|             Bahrain|
# |      227|          Bangladesh|
# |       11|             Belarus|
# |       11|             Belgium|
# |       10|               Benin|
# |        3|              Bhutan|
# |        9|             Bolivia|
# |        9|Bosnia and Herzeg...|
# |        1|            Botswana|
# |      264|              Brazil|
# |        9|            Bulgaria|
# +---------+--------------------+
# only showing top 20 rows
#
# +------------+------------------+-----------------+
# |country_name|     avg(latitude)|   avg(longitude)|
# +------------+------------------+-----------------+
# |    Colombia|4.0745601242169345|-71.9847656033187|
# +------------+------------------+-----------------+

# %%
spark.stop()
sc.stop()

# %% [markdown]
# You can also create a dataframe from an existing RDD as shown on the example below

# %%
# Creating a dataframe from existing dataframes : 
sc=pyspark.SparkContext("local[*]","Dataframe examples in Spark")
sqlContext = pyspark.SQLContext(sc)

# %%
documents_rdd = sc.parallelize([
        [1, 'cats are cute', 0],
        [2, 'dogs are playfull', 0],
        [3, 'lions are big', 1],
        [4, 'cars are fast', 1]])
users_rdd = sc.parallelize([
        [0, 'Alice', 20],
        [1, 'Bob', 23],
        [2, 'Charles', 32]])

# %%
documents_df = documents_rdd.toDF(['doc_id', 'text', 'user_id'])
users_df = users_rdd.toDF(['user_id', 'name', 'age'])

# printing the inferred schema for documents
documents_df.printSchema()
# Out:
# root
#  |-- doc_id: long (nullable = true)
#  |-- text: string (nullable = true)
#  |-- user_id: long (nullable = true)

# %% [markdown]
# Some functions can be apply to a column or to different columns. Here, we compute the age average in the dataframe `users_df`.

# %%
from pyspark.sql import functions as fn

user_age_df = users_df.select(fn.avg('age')).show()
# Out:
# +--------+
# |avg(age)|
# +--------+
# |    25.0|
# +--------+

# %% [markdown]
# Compute the max of age in the dataframe `users_df`.

# %%
# Computing the maximum age :

# We use select and apply the function max. We use show() to display the resultng dataframe.
user_age_df = users_df.select(fn.max('age')).show()
# Out:
# +--------+
# |max(age)|
# +--------+
# |      32|
# +--------+

# %% [markdown]
# Join (as in SQL) the two dataframes `users_df` and `documents_df`

# %%
# We join the two dataframes by 'user_id', using the join function

join_1 = users_df.join(documents_df, 'user_id')
join_1.show()
# Out:
# +-------+-----+---+------+-----------------+
# |user_id| name|age|doc_id|             text|
# +-------+-----+---+------+-----------------+
# |      0|Alice| 20|     1|    cats are cute|
# |      0|Alice| 20|     2|dogs are playfull|
# |      1|  Bob| 23|     3|    lions are big|
# |      1|  Bob| 23|     4|    cars are fast|
# +-------+-----+---+------+-----------------+

# %% [markdown]
# Outer Join (Left) (as in SQL) the two dataframes `users_df` and `documents_df`

# %%
# We do an outer join, which means that each information is kept, by specifying 'outer'

join_2 = users_df.join(documents_df, 'user_id', 'outer')
join_2.show()

# We can see that Charles' age and user_id are displayed, even if he doesn't have a corresponding document.
# Out:
# +-------+-------+---+------+-----------------+
# |user_id|   name|age|doc_id|             text|
# +-------+-------+---+------+-----------------+
# |      0|  Alice| 20|     1|    cats are cute|
# |      0|  Alice| 20|     2|dogs are playfull|
# |      1|    Bob| 23|     3|    lions are big|
# |      1|    Bob| 23|     4|    cars are fast|
# |      2|Charles| 32|  null|             null|
# +-------+-------+---+------+-----------------+

# %% [markdown]
# ## Part 4 : MLlib - Spark for data analysis and machine learning
#
# In this part, we will see how to create a text classifiation application with Spark. We will use some data from the newsgroups [Usenet](https://en.wikipedia.org/wiki/Usenet_newsgroup) and the objective is to predict the topic of the news.
#
# The train data is [here](./SparkData/20ng-train-all-terms.txt) and the test data [here](./SparkData/20ng-test-all-terms.txt).
# The are obtained using the following commands:
# `wget http://ana.cachopo.org/datasets-for-single-label-text-categorization/20ng-train-all-terms.txt`
# and
# `wget http://ana.cachopo.org/datasets-for-single-label-text-categorization/20ng-test-all-terms.txt`
#
# Load these data as some RDDs and translate them in DataFrames.

# %%
sc.stop()

findspark.init()
from pyspark.ml.feature import CountVectorizer

sc=pyspark.SparkContext("local[*]","machine learning in Spark")
sqlContext = pyspark.SQLContext(sc)

from pyspark.sql import Row

def load_dataframe(path):
    # We first read the text document in the path and create a RDD
    data_RDD = sc.textFile(path)
    # We split each line of the RDD to isolate the topic (which is at the beginning, before '\t') from the text of the news
    # We use Row to create the names of each row.
    intermediary=data_RDD.map(lambda x : Row(topic=x.split("\t")[0],news=x.split("\t")[1].split(" ")))
    # We finally create the corresponding dataframe
    dataframe=sqlContext.createDataFrame(intermediary)
    return dataframe

train_data = load_dataframe("./SparkData/train-all-terms.txt")
test_data = load_dataframe("./SparkData/test-all-terms.txt")

train_data.show()
test_data.show()
# Out:
# +--------------------+-----------+
# |                news|      topic|
# +--------------------+-----------+
# |[alt, atheism, fa...|alt.atheism|
# |[alt, atheism, fa...|alt.atheism|
# |[re, gospel, dati...|alt.atheism|
# |[re, university, ...|alt.atheism|
# |[re, soc, motss, ...|alt.atheism|
# |[re, a, visit, fr...|alt.atheism|
# |[re, political, a...|alt.atheism|
# |[re, an, anecdote...|alt.atheism|
# |[re, political, a...|alt.atheism|
# |[re, pompous, ass...|alt.atheism|
# |[re, pompous, ass...|alt.atheism|
# |[re, keith, schne...|alt.atheism|
# |[re, keith, schne...|alt.atheism|
# |[re, political, a...|alt.atheism|
# |[re, political, a...|alt.atheism|
# |[re, political, a...|alt.atheism|
# |[re, don, t, more...|alt.atheism|
# |[re, ancient, isl...|alt.atheism|
# |[re, political, a...|alt.atheism|
# |[re, there, must,...|alt.atheism|
# +--------------------+-----------+
# only showing top 20 rows
#
# +--------------------+-----------+
# |                news|      topic|
# +--------------------+-----------+
# |[re, about, the, ...|alt.atheism|
# |[re, amusing, ath...|alt.atheism|
# |[re, yet, more, r...|alt.atheism|
# |[re, christian, m...|alt.atheism|
# |[re, after, years...|alt.atheism|
# |[re, amusing, ath...|alt.atheism|
# |[southern, baptis...|alt.atheism|
# |[re, amusing, ath...|alt.atheism|
# |[re, requests, in...|alt.atheism|
# |[re, thoughts, on...|alt.atheism|
# |[re, what, s, a, ...|alt.atheism|
# |[re, christian, m...|alt.atheism|
# |[re, theism, and,...|alt.atheism|
# |[re, you, will, a...|alt.atheism|
# |[re, you, will, a...|alt.atheism|
# |[re, what, s, a, ...|alt.atheism|
# |[re, societally, ...|alt.atheism|
# |[re, societally, ...|alt.atheism|
# |[re, christian, m...|alt.atheism|
# |[re, gulf, war, a...|alt.atheism|
# +--------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# A first step is to represent our data, i.e. the messages in the form of a bag-of-word representation using the spark method `CountVectorizer` documented [here](https://spark.apache.org/docs/2.1.0/ml-features.html#countvectorizer)

# %%
# Bag of word representation of test and train data

# We use the CountVectorizer method on the news column to create the features column. 
# After running it a first time, we see that the vocabSize is 73713.

# Creation and training of the model :
cv = CountVectorizer(inputCol="news", outputCol="features", vocabSize=73713)

model = cv.fit(train_data)

# Application of the model on train_data to create the result dataframe: 
result = model.transform(train_data)
result.show(truncate=True)
# Out:
# +--------------------+-----------+--------------------+
# |                news|      topic|            features|
# +--------------------+-----------+--------------------+
# |[alt, atheism, fa...|alt.atheism|(73713,[0,1,2,3,4...|
# |[alt, atheism, fa...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, gospel, dati...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, university, ...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, soc, motss, ...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, a, visit, fr...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, political, a...|alt.atheism|(73713,[0,1,3,4,6...|
# |[re, an, anecdote...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, pompous, ass...|alt.atheism|(73713,[0,4,5,11,...|
# |[re, pompous, ass...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, keith, schne...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, keith, schne...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, don, t, more...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, ancient, isl...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...|
# |[re, there, must,...|alt.atheism|(73713,[0,1,2,3,4...|
# +--------------------+-----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# Displaying of the distinct labels in the datasets

# %%
train_data.select("topic").distinct().sort("topic").show(truncate=False)
# Out:
# +------------------------+
# |topic                   |
# +------------------------+
# |alt.atheism             |
# |comp.graphics           |
# |comp.os.ms-windows.misc |
# |comp.sys.ibm.pc.hardware|
# |comp.sys.mac.hardware   |
# |comp.windows.x          |
# |misc.forsale            |
# |rec.autos               |
# |rec.motorcycles         |
# |rec.sport.baseball      |
# |rec.sport.hockey        |
# |sci.crypt               |
# |sci.electronics         |
# |sci.med                 |
# |sci.space               |
# |soc.religion.christian  |
# |talk.politics.guns      |
# |talk.politics.mideast   |
# |talk.politics.misc      |
# |talk.religion.misc      |
# +------------------------+

# %% [markdown]
# We will now apply a [NaiveBayes](https://spark.apache.org/docs/latest/ml-classification-regression.html#naive-bayes) classifier to our problem.
# Take the time to read the doc and apply it to our problem. You will first have to associate a number to each label. You can use the [`String Indexer`](https://spark.apache.org/docs/2.1.0/ml-features.html#stringindexer) function of pyspark for that.

# %%
# Transformation of the label into a number
# We will use StringIndexer on the column topic to create the column label, with one number corresponding to each topic. 
from pyspark.ml.feature import StringIndexer

# Creation, training and application of the model on result :
indexer = StringIndexer(inputCol="topic", outputCol="label")
indexed_train_data = indexer.fit(result).transform(result)
indexed_train_data.show()

# Displaying the distinct labels : 
indexed_train_data.select("label").distinct().sort("topic").show(truncate=False)
# Out:
# +--------------------+-----------+--------------------+-----+
# |                news|      topic|            features|label|
# +--------------------+-----------+--------------------+-----+
# |[alt, atheism, fa...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[alt, atheism, fa...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, gospel, dati...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, university, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, soc, motss, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, a, visit, fr...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, political, a...|alt.atheism|(73713,[0,1,3,4,6...| 17.0|
# |[re, an, anecdote...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, pompous, ass...|alt.atheism|(73713,[0,4,5,11,...| 17.0|
# |[re, pompous, ass...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, keith, schne...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, keith, schne...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, don, t, more...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, ancient, isl...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, political, a...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, there, must,...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# +--------------------+-----------+--------------------+-----+
# only showing top 20 rows
#
# +-----+
# |label|
# +-----+
# |17.0 |
# |12.0 |
# |14.0 |
# |10.0 |
# |13.0 |
# |8.0  |
# |11.0 |
# |6.0  |
# |2.0  |
# |3.0  |
# |0.0  |
# |4.0  |
# |9.0  |
# |5.0  |
# |7.0  |
# |1.0  |
# |16.0 |
# |15.0 |
# |18.0 |
# |19.0 |
# +-----+

# %%
# Application of the NaivesBayes model

from pyspark.ml.classification import NaiveBayes

# Creation of the trainer and specification of its parameters
nb = NaiveBayes(smoothing=1.0, modelType="multinomial")

# Training of the model
model_nb = nb.fit(indexed_train_data)

# %%
# Creation of the test dataset with the bag of words model and the indexer :

result_test = model.transform(test_data)
indexed_test_data = indexer.fit(result).transform(result_test)
indexed_test_data.show()
# Out:
# +--------------------+-----------+--------------------+-----+
# |                news|      topic|            features|label|
# +--------------------+-----------+--------------------+-----+
# |[re, about, the, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, amusing, ath...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, yet, more, r...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, christian, m...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, after, years...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, amusing, ath...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[southern, baptis...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, amusing, ath...|alt.atheism|(73713,[0,1,4,5,6...| 17.0|
# |[re, requests, in...|alt.atheism|(73713,[0,1,4,5,6...| 17.0|
# |[re, thoughts, on...|alt.atheism|(73713,[0,1,4,5,6...| 17.0|
# |[re, what, s, a, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, christian, m...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, theism, and,...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, you, will, a...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, you, will, a...|alt.atheism|(73713,[1,2,3,4,5...| 17.0|
# |[re, what, s, a, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, societally, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, societally, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|
# |[re, christian, m...|alt.atheism|(73713,[0,1,3,4,5...| 17.0|
# |[re, gulf, war, a...|alt.atheism|(73713,[0,1,3,4,6...| 17.0|
# +--------------------+-----------+--------------------+-----+
# only showing top 20 rows

# %%
# Application of the trained model to the test dataset  

predictions = model_nb.transform(indexed_test_data)

# Displaying the prediction compared to the real value (label column) for the 20 first messages
predictions.show()
# Out:
# +--------------------+-----------+--------------------+-----+--------------------+--------------------+----------+
# |                news|      topic|            features|label|       rawPrediction|         probability|prediction|
# +--------------------+-----------+--------------------+-----+--------------------+--------------------+----------+
# |[re, about, the, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-1077.0701139151...|[1.04746942055342...|      17.0|
# |[re, amusing, ath...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-4865.8011948258...|[1.04542362129609...|      17.0|
# |[re, yet, more, r...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-2801.5395297792...|[1.37884733960126...|      17.0|
# |[re, christian, m...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-1579.1157090824...|[9.08867790888132...|      17.0|
# |[re, after, years...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-3900.6290918277...|[1.19137051036722...|      17.0|
# |[re, amusing, ath...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-2415.5243488590...|[6.53141042349908...|      17.0|
# |[southern, baptis...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-2706.0394381557...|[1.07379774615375...|      19.0|
# |[re, amusing, ath...|alt.atheism|(73713,[0,1,4,5,6...| 17.0|[-637.76997993859...|[2.72990683740069...|      17.0|
# |[re, requests, in...|alt.atheism|(73713,[0,1,4,5,6...| 17.0|[-565.01084111220...|[3.69356860848666...|      17.0|
# |[re, thoughts, on...|alt.atheism|(73713,[0,1,4,5,6...| 17.0|[-720.86391363978...|[9.30605409847867...|      17.0|
# |[re, what, s, a, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-1993.3607557772...|[5.16571807319566...|      17.0|
# |[re, christian, m...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-3119.3673842030...|[1.50403911634191...|      17.0|
# |[re, theism, and,...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-5197.8166524655...|[9.86753663106619...|      17.0|
# |[re, you, will, a...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-1573.9300517042...|[2.15284496162595...|      17.0|
# |[re, you, will, a...|alt.atheism|(73713,[1,2,3,4,5...| 17.0|[-1191.2644573417...|[2.65235264750993...|      17.0|
# |[re, what, s, a, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-1779.0562727271...|[5.35153127229451...|      17.0|
# |[re, societally, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-2518.3817887862...|[1.87761113481592...|      17.0|
# |[re, societally, ...|alt.atheism|(73713,[0,1,2,3,4...| 17.0|[-1208.8675770646...|[6.00141429091731...|      17.0|
# |[re, christian, m...|alt.atheism|(73713,[0,1,3,4,5...| 17.0|[-1619.0842102896...|[1.16985332173674...|      19.0|
# |[re, gulf, war, a...|alt.atheism|(73713,[0,1,3,4,6...| 17.0|[-1036.9086894497...|[1.88829219495922...|      15.0|
# +--------------------+-----------+--------------------+-----+--------------------+--------------------+----------+
# only showing top 20 rows

# %% [markdown]
# The Evaluation of the learned model can be done by using the [evaluation](https://spark.apache.org/docs/2.1.0/mllib-evaluation-metrics.html) module of MLlib. Print the accuracy of the obtained model.

# %%
# Evaluation of the model with MulticlassClassificationEvaluator

from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# We create an evaluator model, specifying the columns to compare :
evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
                                              metricName="accuracy")

# We compute the accuracy on the test set thanks to the predictions 
accuracy = evaluator.evaluate(predictions)
print("Test set accuracy = " + str(accuracy*100.00) + "%")
# Out:
# Test set accuracy = 79.9149840595%
